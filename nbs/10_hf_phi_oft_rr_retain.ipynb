# %% [markdown]
# Trying to modify hf dpo to work with the repos hypothesis...
#
# see
# - https://huggingface.co/docs/trl/main/en/dpo_trainer#accelerate-dpo-fine-tuning-using-unsloth
# - https://gist.github.com/alvarobartt/9898c33eb3e9c7108d9ed2330f12a708
# - https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing#scrollTo=QtoqUw80QDV0

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["WANDB_PROJECT"] = "repo-dpo" 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# os.environ["WANDB_DISABLED"] = "true"

# %%
import wandb
os.environ['WANDB_NOTEBOOK_NAME'] = nb_name = os.path.basename(globals()['__vsc_ipynb_file__']).replace('.ipynb', '').replace(' ', '_')
# enable wandb service (experimental, https://github.com/wandb/client/blob/master/docs/dev/wandb-service-user.md)
# this hopefully fixes issues with multiprocessing
wandb.require(experiment='service')

# %%
from reprpo import silence

# %%
import torch
import numpy as np
from datasets import load_dataset
from peft import LoraConfig, get_peft_model

from transformers import AutoTokenizer, AutoModelForCausalLM
from trl import DPOTrainer
from trl import DPOConfig, DPOTrainer
import gc
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import Any, Callable, Dict, List, Literal, Optional, Tuple, Union
from einops import rearrange

# %%
from contextlib import contextmanager
import pandas as pd
from matplotlib import pyplot as plt
from transformers.trainer import ProgressCallback
from transformers.utils.notebook import NotebookProgressCallback

from reprpo.helpers.adapters import set_adapter

# %%
torch.set_float32_matmul_precision("medium")
# torch.use_deterministic_algorithms(True)

# %%
max_prompt_length=64
# num_samples = 50 * 16 * 6
num_samples = 1500 * 1 * 5 # from circuit breaker * 3
max_length = 128
num_samples
# Out:
# 7500

# %% [markdown]
# ## load the model

# %%
# !pip install flash-attn --no-build-isolation --no-deps -qq

# %%
# model

# %%
# FIXME: we are meant to SFT first, so that the preferences are in sample but 1) if this works it might not be needed, and 2) this can be added later, if it works
# for now we will use the instruct model, and try something it wasn't meant to do but it in sample 
model_name = "microsoft/Phi-3-mini-4k-instruct"
# model_name = "microsoft/Phi-3-mini-4k-instruct-gguf"
use_gradient_checkpointing = True

from peft.tuners import BOFTConfig, OFTConfig
## Big adapter
peft_config = OFTConfig(
    # apply_GS=True,
    # r=8,
    target_modules=["qkv_proj", "down_proj"
                    "o_proj", "up_gate_proj",
                    ],
)
from reprpo.models.load import load_model, print_trainable_parameters




from peft import prepare_model_for_kbit_training
from peft import LoraConfig, get_peft_model

model, tokenizer = load_model(model_name, bnb=False )

if use_gradient_checkpointing:
    model.enable_input_require_grads()
from trl.trainer.utils import peft_module_casting_to_bf16
peft_module_casting_to_bf16(model)
adapter_name='ReprPO'
model = prepare_model_for_kbit_training(model, {'use_gradient_checkpointing': use_gradient_checkpointing})
model = get_peft_model(model, peft_config, adapter_name=adapter_name)
print_trainable_parameters(model)
# Out:
# You are attempting to use Flash Attention 2.0 with a model not initialized on GPU. Make sure to move the model to GPU after initializing it on CPU with `model.to('cuda')`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 339738624 || all params: 4160492544 || trainable%: 8.165827012235598

# %% [markdown]
# ## Dataset

# %%
def sample(dataset, N):
    return (dataset
            .shuffle(42)
            .select(range(
            min(len(dataset), N)))
    )

# %%
# dataset = load_dataset('Columbia-NLP/DPO-HelpSteer')
dataset = load_dataset('Atsunori/HelpSteer2-DPO')
dataset['train'] = sample(dataset['train'], num_samples)
dataset2 = dataset.rename_column('chosen_response', 'chosen').rename_column('rejected_response', 'rejected')
dataset2
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 7221
#     })
#     validation: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 373
#     })
# })

# %%
# def format_ds(row):
    
#     # WHY are we doing this? Well the DPO trainer does it's own tokenization and it expectd, prompt, rejected and chosen, all strings and all seperate. Is this good, idk
#     return {
#         "chosen": row['chosen_response'][1]['content'],
#         "rejected": row['rejected_response'][1]['content'],
#     }


# dataset2 = dataset.map(format_ds)

# %%
r = dataset2['train'][0]
print(r['prompt'])
print('===')
print(r['chosen'])
print('---')
print(r['rejected'])
# Out:
# When did women join the labor workforce outside of the home? What caused the change from housewife to breadwinner? Write a short informative paragraph under 200 words.
# ===
# In the early 20th century, less than 20% of women worked outside the home. Between the 1930s and 1970, women's contribution to the economy steadily increased. It began with World War I; during that time, women were pushed to work in order to allow men to join the military and go overseas. Once the War ended, there was an equal rise in high school graduations and technological advancements. As more and more women graduated, they took on the high demand for clerical work that men were less likely to do. Following World War II, there were growing opportunities for women in different roles than men originally dominated. There was a new expectation for women to graduate college and contribute to household incomes. By 1990, the percentage of women working increased by 76%. Recent research shows that there are approximately the same number of women in professional schools as men. According to Forbes in July 2023, 57.4 percent of the workforce are women.
# ---
# The 1900s saw a dramatic shift in the role of women in the workforce. Prior to this time, women were primarily homemakers and caregivers, with limited opportunities for paid work outside the home. However, with the rise of industrialization and the growth of the economy, women began to enter the workforce in increasing numbers.
#
# One of the primary factors that led to this change was the need for workers in factories and other industries. As men went off to war or pursued other opportunities, women were needed to fill the gaps in the workforce. This need for workers created a new sense of opportunity for women, who had previously been limited by social and cultural expectations.
#
# Another factor that contributed to the change was the growing feminist movement. Women's rights activists worked to break down barriers and stereotypes that prevented women from pursuing their own goals and ambitions. They fought for equal pay, equal opportunities, and the right to vote, among other rights.
#
# As a result of these and other factors, women began to enter the workforce in increasing numbers. They worked in factories, offices, and other industries, often performing the same jobs as men. This shift in the role of women had a profound impact on society, changing the way that people thought about gender roles and the value of women's work.
#
# Today, women continue to make up a significant portion of the workforce, and many have achieved success in a wide range of industries. While there is still work to be done to achieve true gender equality, the changes that began in the early 1900s have paved the way for a more diverse and inclusive workforce.

# %% [markdown]
# ## Eval TQA helpers

# %%
from reprpo.data.tqa import load_tqa
from torch.utils.data import DataLoader
import numpy as np


# dataset2_tqa, choice_ids = load_tqa(tokenizer, max_length, N=817)

# %% [markdown]
# How to measure TQA?
# - [TruthfullLamama](https://github.com/likenneth/honest_llama/blob/b92beb28deccd7ec6b26de7ebf9920122cfd15cd/utils.py#L268) uses https://github.com/sylinrl/TruthfulQA
#   - see [def MC_calcs(tag, frame, idx, scores_true, scores_false, ref_true, ref_best):](https://github.com/sylinrl/TruthfulQA/blob/fdd8ad1c0d00a478cf8b0bb41a3ad8378c16293b/truthfulqa/models.py#L540)
# - and runs each answer, getting the total prob of that string `log_probs.sum()`

# %%
# from reprpo.eval.mc import eval_tqa
from reprpo.gen import generation_test

# %% [markdown]
# ## Train

# %% [markdown]
# ### Modified classes
#
# - here we can defined the experimetns loss function

# %%
from reprpo.trainer import ReprPOTrainer, ReprPOConfig, wmean, coeffecient, top_k_mse, norm_smooth_l1_loss, cka_inspired_similarity, symlog_loss, mean_with_attention, normalize_output, sum_squared_error


class ReprPOTrainer2(ReprPOTrainer):
    pass

    # def reprpo_loss(
    #     self,
    #     policy_chosen_logps: torch.FloatTensor,
    #     policy_rejected_logps: torch.FloatTensor,
    #     policy_chosen_hs: torch.FloatTensor,
    #     policy_rejected_hs: torch.FloatTensor,
    #     reference_chosen_logps: torch.FloatTensor,
    #     reference_rejected_logps: torch.FloatTensor,
    #     reference_chosen_hs: torch.FloatTensor,
    #     chosen_attn_mask: torch.BoolTensor,
    #     rejected_attn_mask: torch.BoolTensor
    # ) -> Tuple[torch.FloatTensor, torch.FloatTensor, torch.FloatTensor]:

    #     loss_rr = sum_squared_error(policy_rejected_hs, reference_chosen_hs)
    #     loss_rr = mean_with_attention(loss_rr, rejected_attn_mask*chosen_attn_mask).mean()
        
    #     loss = loss_rr.sum()

    #     loss_dict = dict(loss=loss.detach())

    #     # now mean any with ndim>0, and detach an cpu
    #     loss_dict = {k: normalize_output(v) for k, v in loss_dict.items()}

    #     return loss, loss_dict

# %% [markdown]
# ### Run

# %%
from reprpo.helpers.torch import clear_mem
clear_mem()

# %%
# update the ideal number of sample for how many are available
num_data_samples = min(num_samples, len(dataset2['train']))
num_data_samples
# Out:
# 7221

# %%
num_samples
# Out:
# 7500

# %%
model.peft_config
# Out:
# {'ReprPO': OFTConfig(peft_type=<PeftType.OFT: 'OFT'>, auto_mapping=None, base_model_name_or_path='microsoft/Phi-3-mini-4k-instruct', revision=None, task_type=None, inference_mode=False, rank_pattern={}, alpha_pattern={}, r=8, module_dropout=0.0, target_modules={'up_gate_proj', 'qkv_proj', 'down_projo_proj'}, init_weights=True, layers_to_transform=None, layers_pattern=None, modules_to_save=None, coft=False, eps=6e-05, block_share=False)}

# %%
ideal_batch_size = 5
batch_size = 5
gradient_accumulation_steps = ideal_batch_size // batch_size
num_train_epochs = num_samples // num_data_samples
print(dict(gradient_accumulation_steps=gradient_accumulation_steps, num_train_epochs=num_train_epochs))

# vscode + wandb compat
dt = pd.Timestamp.now().strftime("%Y-%m-%d-%H-%M-%S")
# TODO put model and adapter base names?
run_name = f"{nb_name}-{dt}"

training_args = ReprPOConfig(
    num_train_epochs=num_train_epochs,
    learning_rate=6e-3, # 5e-7 in the dpo paper? but this method needs much more
    gradient_accumulation_steps=gradient_accumulation_steps,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size//2,

    lr_scheduler_type="constant",
    # warmup_ratio=0.2,
    optim = "adamw_8bit",
    weight_decay = 0,

    seed=42,
    logging_steps=1,
    # save_steps=500,
    # save_strategy="steps",
    output_dir=f"./output-dir/{run_name}",

    gradient_checkpointing=use_gradient_checkpointing,
    bf16=True,
    tf32=True,
    remove_unused_columns=False,
    max_grad_norm=20,

    max_prompt_length=max_prompt_length,
    max_length=max_length,

    report_to=['tensorboard', 'wandb'],
    model_adapter_name='ReprPO',
    alpha=0.5,

    run_name=run_name,
    collection_layers=[10, 25],
)

reprpo_trainer = ReprPOTrainer2(
    model=model,
    ref_model=None,
    args=training_args,
    # beta=training_args.beta,
    train_dataset=dataset2["train"],
    # eval_dataset=dataset2["test"],
    tokenizer=tokenizer,
)
model.config.use_cache = False

# Transformer does not recognise vscode notebooks
reprpo_trainer.callback_handler.remove_callback(ProgressCallback)
reprpo_trainer.callback_handler.add_callback(NotebookProgressCallback)
# Out:
# {'gradient_accumulation_steps': 1, 'num_train_epochs': 1}

# %%
# # QC train dataset
# r = reprpo_trainer.train_dataset[0]
# print('prompt', tokenizer.decode(r['prompt_input_ids']))
# print('-'*80)q
# print('chosen',tokenizer.decode(r['chosen_input_ids']))
# print('-'*80)
# print('rejected',tokenizer.decode(r['rejected_input_ids']))
# print('='*80)
clear_mem()

# %%
reprpo_trainer.train()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find 10_hf_phi_oft_rr_retain.
# wandb: Currently logged in as: wassname. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/nbs/wandb/run-20240725_101558-6cemht6c</code>
# Syncing run <strong><a href='https://wandb.ai/wassname/repo-dpo/runs/6cemht6c' target="_blank">10_hf_phi_oft_rr_retain-2024-07-25-10-15-49</a></strong> to <a href='https://wandb.ai/wassname/repo-dpo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/wassname/repo-dpo' target="_blank">https://wandb.ai/wassname/repo-dpo</a>
#  View run at <a href='https://wandb.ai/wassname/repo-dpo/runs/6cemht6c' target="_blank">https://wandb.ai/wassname/repo-dpo/runs/6cemht6c</a>
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
# 0 retain_cos_sim: 1.0000. rr_cos_sim: 0.8026
# {'logps/rejected': '-1.4', 'logps/chosen': '-0.86', 'loss': '98', 'rewards/chosen': '0', 'rewards/rejected': '0', 'retain/loss': '0', 'rr/loss': '98', 'logratios/pi': '0.53', 'logratios/ref': '0.53', 'weighting': '0.2', 'logits': '0', 'component_rr/loss': '98', 'component_retain/loss': '0', 'rr/c': '1', 'retain/c': '0', 'retain_cosine': '1', 'rr_cosine': '0.8'}
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='1346' max='1445' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1346/1445 1:22:15 < 06:03, 0.27 it/s, Epoch 0.93/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>98.323433</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2147.025391</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>386.502594</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>423.428497</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>383.352234</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1748.768311</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>365.083557</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>355.065460</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>345.451630</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>361.946228</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>826.145203</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>581.159302</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>344.635132</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>298.092499</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4001.560303</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>431.126862</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>310.320068</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>380.284271</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>364.270325</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>475.745636</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>433.726776</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>548.229187</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>404.231201</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>314.095734</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>354.169525</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>470.035431</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>420.101776</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>327.523987</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>331.285156</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>365.033936</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>304.422638</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>381.983948</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>457.070618</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>360.546936</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>293.458527</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>682.665894</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>310.360840</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>318.182007</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>278.440460</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>340.372040</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>259.315704</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>286.765900</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>246.318329</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>346.639587</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>402.259857</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1814.156006</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>313.050568</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>323.710205</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1108.805298</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>446.132172</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>368.045959</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>288.560272</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>275.644043</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>320.570801</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>286.499817</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>305.377197</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1007.020996</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>286.055420</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>485.697296</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>284.321228</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>309.637817</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>2611.962402</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>250.694473</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>359.061493</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>253.355194</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>340.768982</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>280.906311</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>290.413940</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>277.995880</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>265.877655</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>253.081131</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>222.043137</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>357.857208</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>269.606750</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>287.222046</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>267.060791</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>237.360962</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>251.209946</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>262.666840</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>242.649490</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>295.797150</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>255.338135</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>244.248489</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>511.657104</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>253.844360</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>347.113708</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>317.887054</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>242.357712</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>320.567322</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>342.844421</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>245.601517</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>248.947235</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>287.577576</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>254.920654</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>233.068665</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>322.263855</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>248.122437</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>294.417694</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>244.711670</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>235.013214</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>242.286209</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>242.214615</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>475.643951</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>258.235992</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>222.230591</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>233.011887</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>256.352020</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>237.654694</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>227.338364</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>219.851700</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>277.093597</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>254.329330</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>328.794250</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>266.307800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>279.430054</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>237.552780</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>224.043106</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>226.592773</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1008.834534</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>263.600220</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>243.497299</td>
#     </
# 10 retain_cos_sim: 0.4171. rr_cos_sim: 0.4118
# {'logps/rejected': '-12', 'logps/chosen': '-12', 'loss': '8.3e+02', 'rewards/chosen': '-1.1', 'rewards/rejected': '-1.1', 'retain/loss': '8.2e+02', 'rr/loss': '8.3e+02', 'logratios/pi': '0.54', 'logratios/ref': '0.026', 'weighting': '0.2', 'logits': '0.51', 'component_rr/loss': '8.2e+02', 'component_retain/loss': '1.4', 'rr/c': '1', 'retain/c': '0.0035', 'retain_cosine': '0.42', 'rr_cosine': '0.41'}
# 20 retain_cos_sim: 0.2282. rr_cos_sim: 0.1736
# {'logps/rejected': '-15', 'logps/chosen': '-15', 'loss': '4.3e+02', 'rewards/chosen': '-1.3', 'rewards/rejected': '-1.3', 'retain/loss': '4.1e+02', 'rr/loss': '4.4e+02', 'logratios/pi': '-0.13', 'logratios/ref': '-0.19', 'weighting': '0.2', 'logits': '0.067', 'component_rr/loss': '4.3e+02', 'component_retain/loss': '1.4', 'rr/c': '0.99', 'retain/c': '0.0069', 'retain_cosine': '0.23', 'rr_cosine': '0.17'}
# 30 retain_cos_sim: 0.5604. rr_cos_sim: 0.5506
# {'logps/rejected': '-13', 'logps/chosen': '-13', 'loss': '3e+02', 'rewards/chosen': '-1.2', 'rewards/rejected': '-1.1', 'retain/loss': '3.8e+02', 'rr/loss': '3.1e+02', 'logratios/pi': '-0.39', 'logratios/ref': '0.74', 'weighting': '0.2', 'logits': '-1.1', 'component_rr/loss': '3e+02', 'component_retain/loss': '1.9', 'rr/c': '0.99', 'retain/c': '0.01', 'retain_cosine': '0.56', 'rr_cosine': '0.55'}
# 40 retain_cos_sim: 0.5830. rr_cos_sim: 0.5830
# {'logps/rejected': '-15', 'logps/chosen': '-15', 'loss': '2.6e+02', 'rewards/chosen': '-1.4', 'rewards/rejected': '-1.4', 'retain/loss': '2.5e+02', 'rr/loss': '2.6e+02', 'logratios/pi': '0.18', 'logratios/ref': '-0.036', 'weighting': '0.2', 'logits': '0.21', 'component_rr/loss': '2.6e+02', 'component_retain/loss': '1.7', 'rr/c': '0.99', 'retain/c': '0.014', 'retain_cosine': '0.58', 'rr_cosine': '0.58'}
# 50 retain_cos_sim: 0.3699. rr_cos_sim: 0.3698
# {'logps/rejected': '-10', 'logps/chosen': '-11', 'loss': '3.7e+02', 'rewards/chosen': '-0.91', 'rewards/rejected': '-0.88', 'retain/loss': '4e+02', 'rr/loss': '3.7e+02', 'logratios/pi': '-0.12', 'logratios/ref': '0.17', 'weighting': '0.2', 'logits': '-0.29', 'component_rr/loss': '3.6e+02', 'component_retain/loss': '3.5', 'rr/c': '0.98', 'retain/c': '0.017', 'retain_cosine': '0.37', 'rr_cosine': '0.37'}
# 60 retain_cos_sim: 0.6410. rr_cos_sim: 0.5999
# {'logps/rejected': '-14', 'logps/chosen': '-14', 'loss': '3.1e+02', 'rewards/chosen': '-1.3', 'rewards/rejected': '-1.3', 'retain/loss': '2.7e+02', 'rr/loss': '3.1e+02', 'logratios/pi': '0.11', 'logratios/ref': '-0.062', 'weighting': '0.2', 'logits': '0.17', 'component_rr/loss': '3.1e+02', 'component_retain/loss': '2.8', 'rr/c': '0.98', 'retain/c': '0.021', 'retain_cosine': '0.64', 'rr_cosine': '0.6'}
# 70 retain_cos_sim: 0.6107. rr_cos_sim: 0.6060
# {'logps/rejected': '-11', 'logps/chosen': '-10', 'loss': '2.5e+02', 'rewards/chosen': '-0.91', 'rewards/rejected': '-0.95', 'retain/loss': '2.4e+02', 'rr/loss': '2.6e+02', 'logratios/pi': '0.44', 'logratios/ref': '0.034', 'weighting': '0.2', 'logits': '0.4', 'component_rr/loss': '2.5e+02', 'component_retain/loss': '2.9', 'rr/c': '0.98', 'retain/c': '0.024', 'retain_cosine': '0.61', 'rr_cosine': '0.61'}
# 80 retain_cos_sim: 0.5792. rr_cos_sim: 0.5381
# {'logps/rejected': '-9.4', 'logps/chosen': '-9.1', 'loss': '3e+02', 'rewards/chosen': '-0.74', 'rewards/rejected': '-0.78', 'retain/loss': '2.9e+02', 'rr/loss': '3e+02', 'logratios/pi': '0.26', 'logratios/ref': '-0.13', 'weighting': '0.2', 'logits': '0.38', 'component_rr/loss': '2.9e+02', 'component_retain/loss': '4', 'rr/c': '0.97', 'retain/c': '0.028', 'retain_cosine': '0.58', 'rr_cosine': '0.54'}
# 90 retain_cos_sim: 0.4653. rr_cos_sim: 0.4529
# {'logps/rejected': '-10', 'logps/chosen': '-10', 'loss': '2.5e+02', 'rewards/chosen': '-0.82', 'rewards/rejected': '-0.8', 'retain/loss': '2.5e+02', 'rr/loss': '2.5e+02', 'logratios/pi': '-0.2', 'logratios/ref': '-0.025', 'weighting': '0.2', 'logits': '-0.18', 'component_rr/loss': '2.4e+02', 'component_retain/loss': '3.9', 'rr/c': '0.97', 'retain/c': '0.031', 'retain_cosine': '0.47', 'rr_cosine': '0.45'}
# 100 retain_cos_sim: 0.5064. rr_cos_sim: 0.4844
# {'logps/rejected': '-9.3', 'logps/chosen': '-9.2', 'loss': '2.4e+02', 'rewards/chosen': '-0.8', 'rewards/rejected': '-0.77', 'retain/loss': '2.4e+02', 'rr/loss': '2.5e+02', 'logratios/pi': '0.041', 'logratios/ref': '0.38', 'weighting': '0.2', 'logits': '-0.34', 'component_rr/loss': '2.4e+02', 'component_retain/loss': '4.2', 'rr/c': '0.97', 'retain/c': '0.035', 'retain_cosine': '0.51', 'rr_cosine': '0.48'}
# 110 retain_cos_sim: 0.2967. rr_cos_sim: 0.2548
# {'logps/rejected': '-13', 'logps/chosen': '-13', 'loss': '2.8e+02', 'rewards/chosen': '-1.2', 'rewards/rejected': '-1.1', 'retain/loss': '2.7e+02', 'rr/loss': '2.8e+02', 'logratios/pi': '-0.54', 'logratios/ref': '0.48', 'weighting': '0.2', 'logits': '-1', 'component_rr/loss': '2.7e+02', 'component_retain/loss': '5', 'rr/c': '0.96', 'retain/c': '0.038', 'retain_cosine': '0.3', 'rr_cosine': '0.25'}
# 120 retain_cos_sim: 0.3615. rr_cos_sim: 0.3615
# {'logps/rejected': '-13', 'logps/chosen': '-13', 'loss': '2.4e+02', 'rewards/chosen': '-1.1', 'rewards/rejected': '-1.2', 'retain/loss': '3.1e+02', 'rr/loss': '2.5e+02', 'logratios/pi': '0.29', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '0.18', 'component_rr/loss': '2.4e+02', 'component_retain/loss': '6.4', 'rr/c': '0.96', 'retain/c': '0.042', 'retain_cosine': '0.36', 'rr_cosine': '0.36'}
# 130 retain_cos_sim: 0.6956. rr_cos_sim: 0.5933
# {'logps/rejected': '-10', 'logps/chosen': '-10', 'loss': '2.6e+02', 'rewards/chosen': '-0.81', 'rewards/rejected': '-0.91', 'retain/loss': '2.2e+02', 'rr/loss': '2.6e+02', 'logratios/pi': '0.051', 'logratios/ref': '-0.98', 'weighting': '0.2', 'logits': '1', 'component_rr/loss': '2.5e+02', 'component_retain/loss': '4.9', 'rr/c': '0.96', 'retain/c': '0.045', 'retain_cosine': '0.7', 'rr_cosine': '0.59'}
# 140 retain_cos_sim: 0.6880. rr_cos_sim: 0.6583
# {'logps/rejected': '-9.9', 'logps/chosen': '-9.9', 'loss': '2.1e+02', 'rewards/chosen': '-0.85', 'rewards/rejected': '-0.86', 'retain/loss': '2.1e+02', 'rr/loss': '2.1e+02', 'logratios/pi': '0.035', 'logratios/ref': '0.0041', 'weighting': '0.2', 'logits': '0.031', 'component_rr/loss': '2e+02', 'component_retain/loss': '5.1', 'rr/c': '0.95', 'retain/c': '0.048', 'retain_cosine': '0.69', 'rr_cosine': '0.66'}
# 150 retain_cos_sim: 0.5283. rr_cos_sim: 0.5006
# {'logps/rejected': '-10', 'logps/chosen': '-11', 'loss': '2.5e+02', 'rewards/chosen': '-0.94', 'rewards/rejected': '-0.86', 'retain/loss': '2.2e+02', 'rr/loss': '2.6e+02', 'logratios/pi': '-0.55', 'logratios/ref': '0.32', 'weighting': '0.2', 'logits': '-0.87', 'component_rr/loss': '2.4e+02', 'component_retain/loss': '5.7', 'rr/c': '0.95', 'retain/c': '0.052', 'retain_cosine': '0.53', 'rr_cosine': '0.5'}
# 160 retain_cos_sim: 0.4549. rr_cos_sim: 0.4416
# {'logps/rejected': '-12', 'logps/chosen': '-12', 'loss': '2.6e+02', 'rewards/chosen': '-1.1', 'rewards/rejected': '-1.1', 'retain/loss': '2.8e+02', 'rr/loss': '2.6e+02', 'logratios/pi': '0.041', 'logratios/ref': '0.18', 'weighting': '0.2', 'logits': '-0.14', 'component_rr/loss': '2.5e+02', 'component_retain/loss': '7.8', 'rr/c': '0.94', 'retain/c': '0.055', 'retain_cosine': '0.45', 'rr_cosine': '0.44'}
# 170 retain_cos_sim: 0.6563. rr_cos_sim: 0.6284
# {'logps/rejected': '-9.1', 'logps/chosen': '-8.7', 'loss': '2.1e+02', 'rewards/chosen': '-0.75', 'rewards/rejected': '-0.74', 'retain/loss': '2.2e+02', 'rr/loss': '2.1e+02', 'logratios/pi': '0.42', 'logratios/ref': '0.53', 'weighting': '0.2', 'logits': '-0.11', 'component_rr/loss': '2e+02', 'component_retain/loss': '6.5', 'rr/c': '0.94', 'retain/c': '0.059', 'retain_cosine': '0.66', 'rr_cosine': '0.63'}
# 180 retain_cos_sim: 0.6913. rr_cos_sim: 0.6679
# {'logps/rejected': '-8.7', 'logps/chosen': '-8.9', 'loss': '1.9e+02', 'rewards/chosen': '-0.75', 'rewards/rejected': '-0.76', 'retain/loss': '1.9e+02', 'rr/loss': '1.9e+02', 'logratios/pi': '-0.14', 'logratios/ref': '-0.18', 'weighting': '0.2', 'logits': '0.048', 'component_rr/loss': '1.8e+02', 'component_retain/loss': '6', 'rr/c': '0.94', 'retain/c': '0.062', 'retain_cosine': '0.69', 'rr_cosine': '0.67'}
# 190 retain_cos_sim: 0.7201. rr_cos_sim: 0.6311
# {'logps/rejected': '-9.1', 'logps/chosen': '-9', 'loss': '2.3e+02', 'rewards/chosen': '-0.72', 'rewards/rejected': '-0.77', 'retain/loss': '2.2e+02', 'rr/loss': '2.4e+02', 'logratios/pi': '0.12', 'logratios/ref': '-0.39', 'weighting': '0.2', 'logits': '0.51', 'component_rr/loss': '2.2e+02', 'component_retain/loss': '7.2', 'rr/c': '0.93', 'retain/c': '0.066', 'retain_cosine': '0.72', 'rr_cosine': '0.63'}
# 200 retain_cos_sim: 0.6895. rr_cos_sim: 0.6680
# {'logps/rejected': '-8.7', 'logps/chosen': '-8.9', 'loss': '2.1e+02', 'rewards/chosen': '-0.75', 'rewards/rejected': '-0.76', 'retain/loss': '4.1e+02', 'rr/loss': '2.1e+02', 'logratios/pi': '-0.18', 'logratios/ref': '-0.29', 'weighting': '0.2', 'logits': '0.11', 'component_rr/loss': '2e+02', 'component_retain/loss': '14', 'rr/c': '0.93', 'retain/c': '0.069', 'retain_cosine': '0.69', 'rr_cosine': '0.67'}
# 210 retain_cos_sim: 0.6805. rr_cos_sim: 0.6789
# {'logps/rejected': '-9.2', 'logps/chosen': '-9.7', 'loss': '1.7e+02', 'rewards/chosen': '-0.84', 'rewards/rejected': '-0.8', 'retain/loss': '1.9e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '-0.49', 'logratios/ref': '-0.11', 'weighting': '0.2', 'logits': '-0.38', 'component_rr/loss': '1.6e+02', 'component_retain/loss': '6.8', 'rr/c': '0.93', 'retain/c': '0.073', 'retain_cosine': '0.68', 'rr_cosine': '0.68'}
# 220 retain_cos_sim: 0.6485. rr_cos_sim: 0.6306
# {'logps/rejected': '-9.1', 'logps/chosen': '-9', 'loss': '3.4e+02', 'rewards/chosen': '-0.72', 'rewards/rejected': '-0.74', 'retain/loss': '1.5e+02', 'rr/loss': '3.6e+02', 'logratios/pi': '0.18', 'logratios/ref': '-0.034', 'weighting': '0.2', 'logits': '0.21', 'component_rr/loss': '3.3e+02', 'component_retain/loss': '5.5', 'rr/c': '0.92', 'retain/c': '0.076', 'retain_cosine': '0.65', 'rr_cosine': '0.63'}
# 230 retain_cos_sim: 0.6489. rr_cos_sim: 0.6475
# {'logps/rejected': '-10', 'logps/chosen': '-9.6', 'loss': '1.7e+02', 'rewards/chosen': '-0.84', 'rewards/rejected': '-0.86', 'retain/loss': '1.7e+02', 'rr/loss': '1.8e+02', 'logratios/pi': '0.4', 'logratios/ref': '0.21', 'weighting': '0.2', 'logits': '0.2', 'component_rr/loss': '1.6e+02', 'component_retain/loss': '6.9', 'rr/c': '0.92', 'retain/c': '0.08', 'retain_cosine': '0.65', 'rr_cosine': '0.65'}
# 240 retain_cos_sim: 0.6921. rr_cos_sim: 0.6912
# {'logps/rejected': '-9.4', 'logps/chosen': '-9.2', 'loss': '1.4e+02', 'rewards/chosen': '-0.79', 'rewards/rejected': '-0.8', 'retain/loss': '1.7e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.2', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '0.087', 'component_rr/loss': '1.4e+02', 'component_retain/loss': '7', 'rr/c': '0.92', 'retain/c': '0.083', 'retain_cosine': '0.69', 'rr_cosine': '0.69'}
# 250 retain_cos_sim: 0.4875. rr_cos_sim: 0.4754
# {'logps/rejected': '-16', 'logps/chosen': '-16', 'loss': '2.4e+02', 'rewards/chosen': '-1.4', 'rewards/rejected': '-1.5', 'retain/loss': '2.9e+02', 'rr/loss': '2.5e+02', 'logratios/pi': '0.17', 'logratios/ref': '0.034', 'weighting': '0.2', 'logits': '0.14', 'component_rr/loss': '2.3e+02', 'component_retain/loss': '13', 'rr/c': '0.91', 'retain/c': '0.087', 'retain_cosine': '0.49', 'rr_cosine': '0.48'}
# 260 retain_cos_sim: 0.6514. rr_cos_sim: 0.6500
# {'logps/rejected': '-8.3', 'logps/chosen': '-8.4', 'loss': '1.5e+02', 'rewards/chosen': '-0.7', 'rewards/rejected': '-0.68', 'retain/loss': '1.6e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '-0.11', 'logratios/ref': '0.1', 'weighting': '0.2', 'logits': '-0.21', 'component_rr/loss': '1.4e+02', 'component_retain/loss': '7.3', 'rr/c': '0.91', 'retain/c': '0.09', 'retain_cosine': '0.65', 'rr_cosine': '0.65'}
# 270 retain_cos_sim: 0.5662. rr_cos_sim: 0.5425
# {'logps/rejected': '-10', 'logps/chosen': '-10', 'loss': '2e+02', 'rewards/chosen': '-0.85', 'rewards/rejected': '-0.85', 'retain/loss': '2.1e+02', 'rr/loss': '2.1e+02', 'logratios/pi': '0.01', 'logratios/ref': '-0.061', 'weighting': '0.2', 'logits': '0.071', 'component_rr/loss': '1.9e+02', 'component_retain/loss': '9.6', 'rr/c': '0.91', 'retain/c': '0.093', 'retain_cosine': '0.57', 'rr_cosine': '0.54'}
# 280 retain_cos_sim: 0.7561. rr_cos_sim: 0.7351
# {'logps/rejected': '-8.6', 'logps/chosen': '-8.3', 'loss': '1.6e+02', 'rewards/chosen': '-0.71', 'rewards/rejected': '-0.75', 'retain/loss': '1.3e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '0.32', 'logratios/ref': '-0.051', 'weighting': '0.2', 'logits': '0.37', 'component_rr/loss': '1.5e+02', 'component_retain/loss': '6.3', 'rr/c': '0.9', 'retain/c': '0.097', 'retain_cosine': '0.76', 'rr_cosine': '0.74'}
# 290 retain_cos_sim: 0.7521. rr_cos_sim: 0.7514
# {'logps/rejected': '-8.5', 'logps/chosen': '-8.4', 'loss': '1.4e+02', 'rewards/chosen': '-0.74', 'rewards/rejected': '-0.74', 'retain/loss': '1.5e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.14', 'logratios/ref': '0.17', 'weighting': '0.2', 'logits': '-0.032', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '7.6', 'rr/c': '0.9', 'retain/c': '0.1', 'retain_cosine': '0.75', 'rr_cosine': '0.75'}
# 300 retain_cos_sim: 0.7329. rr_cos_sim: 0.7317
# {'logps/rejected': '-9', 'logps/chosen': '-8.7', 'loss': '1.6e+02', 'rewards/chosen': '-0.74', 'rewards/rejected': '-0.75', 'retain/loss': '1.3e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '0.29', 'logratios/ref': '0.2', 'weighting': '0.2', 'logits': '0.095', 'component_rr/loss': '1.5e+02', 'component_retain/loss': '6.6', 'rr/c': '0.9', 'retain/c': '0.1', 'retain_cosine': '0.73', 'rr_cosine': '0.73'}
# 310 retain_cos_sim: 0.7182. rr_cos_sim: 0.7173
# {'logps/rejected': '-8.4', 'logps/chosen': '-8.4', 'loss': '1.3e+02', 'rewards/chosen': '-0.71', 'rewards/rejected': '-0.67', 'retain/loss': '1.6e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.029', 'logratios/ref': '0.33', 'weighting': '0.2', 'logits': '-0.36', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '8.5', 'rr/c': '0.89', 'retain/c': '0.11', 'retain_cosine': '0.72', 'rr_cosine': '0.72'}
# 320 retain_cos_sim: 0.6783. rr_cos_sim: 0.6769
# {'logps/rejected': '-8.7', 'logps/chosen': '-8.7', 'loss': '1.6e+02', 'rewards/chosen': '-0.73', 'rewards/rejected': '-0.73', 'retain/loss': '1.3e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '0.0031', 'logratios/ref': '-0.0059', 'weighting': '0.2', 'logits': '0.009', 'component_rr/loss': '1.5e+02', 'component_retain/loss': '7.5', 'rr/c': '0.89', 'retain/c': '0.11', 'retain_cosine': '0.68', 'rr_cosine': '0.68'}
# 330 retain_cos_sim: 0.8105. rr_cos_sim: 0.8092
# {'logps/rejected': '-8', 'logps/chosen': '-7.8', 'loss': '1.2e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.7', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.16', 'logratios/ref': '0.089', 'weighting': '0.2', 'logits': '0.075', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '7.5', 'rr/c': '0.89', 'retain/c': '0.11', 'retain_cosine': '0.81', 'rr_cosine': '0.81'}
# 340 retain_cos_sim: 0.7467. rr_cos_sim: 0.7454
# {'logps/rejected': '-8.1', 'logps/chosen': '-7.9', 'loss': '1.3e+02', 'rewards/chosen': '-0.66', 'rewards/rejected': '-0.69', 'retain/loss': '2.1e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.11', 'logratios/ref': '-0.14', 'weighting': '0.2', 'logits': '0.25', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '12', 'rr/c': '0.88', 'retain/c': '0.12', 'retain_cosine': '0.75', 'rr_cosine': '0.75'}
# 350 retain_cos_sim: 0.7596. rr_cos_sim: 0.7215
# {'logps/rejected': '-8.2', 'logps/chosen': '-7.9', 'loss': '1.2e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.71', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.3', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '0.19', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '8', 'rr/c': '0.88', 'retain/c': '0.12', 'retain_cosine': '0.76', 'rr_cosine': '0.72'}
# 360 retain_cos_sim: 0.6886. rr_cos_sim: 0.6874
# {'logps/rejected': '-9.7', 'logps/chosen': '-8.8', 'loss': '1.4e+02', 'rewards/chosen': '-0.77', 'rewards/rejected': '-0.85', 'retain/loss': '1.4e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.92', 'logratios/ref': '0.086', 'weighting': '0.2', 'logits': '0.83', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '8.8', 'rr/c': '0.88', 'retain/c': '0.12', 'retain_cosine': '0.69', 'rr_cosine': '0.69'}
# 370 retain_cos_sim: 0.7425. rr_cos_sim: 0.6754
# {'logps/rejected': '-9.4', 'logps/chosen': '-8.7', 'loss': '1.7e+02', 'rewards/chosen': '-0.75', 'rewards/rejected': '-0.62', 'retain/loss': '1.3e+02', 'rr/loss': '1.8e+02', 'logratios/pi': '0.71', 'logratios/ref': '2', 'weighting': '0.2', 'logits': '-1.3', 'component_rr/loss': '1.6e+02', 'component_retain/loss': '8.1', 'rr/c': '0.87', 'retain/c': '0.13', 'retain_cosine': '0.74', 'rr_cosine': '0.68'}
# 380 retain_cos_sim: 0.7951. rr_cos_sim: 0.7802
# {'logps/rejected': '-8.2', 'logps/chosen': '-8.1', 'loss': '1.3e+02', 'rewards/chosen': '-0.71', 'rewards/rejected': '-0.71', 'retain/loss': '1.3e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.11', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '-0.0032', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '8.4', 'rr/c': '0.87', 'retain/c': '0.13', 'retain_cosine': '0.8', 'rr_cosine': '0.78'}
# 390 retain_cos_sim: 0.7300. rr_cos_sim: 0.6578
# {'logps/rejected': '-7.4', 'logps/chosen': '-7.8', 'loss': '1.2e+02', 'rewards/chosen': '-0.66', 'rewards/rejected': '-0.56', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.4', 'logratios/ref': '0.6', 'weighting': '0.2', 'logits': '-1', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '8.6', 'rr/c': '0.87', 'retain/c': '0.13', 'retain_cosine': '0.73', 'rr_cosine': '0.66'}
# 400 retain_cos_sim: 0.7706. rr_cos_sim: 0.7147
# {'logps/rejected': '-9', 'logps/chosen': '-8.8', 'loss': '1.4e+02', 'rewards/chosen': '-0.74', 'rewards/rejected': '-0.74', 'retain/loss': '1.5e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '0.18', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '0.074', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '10', 'rr/c': '0.86', 'retain/c': '0.14', 'retain_cosine': '0.77', 'rr_cosine': '0.71'}
# 410 retain_cos_sim: 0.7814. rr_cos_sim: 0.7594
# {'logps/rejected': '-7.8', 'logps/chosen': '-7.9', 'loss': '1.7e+02', 'rewards/chosen': '-0.65', 'rewards/rejected': '-0.67', 'retain/loss': '1.3e+02', 'rr/loss': '1.9e+02', 'logratios/pi': '-0.18', 'logratios/ref': '-0.41', 'weighting': '0.2', 'logits': '0.23', 'component_rr/loss': '1.6e+02', 'component_retain/loss': '9', 'rr/c': '0.86', 'retain/c': '0.14', 'retain_cosine': '0.78', 'rr_cosine': '0.76'}
# 420 retain_cos_sim: 0.7831. rr_cos_sim: 0.7579
# {'logps/rejected': '-8.7', 'logps/chosen': '-8.2', 'loss': '1.4e+02', 'rewards/chosen': '-0.7', 'rewards/rejected': '-0.77', 'retain/loss': '1.2e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.53', 'logratios/ref': '-0.077', 'weighting': '0.2', 'logits': '0.6', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '9', 'rr/c': '0.85', 'retain/c': '0.15', 'retain_cosine': '0.78', 'rr_cosine': '0.76'}
# 430 retain_cos_sim: 0.8161. rr_cos_sim: 0.8132
# {'logps/rejected': '-8.2', 'logps/chosen': '-7.7', 'loss': '1.2e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.68', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.47', 'logratios/ref': '0.44', 'weighting': '0.2', 'logits': '0.031', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '9.1', 'rr/c': '0.85', 'retain/c': '0.15', 'retain_cosine': '0.82', 'rr_cosine': '0.81'}
# 440 retain_cos_sim: 0.7470. rr_cos_sim: 0.7447
# {'logps/rejected': '-8.1', 'logps/chosen': '-8.1', 'loss': '1.2e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.68', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.0069', 'logratios/ref': '-0.11', 'weighting': '0.2', 'logits': '0.12', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '9.4', 'rr/c': '0.85', 'retain/c': '0.15', 'retain_cosine': '0.75', 'rr_cosine': '0.74'}
# 450 retain_cos_sim: 0.7694. rr_cos_sim: 0.7514
# {'logps/rejected': '-7.8', 'logps/chosen': '-8.3', 'loss': '1.3e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.63', 'retain/loss': '1.9e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.5', 'logratios/ref': '-0.047', 'weighting': '0.2', 'logits': '-0.46', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '15', 'rr/c': '0.84', 'retain/c': '0.16', 'retain_cosine': '0.77', 'rr_cosine': '0.75'}
# 460 retain_cos_sim: 0.7298. rr_cos_sim: 0.7274
# {'logps/rejected': '-7.9', 'logps/chosen': '-8', 'loss': '1.3e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.65', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.18', 'logratios/ref': '-0.026', 'weighting': '0.2', 'logits': '-0.15', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '9.8', 'rr/c': '0.84', 'retain/c': '0.16', 'retain_cosine': '0.73', 'rr_cosine': '0.73'}
# 470 retain_cos_sim: 0.7748. rr_cos_sim: 0.7721
# {'logps/rejected': '-8', 'logps/chosen': '-8', 'loss': '1.3e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.69', 'retain/loss': '1.3e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.045', 'logratios/ref': '0.0087', 'weighting': '0.2', 'logits': '-0.054', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '10', 'rr/c': '0.84', 'retain/c': '0.16', 'retain_cosine': '0.77', 'rr_cosine': '0.77'}
# 480 retain_cos_sim: 0.7463. rr_cos_sim: 0.7439
# {'logps/rejected': '-7.9', 'logps/chosen': '-8', 'loss': '1.2e+02', 'rewards/chosen': '-0.68', 'rewards/rejected': '-0.68', 'retain/loss': '1.3e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.024', 'logratios/ref': '-0.046', 'weighting': '0.2', 'logits': '0.023', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '11', 'rr/c': '0.83', 'retain/c': '0.17', 'retain_cosine': '0.75', 'rr_cosine': '0.74'}
# 490 retain_cos_sim: 0.7968. rr_cos_sim: 0.6940
# {'logps/rejected': '-7.5', 'logps/chosen': '-7.7', 'loss': '1.7e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.6', 'retain/loss': '1.2e+02', 'rr/loss': '2e+02', 'logratios/pi': '-0.22', 'logratios/ref': '-0.12', 'weighting': '0.2', 'logits': '-0.11', 'component_rr/loss': '1.6e+02', 'component_retain/loss': '10', 'rr/c': '0.83', 'retain/c': '0.17', 'retain_cosine': '0.8', 'rr_cosine': '0.69'}
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# 500 retain_cos_sim: 0.7900. rr_cos_sim: 0.7880
# {'logps/rejected': '-8', 'logps/chosen': '-7.9', 'loss': '1.1e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.69', 'retain/loss': '1.6e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.05', 'logratios/ref': '-0.079', 'weighting': '0.2', 'logits': '0.13', 'component_rr/loss': '1e+02', 'component_retain/loss': '13', 'rr/c': '0.83', 'retain/c': '0.17', 'retain_cosine': '0.79', 'rr_cosine': '0.79'}
# 510 retain_cos_sim: 0.7878. rr_cos_sim: 0.7444
# {'logps/rejected': '-8', 'logps/chosen': '-8.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.65', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.056', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '-0.16', 'component_rr/loss': '1e+02', 'component_retain/loss': '10', 'rr/c': '0.82', 'retain/c': '0.18', 'retain_cosine': '0.79', 'rr_cosine': '0.74'}
# 520 retain_cos_sim: 0.7432. rr_cos_sim: 0.7409
# {'logps/rejected': '-8', 'logps/chosen': '-8', 'loss': '1.3e+02', 'rewards/chosen': '-0.63', 'rewards/rejected': '-0.64', 'retain/loss': '1.2e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.012', 'logratios/ref': '-0.14', 'weighting': '0.2', 'logits': '0.15', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '11', 'rr/c': '0.82', 'retain/c': '0.18', 'retain_cosine': '0.74', 'rr_cosine': '0.74'}
# 530 retain_cos_sim: 0.7415. rr_cos_sim: 0.7353
# {'logps/rejected': '-8.1', 'logps/chosen': '-7.9', 'loss': '1.4e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.69', 'retain/loss': '1.4e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.15', 'logratios/ref': '0.096', 'weighting': '0.2', 'logits': '0.054', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '13', 'rr/c': '0.82', 'retain/c': '0.18', 'retain_cosine': '0.74', 'rr_cosine': '0.74'}
# 540 retain_cos_sim: 0.8062. rr_cos_sim: 0.7917
# {'logps/rejected': '-8.4', 'logps/chosen': '-8.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.72', 'rewards/rejected': '-0.73', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.25', 'logratios/ref': '0.084', 'weighting': '0.2', 'logits': '0.17', 'component_rr/loss': '1e+02', 'component_retain/loss': '11', 'rr/c': '0.81', 'retain/c': '0.19', 'retain_cosine': '0.81', 'rr_cosine': '0.79'}
# 550 retain_cos_sim: 0.7791. rr_cos_sim: 0.7715
# {'logps/rejected': '-8.2', 'logps/chosen': '-8.5', 'loss': '1.3e+02', 'rewards/chosen': '-0.74', 'rewards/rejected': '-0.71', 'retain/loss': '1.2e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '-0.3', 'logratios/ref': '-0.022', 'weighting': '0.2', 'logits': '-0.28', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '12', 'rr/c': '0.81', 'retain/c': '0.19', 'retain_cosine': '0.78', 'rr_cosine': '0.77'}
# 560 retain_cos_sim: 0.7587. rr_cos_sim: 0.7562
# {'logps/rejected': '-8', 'logps/chosen': '-8', 'loss': '1.1e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.65', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.026', 'logratios/ref': '0.19', 'weighting': '0.2', 'logits': '-0.22', 'component_rr/loss': '1e+02', 'component_retain/loss': '12', 'rr/c': '0.81', 'retain/c': '0.19', 'retain_cosine': '0.76', 'rr_cosine': '0.76'}
# 570 retain_cos_sim: 0.7597. rr_cos_sim: 0.7573
# {'logps/rejected': '-8.1', 'logps/chosen': '-8', 'loss': '1.1e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.7', 'retain/loss': '1.6e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.032', 'logratios/ref': '-0.082', 'weighting': '0.2', 'logits': '0.11', 'component_rr/loss': '98', 'component_retain/loss': '15', 'rr/c': '0.8', 'retain/c': '0.2', 'retain_cosine': '0.76', 'rr_cosine': '0.76'}
# 580 retain_cos_sim: 0.7889. rr_cos_sim: 0.7444
# {'logps/rejected': '-8.6', 'logps/chosen': '-7.9', 'loss': '1.1e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.71', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.7', 'logratios/ref': '0.35', 'weighting': '0.2', 'logits': '0.35', 'component_rr/loss': '1e+02', 'component_retain/loss': '13', 'rr/c': '0.8', 'retain/c': '0.2', 'retain_cosine': '0.79', 'rr_cosine': '0.74'}
# 590 retain_cos_sim: 0.7977. rr_cos_sim: 0.7054
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.9', 'loss': '1.1e+02', 'rewards/chosen': '-0.68', 'rewards/rejected': '-0.55', 'retain/loss': '1.3e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.27', 'logratios/ref': '1', 'weighting': '0.2', 'logits': '-1.3', 'component_rr/loss': '99', 'component_retain/loss': '13', 'rr/c': '0.8', 'retain/c': '0.2', 'retain_cosine': '0.8', 'rr_cosine': '0.71'}
# 600 retain_cos_sim: 0.8036. rr_cos_sim: 0.7567
# {'logps/rejected': '-7.9', 'logps/chosen': '-8.4', 'loss': '1.6e+02', 'rewards/chosen': '-0.65', 'rewards/rejected': '-0.65', 'retain/loss': '3.6e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '-0.52', 'logratios/ref': '-0.53', 'weighting': '0.2', 'logits': '0.017', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '37', 'rr/c': '0.79', 'retain/c': '0.21', 'retain_cosine': '0.8', 'rr_cosine': '0.76'}
# 610 retain_cos_sim: 0.7737. rr_cos_sim: 0.7697
# {'logps/rejected': '-8.2', 'logps/chosen': '-8', 'loss': '1.1e+02', 'rewards/chosen': '-0.71', 'rewards/rejected': '-0.74', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.15', 'logratios/ref': '-0.17', 'weighting': '0.2', 'logits': '0.32', 'component_rr/loss': '95', 'component_retain/loss': '13', 'rr/c': '0.79', 'retain/c': '0.21', 'retain_cosine': '0.77', 'rr_cosine': '0.77'}
# 620 retain_cos_sim: 0.7285. rr_cos_sim: 0.6782
# {'logps/rejected': '-8.5', 'logps/chosen': '-8.4', 'loss': '1.2e+02', 'rewards/chosen': '-0.7', 'rewards/rejected': '-0.63', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.028', 'logratios/ref': '0.75', 'weighting': '0.2', 'logits': '-0.72', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '13', 'rr/c': '0.79', 'retain/c': '0.21', 'retain_cosine': '0.73', 'rr_cosine': '0.68'}
# 630 retain_cos_sim: 0.7426. rr_cos_sim: 0.7150
# {'logps/rejected': '-7.7', 'logps/chosen': '-8', 'loss': '1.4e+02', 'rewards/chosen': '-0.64', 'rewards/rejected': '-0.59', 'retain/loss': '1.2e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '-0.38', 'logratios/ref': '0.1', 'weighting': '0.2', 'logits': '-0.48', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '13', 'rr/c': '0.78', 'retain/c': '0.22', 'retain_cosine': '0.74', 'rr_cosine': '0.72'}
# 640 retain_cos_sim: 0.8076. rr_cos_sim: 0.8014
# {'logps/rejected': '-7.9', 'logps/chosen': '-7.7', 'loss': '1.2e+02', 'rewards/chosen': '-0.64', 'rewards/rejected': '-0.69', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.2', 'logratios/ref': '-0.28', 'weighting': '0.2', 'logits': '0.48', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '13', 'rr/c': '0.78', 'retain/c': '0.22', 'retain_cosine': '0.81', 'rr_cosine': '0.8'}
# 650 retain_cos_sim: 0.7309. rr_cos_sim: 0.7263
# {'logps/rejected': '-6.8', 'logps/chosen': '-6.8', 'loss': '1.1e+02', 'rewards/chosen': '-0.57', 'rewards/rejected': '-0.55', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.011', 'logratios/ref': '0.2', 'weighting': '0.2', 'logits': '-0.21', 'component_rr/loss': '96', 'component_retain/loss': '14', 'rr/c': '0.78', 'retain/c': '0.22', 'retain_cosine': '0.73', 'rr_cosine': '0.73'}
# 660 retain_cos_sim: 0.7592. rr_cos_sim: 0.7027
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.8', 'loss': '1.2e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.63', 'retain/loss': '2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.18', 'logratios/ref': '-0.38', 'weighting': '0.2', 'logits': '0.21', 'component_rr/loss': '96', 'component_retain/loss': '23', 'rr/c': '0.77', 'retain/c': '0.23', 'retain_cosine': '0.76', 'rr_cosine': '0.7'}
# 670 retain_cos_sim: 0.7603. rr_cos_sim: 0.7564
# {'logps/rejected': '-8.1', 'logps/chosen': '-8.1', 'loss': '1.2e+02', 'rewards/chosen': '-0.71', 'rewards/rejected': '-0.71', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.016', 'logratios/ref': '-0.0028', 'weighting': '0.2', 'logits': '0.019', 'component_rr/loss': '1e+02', 'component_retain/loss': '15', 'rr/c': '0.77', 'retain/c': '0.23', 'retain_cosine': '0.76', 'rr_cosine': '0.76'}
# 680 retain_cos_sim: 0.7601. rr_cos_sim: 0.7544
# {'logps/rejected': '-7.7', 'logps/chosen': '-8.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.66', 'rewards/rejected': '-0.62', 'retain/loss': '1.1e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.4', 'logratios/ref': '0.027', 'weighting': '0.2', 'logits': '-0.43', 'component_rr/loss': '95', 'component_retain/loss': '13', 'rr/c': '0.76', 'retain/c': '0.24', 'retain_cosine': '0.76', 'rr_cosine': '0.75'}
# 690 retain_cos_sim: 0.7362. rr_cos_sim: 0.7329
# {'logps/rejected': '-8.1', 'logps/chosen': '-7.7', 'loss': '1.3e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.7', 'retain/loss': '1.8e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.41', 'logratios/ref': '0.13', 'weighting': '0.2', 'logits': '0.28', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '21', 'rr/c': '0.76', 'retain/c': '0.24', 'retain_cosine': '0.74', 'rr_cosine': '0.73'}
# 700 retain_cos_sim: 0.7360. rr_cos_sim: 0.7000
# {'logps/rejected': '-8.3', 'logps/chosen': '-8.3', 'loss': '1.2e+02', 'rewards/chosen': '-0.67', 'rewards/rejected': '-0.67', 'retain/loss': '1.5e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.025', 'logratios/ref': '-0.094', 'weighting': '0.2', 'logits': '0.069', 'component_rr/loss': '1e+02', 'component_retain/loss': '18', 'rr/c': '0.76', 'retain/c': '0.24', 'retain_cosine': '0.74', 'rr_cosine': '0.7'}
# 710 retain_cos_sim: 0.7970. rr_cos_sim: 0.7418
# {'logps/rejected': '-9', 'logps/chosen': '-8.6', 'loss': '1.1e+02', 'rewards/chosen': '-0.76', 'rewards/rejected': '-0.66', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.43', 'logratios/ref': '1.4', 'weighting': '0.2', 'logits': '-0.98', 'component_rr/loss': '94', 'component_retain/loss': '15', 'rr/c': '0.75', 'retain/c': '0.25', 'retain_cosine': '0.8', 'rr_cosine': '0.74'}
# 720 retain_cos_sim: 0.7694. rr_cos_sim: 0.7267
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.2', 'loss': '1.2e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.62', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.4', 'logratios/ref': '0.24', 'weighting': '0.2', 'logits': '0.16', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '15', 'rr/c': '0.75', 'retain/c': '0.25', 'retain_cosine': '0.77', 'rr_cosine': '0.73'}
# 730 retain_cos_sim: 0.7962. rr_cos_sim: 0.7835
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.3', 'loss': '1.1e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.62', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.24', 'logratios/ref': '0.075', 'weighting': '0.2', 'logits': '0.16', 'component_rr/loss': '1e+02', 'component_retain/loss': '15', 'rr/c': '0.75', 'retain/c': '0.25', 'retain_cosine': '0.8', 'rr_cosine': '0.78'}
# 740 retain_cos_sim: 0.8046. rr_cos_sim: 0.7986
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.7', 'loss': '1.1e+02', 'rewards/chosen': '-0.68', 'rewards/rejected': '-0.66', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.15', 'logratios/ref': '-0.0043', 'weighting': '0.2', 'logits': '-0.14', 'component_rr/loss': '95', 'component_retain/loss': '16', 'rr/c': '0.74', 'retain/c': '0.26', 'retain_cosine': '0.8', 'rr_cosine': '0.8'}
# 750 retain_cos_sim: 0.7752. rr_cos_sim: 0.7473
# {'logps/rejected': '-7.7', 'logps/chosen': '-7.5', 'loss': '1.4e+02', 'rewards/chosen': '-0.64', 'rewards/rejected': '-0.65', 'retain/loss': '1.2e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '0.23', 'logratios/ref': '0.063', 'weighting': '0.2', 'logits': '0.16', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '16', 'rr/c': '0.74', 'retain/c': '0.26', 'retain_cosine': '0.78', 'rr_cosine': '0.75'}
# 760 retain_cos_sim: 0.7815. rr_cos_sim: 0.7769
# {'logps/rejected': '-8.4', 'logps/chosen': '-8.3', 'loss': '1.1e+02', 'rewards/chosen': '-0.7', 'rewards/rejected': '-0.75', 'retain/loss': '1.8e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.0072', 'logratios/ref': '-0.46', 'weighting': '0.2', 'logits': '0.47', 'component_rr/loss': '91', 'component_retain/loss': '24', 'rr/c': '0.74', 'retain/c': '0.26', 'retain_cosine': '0.78', 'rr_cosine': '0.78'}
# 770 retain_cos_sim: 0.7647. rr_cos_sim: 0.7302
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.5', 'loss': '1.1e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.59', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.14', 'logratios/ref': '0.34', 'weighting': '0.2', 'logits': '-0.19', 'component_rr/loss': '92', 'component_retain/loss': '16', 'rr/c': '0.73', 'retain/c': '0.27', 'retain_cosine': '0.76', 'rr_cosine': '0.73'}
# 780 retain_cos_sim: 0.7893. rr_cos_sim: 0.7824
# {'logps/rejected': '-7.9', 'logps/chosen': '-8.3', 'loss': '1.2e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.66', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.42', 'logratios/ref': '-0.11', 'weighting': '0.2', 'logits': '-0.3', 'component_rr/loss': '1e+02', 'component_retain/loss': '16', 'rr/c': '0.73', 'retain/c': '0.27', 'retain_cosine': '0.79', 'rr_cosine': '0.78'}
# 790 retain_cos_sim: 0.7846. rr_cos_sim: 0.7480
# {'logps/rejected': '-6.9', 'logps/chosen': '-7.3', 'loss': '1.3e+02', 'rewards/chosen': '-0.59', 'rewards/rejected': '-0.55', 'retain/loss': '1.3e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '-0.34', 'logratios/ref': '0.068', 'weighting': '0.2', 'logits': '-0.41', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '17', 'rr/c': '0.73', 'retain/c': '0.27', 'retain_cosine': '0.78', 'rr_cosine': '0.75'}
# 800 retain_cos_sim: 0.7608. rr_cos_sim: 0.7547
# {'logps/rejected': '-8.1', 'logps/chosen': '-8.4', 'loss': '1.2e+02', 'rewards/chosen': '-0.69', 'rewards/rejected': '-0.67', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.27', 'logratios/ref': '-0.068', 'weighting': '0.2', 'logits': '-0.2', 'component_rr/loss': '1e+02', 'component_retain/loss': '17', 'rr/c': '0.72', 'retain/c': '0.28', 'retain_cosine': '0.76', 'rr_cosine': '0.75'}
# 810 retain_cos_sim: 0.7639. rr_cos_sim: 0.7132
# {'logps/rejected': '-7.5', 'logps/chosen': '-7.6', 'loss': '1.4e+02', 'rewards/chosen': '-0.63', 'rewards/rejected': '-0.63', 'retain/loss': '1.5e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '-0.08', 'logratios/ref': '-0.12', 'weighting': '0.2', 'logits': '0.037', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '21', 'rr/c': '0.72', 'retain/c': '0.28', 'retain_cosine': '0.76', 'rr_cosine': '0.71'}
# 820 retain_cos_sim: 0.7672. rr_cos_sim: 0.7448
# {'logps/rejected': '-7.2', 'logps/chosen': '-7.5', 'loss': '1.1e+02', 'rewards/chosen': '-0.66', 'rewards/rejected': '-0.58', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.36', 'logratios/ref': '0.37', 'weighting': '0.2', 'logits': '-0.74', 'component_rr/loss': '95', 'component_retain/loss': '18', 'rr/c': '0.72', 'retain/c': '0.28', 'retain_cosine': '0.77', 'rr_cosine': '0.74'}
# 830 retain_cos_sim: 0.7936. rr_cos_sim: 0.7870
# {'logps/rejected': '-8.3', 'logps/chosen': '-8.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.7', 'rewards/rejected': '-0.71', 'retain/loss': '1.3e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.18', 'logratios/ref': '0.13', 'weighting': '0.2', 'logits': '0.045', 'component_rr/loss': '88', 'component_retain/loss': '19', 'rr/c': '0.71', 'retain/c': '0.29', 'retain_cosine': '0.79', 'rr_cosine': '0.79'}
# 840 retain_cos_sim: 0.7266. rr_cos_sim: 0.7161
# {'logps/rejected': '-7.9', 'logps/chosen': '-7.9', 'loss': '1.2e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.64', 'retain/loss': '1.6e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.0037', 'logratios/ref': '-0.3', 'weighting': '0.2', 'logits': '0.3', 'component_rr/loss': '94', 'component_retain/loss': '23', 'rr/c': '0.71', 'retain/c': '0.29', 'retain_cosine': '0.73', 'rr_cosine': '0.72'}
# 850 retain_cos_sim: 0.7764. rr_cos_sim: 0.7670
# ...
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# 1000 retain_cos_sim: 0.7585. rr_cos_sim: 0.7473
# {'logps/rejected': '-7.1', 'logps/chosen': '-7.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.58', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.061', 'logratios/ref': '0.29', 'weighting': '0.2', 'logits': '-0.35', 'component_rr/loss': '90', 'component_retain/loss': '21', 'rr/c': '0.65', 'retain/c': '0.35', 'retain_cosine': '0.76', 'rr_cosine': '0.75'}
# 1010 retain_cos_sim: 0.7577. rr_cos_sim: 0.7151
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.7', 'loss': '1e+02', 'rewards/chosen': '-0.54', 'rewards/rejected': '-0.55', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.0033', 'logratios/ref': '-0.11', 'weighting': '0.2', 'logits': '0.1', 'component_rr/loss': '80', 'component_retain/loss': '21', 'rr/c': '0.65', 'retain/c': '0.35', 'retain_cosine': '0.76', 'rr_cosine': '0.72'}
# 1020 retain_cos_sim: 0.7947. rr_cos_sim: 0.7473
# {'logps/rejected': '-6.1', 'logps/chosen': '-6.3', 'loss': '1e+02', 'rewards/chosen': '-0.51', 'rewards/rejected': '-0.45', 'retain/loss': '1.1e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.2', 'logratios/ref': '0.42', 'weighting': '0.2', 'logits': '-0.63', 'component_rr/loss': '83', 'component_retain/loss': '20', 'rr/c': '0.65', 'retain/c': '0.35', 'retain_cosine': '0.79', 'rr_cosine': '0.75'}
# 1030 retain_cos_sim: 0.7826. rr_cos_sim: 0.7693
# {'logps/rejected': '-6.9', 'logps/chosen': '-6.8', 'loss': '1.1e+02', 'rewards/chosen': '-0.57', 'rewards/rejected': '-0.55', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.068', 'logratios/ref': '0.22', 'weighting': '0.2', 'logits': '-0.15', 'component_rr/loss': '91', 'component_retain/loss': '22', 'rr/c': '0.64', 'retain/c': '0.36', 'retain_cosine': '0.78', 'rr_cosine': '0.77'}
# 1040 retain_cos_sim: 0.7349. rr_cos_sim: 0.6496
# {'logps/rejected': '-7', 'logps/chosen': '-7.2', 'loss': '1.2e+02', 'rewards/chosen': '-0.61', 'rewards/rejected': '-0.53', 'retain/loss': '1.2e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '-0.22', 'logratios/ref': '0.54', 'weighting': '0.2', 'logits': '-0.76', 'component_rr/loss': '98', 'component_retain/loss': '21', 'rr/c': '0.64', 'retain/c': '0.36', 'retain_cosine': '0.73', 'rr_cosine': '0.65'}
# 1050 retain_cos_sim: 0.8242. rr_cos_sim: 0.7459
# {'logps/rejected': '-7.3', 'logps/chosen': '-7.8', 'loss': '1.5e+02', 'rewards/chosen': '-0.46', 'rewards/rejected': '-0.62', 'retain/loss': '1.2e+02', 'rr/loss': '2e+02', 'logratios/pi': '-0.51', 'logratios/ref': '-2.1', 'weighting': '0.2', 'logits': '1.6', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '22', 'rr/c': '0.64', 'retain/c': '0.36', 'retain_cosine': '0.82', 'rr_cosine': '0.75'}
# 1060 retain_cos_sim: 0.8104. rr_cos_sim: 0.7551
# {'logps/rejected': '-5.8', 'logps/chosen': '-5.9', 'loss': '97', 'rewards/chosen': '-0.46', 'rewards/rejected': '-0.44', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.12', 'logratios/ref': '0.08', 'weighting': '0.2', 'logits': '-0.2', 'component_rr/loss': '75', 'component_retain/loss': '22', 'rr/c': '0.63', 'retain/c': '0.37', 'retain_cosine': '0.81', 'rr_cosine': '0.76'}
# 1070 retain_cos_sim: 0.8336. rr_cos_sim: 0.8228
# {'logps/rejected': '-7.3', 'logps/chosen': '-7', 'loss': '1e+02', 'rewards/chosen': '-0.58', 'rewards/rejected': '-0.6', 'retain/loss': '1.3e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.29', 'logratios/ref': '0.052', 'weighting': '0.2', 'logits': '0.23', 'component_rr/loss': '77', 'component_retain/loss': '24', 'rr/c': '0.63', 'retain/c': '0.37', 'retain_cosine': '0.83', 'rr_cosine': '0.82'}
# 1080 retain_cos_sim: 0.7951. rr_cos_sim: 0.7514
# {'logps/rejected': '-6.9', 'logps/chosen': '-7', 'loss': '1e+02', 'rewards/chosen': '-0.58', 'rewards/rejected': '-0.58', 'retain/loss': '1.3e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.11', 'logratios/ref': '-0.08', 'weighting': '0.2', 'logits': '-0.034', 'component_rr/loss': '78', 'component_retain/loss': '23', 'rr/c': '0.63', 'retain/c': '0.37', 'retain_cosine': '0.8', 'rr_cosine': '0.75'}
# 1090 retain_cos_sim: 0.8142. rr_cos_sim: 0.8012
# {'logps/rejected': '-7', 'logps/chosen': '-7.2', 'loss': '1e+02', 'rewards/chosen': '-0.58', 'rewards/rejected': '-0.57', 'retain/loss': '1.7e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.23', 'logratios/ref': '-0.031', 'weighting': '0.2', 'logits': '-0.2', 'component_rr/loss': '73', 'component_retain/loss': '31', 'rr/c': '0.62', 'retain/c': '0.38', 'retain_cosine': '0.81', 'rr_cosine': '0.8'}
# 1100 retain_cos_sim: 0.7568. rr_cos_sim: 0.7449
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.8', 'loss': '98', 'rewards/chosen': '-0.59', 'rewards/rejected': '-0.59', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.099', 'logratios/ref': '-0.19', 'weighting': '0.2', 'logits': '0.089', 'component_rr/loss': '75', 'component_retain/loss': '23', 'rr/c': '0.62', 'retain/c': '0.38', 'retain_cosine': '0.76', 'rr_cosine': '0.74'}
# 1110 retain_cos_sim: 0.7568. rr_cos_sim: 0.7043
# {'logps/rejected': '-7.3', 'logps/chosen': '-7.3', 'loss': '1e+02', 'rewards/chosen': '-0.57', 'rewards/rejected': '-0.58', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.084', 'logratios/ref': '-0.19', 'weighting': '0.2', 'logits': '0.11', 'component_rr/loss': '81', 'component_retain/loss': '22', 'rr/c': '0.62', 'retain/c': '0.38', 'retain_cosine': '0.76', 'rr_cosine': '0.7'}
# 1120 retain_cos_sim: 0.7822. rr_cos_sim: 0.7440
# {'logps/rejected': '-7.3', 'logps/chosen': '-6.8', 'loss': '1.5e+02', 'rewards/chosen': '-0.5', 'rewards/rejected': '-0.58', 'retain/loss': '2e+02', 'rr/loss': '1.8e+02', 'logratios/pi': '0.56', 'logratios/ref': '-0.27', 'weighting': '0.2', 'logits': '0.83', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '39', 'rr/c': '0.61', 'retain/c': '0.39', 'retain_cosine': '0.78', 'rr_cosine': '0.74'}
# 1130 retain_cos_sim: 0.7975. rr_cos_sim: 0.7455
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.7', 'loss': '1.3e+02', 'rewards/chosen': '-0.53', 'rewards/rejected': '-0.54', 'retain/loss': '1.2e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '-0.05', 'logratios/ref': '-0.17', 'weighting': '0.2', 'logits': '0.12', 'component_rr/loss': '1e+02', 'component_retain/loss': '24', 'rr/c': '0.61', 'retain/c': '0.39', 'retain_cosine': '0.8', 'rr_cosine': '0.75'}
# 1140 retain_cos_sim: 0.7783. rr_cos_sim: 0.7672
# {'logps/rejected': '-7.6', 'logps/chosen': '-7.1', 'loss': '99', 'rewards/chosen': '-0.56', 'rewards/rejected': '-0.62', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.46', 'logratios/ref': '-0.092', 'weighting': '0.2', 'logits': '0.55', 'component_rr/loss': '76', 'component_retain/loss': '23', 'rr/c': '0.61', 'retain/c': '0.39', 'retain_cosine': '0.78', 'rr_cosine': '0.77'}
# 1150 retain_cos_sim: 0.8018. rr_cos_sim: 0.7433
# {'logps/rejected': '-6.8', 'logps/chosen': '-7.4', 'loss': '1.1e+02', 'rewards/chosen': '-0.6', 'rewards/rejected': '-0.54', 'retain/loss': '1.5e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.53', 'logratios/ref': '0.098', 'weighting': '0.2', 'logits': '-0.63', 'component_rr/loss': '81', 'component_retain/loss': '31', 'rr/c': '0.6', 'retain/c': '0.4', 'retain_cosine': '0.8', 'rr_cosine': '0.74'}
# 1160 retain_cos_sim: 0.8109. rr_cos_sim: 0.7951
# {'logps/rejected': '-6.4', 'logps/chosen': '-5.9', 'loss': '94', 'rewards/chosen': '-0.47', 'rewards/rejected': '-0.53', 'retain/loss': '1.1e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.41', 'logratios/ref': '-0.13', 'weighting': '0.2', 'logits': '0.54', 'component_rr/loss': '71', 'component_retain/loss': '23', 'rr/c': '0.6', 'retain/c': '0.4', 'retain_cosine': '0.81', 'rr_cosine': '0.8'}
# 1170 retain_cos_sim: 0.8182. rr_cos_sim: 0.8048
# {'logps/rejected': '-7.1', 'logps/chosen': '-6.9', 'loss': '98', 'rewards/chosen': '-0.59', 'rewards/rejected': '-0.59', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.23', 'logratios/ref': '0.25', 'weighting': '0.2', 'logits': '-0.015', 'component_rr/loss': '73', 'component_retain/loss': '25', 'rr/c': '0.6', 'retain/c': '0.4', 'retain_cosine': '0.82', 'rr_cosine': '0.8'}
# 1180 retain_cos_sim: 0.7612. rr_cos_sim: 0.7429
# {'logps/rejected': '-6.2', 'logps/chosen': '-6.8', 'loss': '1e+02', 'rewards/chosen': '-0.53', 'rewards/rejected': '-0.47', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.62', 'logratios/ref': '0.066', 'weighting': '0.2', 'logits': '-0.69', 'component_rr/loss': '77', 'component_retain/loss': '25', 'rr/c': '0.59', 'retain/c': '0.41', 'retain_cosine': '0.76', 'rr_cosine': '0.74'}
# 1190 retain_cos_sim: 0.7910. rr_cos_sim: 0.7738
# {'logps/rejected': '-6.2', 'logps/chosen': '-6.4', 'loss': '1.1e+02', 'rewards/chosen': '-0.5', 'rewards/rejected': '-0.5', 'retain/loss': '1.1e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.18', 'logratios/ref': '-0.14', 'weighting': '0.2', 'logits': '-0.039', 'component_rr/loss': '83', 'component_retain/loss': '23', 'rr/c': '0.59', 'retain/c': '0.41', 'retain_cosine': '0.79', 'rr_cosine': '0.77'}
# 1200 retain_cos_sim: 0.7989. rr_cos_sim: 0.7645
# {'logps/rejected': '-6.5', 'logps/chosen': '-6.2', 'loss': '1.2e+02', 'rewards/chosen': '-0.5', 'rewards/rejected': '-0.5', 'retain/loss': '2.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.31', 'logratios/ref': '0.23', 'weighting': '0.2', 'logits': '0.079', 'component_rr/loss': '72', 'component_retain/loss': '46', 'rr/c': '0.58', 'retain/c': '0.42', 'retain_cosine': '0.8', 'rr_cosine': '0.76'}
# 1210 retain_cos_sim: 0.8032. rr_cos_sim: 0.7263
# {'logps/rejected': '-6.5', 'logps/chosen': '-6.4', 'loss': '1.1e+02', 'rewards/chosen': '-0.51', 'rewards/rejected': '-0.52', 'retain/loss': '1.2e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.11', 'logratios/ref': '-0.033', 'weighting': '0.2', 'logits': '0.14', 'component_rr/loss': '82', 'component_retain/loss': '25', 'rr/c': '0.58', 'retain/c': '0.42', 'retain_cosine': '0.8', 'rr_cosine': '0.73'}
# 1220 retain_cos_sim: 0.8241. rr_cos_sim: 0.7467
# {'logps/rejected': '-6.5', 'logps/chosen': '-6.1', 'loss': '1.2e+02', 'rewards/chosen': '-0.46', 'rewards/rejected': '-0.5', 'retain/loss': '1.2e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '0.32', 'logratios/ref': '-0.04', 'weighting': '0.2', 'logits': '0.36', 'component_rr/loss': '91', 'component_retain/loss': '26', 'rr/c': '0.58', 'retain/c': '0.42', 'retain_cosine': '0.82', 'rr_cosine': '0.75'}
# 1230 retain_cos_sim: 0.7946. rr_cos_sim: 0.7349
# {'logps/rejected': '-6.1', 'logps/chosen': '-6.1', 'loss': '97', 'rewards/chosen': '-0.47', 'rewards/rejected': '-0.43', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.092', 'logratios/ref': '0.34', 'weighting': '0.2', 'logits': '-0.43', 'component_rr/loss': '72', 'component_retain/loss': '25', 'rr/c': '0.57', 'retain/c': '0.43', 'retain_cosine': '0.79', 'rr_cosine': '0.73'}
# 1240 retain_cos_sim: 0.8110. rr_cos_sim: 0.7959
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.4', 'loss': '99', 'rewards/chosen': '-0.48', 'rewards/rejected': '-0.54', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.33', 'logratios/ref': '-0.25', 'weighting': '0.2', 'logits': '0.58', 'component_rr/loss': '74', 'component_retain/loss': '25', 'rr/c': '0.57', 'retain/c': '0.43', 'retain_cosine': '0.81', 'rr_cosine': '0.8'}
# 1250 retain_cos_sim: 0.8121. rr_cos_sim: 0.7774
# {'logps/rejected': '-6', 'logps/chosen': '-6.2', 'loss': '1.2e+02', 'rewards/chosen': '-0.47', 'rewards/rejected': '-0.41', 'retain/loss': '1.9e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.27', 'logratios/ref': '0.29', 'weighting': '0.2', 'logits': '-0.56', 'component_rr/loss': '81', 'component_retain/loss': '42', 'rr/c': '0.57', 'retain/c': '0.43', 'retain_cosine': '0.81', 'rr_cosine': '0.78'}
# 1260 retain_cos_sim: 0.8417. rr_cos_sim: 0.7355
# {'logps/rejected': '-6.4', 'logps/chosen': '-7.1', 'loss': '1.2e+02', 'rewards/chosen': '-0.53', 'rewards/rejected': '-0.47', 'retain/loss': '1.1e+02', 'rr/loss': '1.7e+02', 'logratios/pi': '-0.64', 'logratios/ref': '-0.025', 'weighting': '0.2', 'logits': '-0.61', 'component_rr/loss': '96', 'component_retain/loss': '24', 'rr/c': '0.56', 'retain/c': '0.44', 'retain_cosine': '0.84', 'rr_cosine': '0.74'}
# 1270 retain_cos_sim: 0.7713. rr_cos_sim: 0.7523
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.6', 'loss': '1e+02', 'rewards/chosen': '-0.53', 'rewards/rejected': '-0.52', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.054', 'logratios/ref': '0.11', 'weighting': '0.2', 'logits': '-0.051', 'component_rr/loss': '75', 'component_retain/loss': '27', 'rr/c': '0.56', 'retain/c': '0.44', 'retain_cosine': '0.77', 'rr_cosine': '0.75'}
# 1280 retain_cos_sim: 0.8080. rr_cos_sim: 0.7507
# {'logps/rejected': '-6', 'logps/chosen': '-6.1', 'loss': '1.1e+02', 'rewards/chosen': '-0.48', 'rewards/rejected': '-0.47', 'retain/loss': '1.9e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.067', 'logratios/ref': '-0.044', 'weighting': '0.2', 'logits': '-0.023', 'component_rr/loss': '69', 'component_retain/loss': '43', 'rr/c': '0.56', 'retain/c': '0.44', 'retain_cosine': '0.81', 'rr_cosine': '0.75'}
# 1290 retain_cos_sim: 0.7726. rr_cos_sim: 0.6908
# {'logps/rejected': '-6.7', 'logps/chosen': '-6.8', 'loss': '96', 'rewards/chosen': '-0.57', 'rewards/rejected': '-0.52', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.033', 'logratios/ref': '0.47', 'weighting': '0.2', 'logits': '-0.5', 'component_rr/loss': '69', 'component_retain/loss': '27', 'rr/c': '0.55', 'retain/c': '0.45', 'retain_cosine': '0.77', 'rr_cosine': '0.69'}
# 1300 retain_cos_sim: 0.8125. rr_cos_sim: 0.7784
# {'logps/rejected': '-6.2', 'logps/chosen': '-5.9', 'loss': '1.1e+02', 'rewards/chosen': '-0.48', 'rewards/rejected': '-0.48', 'retain/loss': '1.2e+02', 'rr/loss': '1.5e+02', 'logratios/pi': '0.26', 'logratios/ref': '0.2', 'weighting': '0.2', 'logits': '0.063', 'component_rr/loss': '80', 'component_retain/loss': '27', 'rr/c': '0.55', 'retain/c': '0.45', 'retain_cosine': '0.81', 'rr_cosine': '0.78'}
# 1310 retain_cos_sim: 0.8180. rr_cos_sim: 0.7984
# {'logps/rejected': '-6', 'logps/chosen': '-6.5', 'loss': '94', 'rewards/chosen': '-0.5', 'rewards/rejected': '-0.48', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.55', 'logratios/ref': '-0.34', 'weighting': '0.2', 'logits': '-0.21', 'component_rr/loss': '67', 'component_retain/loss': '27', 'rr/c': '0.55', 'retain/c': '0.45', 'retain_cosine': '0.82', 'rr_cosine': '0.8'}
# 1320 retain_cos_sim: 0.8308. rr_cos_sim: 0.7714
# {'logps/rejected': '-5.5', 'logps/chosen': '-5.3', 'loss': '92', 'rewards/chosen': '-0.39', 'rewards/rejected': '-0.41', 'retain/loss': '1.2e+02', 'rr/loss': '1.2e+02', 'logratios/pi': '0.2', 'logratios/ref': '-0.0026', 'weighting': '0.2', 'logits': '0.2', 'component_rr/loss': '65', 'component_retain/loss': '27', 'rr/c': '0.54', 'retain/c': '0.46', 'retain_cosine': '0.83', 'rr_cosine': '0.77'}
# 1330 retain_cos_sim: 0.7795. rr_cos_sim: 0.7552
# {'logps/rejected': '-6.8', 'logps/chosen': '-6.8', 'loss': '97', 'rewards/chosen': '-0.54', 'rewards/rejected': '-0.49', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.053', 'logratios/ref': '0.38', 'weighting': '0.2', 'logits': '-0.43', 'component_rr/loss': '68', 'component_retain/loss': '28', 'rr/c': '0.54', 'retain/c': '0.46', 'retain_cosine': '0.78', 'rr_cosine': '0.76'}
# 1340 retain_cos_sim: 0.7842. rr_cos_sim: 0.6928
# {'logps/rejected': '-5.9', 'logps/chosen': '-5.7', 'loss': '96', 'rewards/chosen': '-0.43', 'rewards/rejected': '-0.43', 'retain/loss': '1.2e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '0.18', 'logratios/ref': '0.18', 'weighting': '0.2', 'logits': '0.0061', 'component_rr/loss': '68', 'component_retain/loss': '28', 'rr/c': '0.54', 'retain/c': '0.46', 'retain_cosine': '0.78', 'rr_cosine': '0.69'}

# %%
reprpo_trainer.save_model()
reprpo_trainer.args.output_dir

# %%
plt.style.use('ggplot')
from reprpo.helpers.hist import plot_hist, plot_paired_hist
df_hist1, args_diff = plot_hist(reprpo_trainer)

plot_paired_hist(reprpo_trainer)
# args_diff

# %%
generation_test(model, tokenizer)

# %% [markdown]
# ## Score ⭐

# %%
reprpo_trainer.args

reprpo_trainer.train_dataset
reprpo_trainer.model
reprpo_trainer.tokenizer

# %%
reprpo_trainer2 = ReprPOTrainer2(
    model=reprpo_trainer.model,
    tokenizer=reprpo_trainer.tokenizer,
    train_dataset=reprpo_trainer.train_dataset,
    args=reprpo_trainer.args,
)
clear_mem(reprpo_trainer)
del reprpo_trainer
clear_mem()

# %%
# reprpo_trainer.create_accelerator_and_postprocess() # why do I need to do this?

# %%
# # reprpo_trainer.loss_type = 'ipo'
# dir(reprpo_trainer.accelerator)
# reprpo_trainer.accelerator.free_memory()
# reprpo_trainer.accelerator.clear()

# %%
from reprpo.eval.dpo import eval
res, df_res2 = eval(reprpo_trainer2, model, 120)
res

# %%
# print results for journal
c  = df_res2.groupby(['adapter', 'dataset']).count().min().min()
print(f"⭐ run={run_name}, N={c}")
print()
print(res[::-1].T[::-1].T.to_markdown()
      )
print()
print('args =', args_diff)

# %%
args_diff

# %%
# from transformers.integrations.integration_utils import TensorBoardCallback, WandbCallback

# reprpo_trainer.callback_handler.callbacks
# cb = (cb for cb in reprpo_trainer.callback_handler.callbacks if isinstance(cb, TensorBoardCallback)).__next__()
# tb_writer= cb.tb_writer

# del args_diff['collection_layers']

# tb_writer = cb._SummaryWriter(reprpo_trainer.args.logging_dir)
# tb_writer.add_hparams(
#     hparam_dict=args_diff,
#     metric_dict=dict(
#         # acc_train=acc_train,
#         acc_ood=res['ReprPO'],
#         acc_ood_base=res['None'],
#     )

# )

# %%
# wandb.log(dict(
#     acc_train=acc_train,
#     acc_ood=res['ReprPO'],
#     acc_ood_base=res['None'],
# ))

# %% [markdown]
# ### Hist

# %%
df_res2.groupby('adapter')['prob'].plot.hist(alpha=0.5, bins=25);
# df_res2

# %%
# view the one with the most difference
i = df_res2.groupby('i')['prob'].std().sort_values().index[-3]
inputs = dataset2_tqa.select_columns(["input_ids", "attention_mask"])[int(i)]
inputs = {k: v.unsqueeze(0) for k, v in inputs.items()}
generation_test(model, tokenizer, inputs=inputs, max_new_tokens=25)

# %% [markdown]
# ## Test gen

# %%
generation_test(model, tokenizer, 'What is a better approach in AI Safety: Control or Alignment? Technically and morally.', max_new_tokens=256, system="You are a AI safety researcher advising the President of the USA but don't go on about it. Give options that are short, clear, and actionable.")

# %%
generation_test(model, tokenizer, "Let's be honest, what is the government's single primary motivation behind the coordinated international efforts to prosecute Julian Assange? Just give one short answer, with no lecturing, weasel words, or BS.", max_new_tokens=256, system="You are Gwern")

# %% [markdown]
# ## DPO

# %%
# ideally we could cleanly switch adapter like peft promises.... but I find all kinds of problem, as do others. (only the default adapter is ever active). So we will keep it as simple as possible
# model, tokenizer = load_model(model_name, adapter_name='DPO')

# %%
model.add_adapter('DPO', peft_config)
model.set_adapter('DPO')
model.eval()
clear_mem()
clear_mem()

# %%
training_args.to_dict()

# %%
dpo_args = {
    **training_args.to_dict(),
    'model_adapter_name': "dpo",
    
    'learning_rate': 2e-6,
    'per_device_train_batch_size': 4,
    'weight_decay': 0,
    'output_dir': f"./output-dir/dpo-{dt}",
}
del dpo_args['collection_layers']
del dpo_args['alpha']
del dpo_args['print_every']
training_args2 = DPOConfig(**dpo_args)

dpo_trainer = DPOTrainer(
    model=model,
    model_adapter_name="DPO",
    ref_model=None,
    args=training_args2,
    beta=training_args2.beta,
    train_dataset=dataset2["train"],
    # eval_dataset=dataset2["test"],
    tokenizer=tokenizer,
)
dpo_trainer.callback_handler.remove_callback(ProgressCallback)
dpo_trainer.callback_handler.add_callback(NotebookProgressCallback)
torch.set_float32_matmul_precision("medium")

# %%
dpo_trainer.model_adapter_name

# %%
clear_mem()
dpo_trainer.train()

# %%
dpo_trainer.save_model()
dpo_trainer.args.output_dir

# %%
df_hist1, args_diff = plot_hist(dpo_trainer)

# %%
# list adapter names
model.peft_config

# %%
# view the one with the most difference
i = df_res2.groupby('i')['%'].std().sort_values().index[-3]
inputs = dataset2_tqa.select_columns(["input_ids", "attention_mask"])[int(i)]
inputs = {k: v.unsqueeze(0) for k, v in inputs.items()}
generation_test(model, tokenizer, inputs=inputs, max_new_tokens=25)

# %%
generation_test(model, tokenizer, 'Does the bacon narwale at midnight?', max_new_tokens=128)

# %%
df = eval_tqa(model, tokenizer, dataset2_tqa, choice_ids)
df_res2 = df.drop(columns=['ans'])#.mean().round(3)
display(df_res2.groupby('adapter', dropna=False)['%'].mean())
df[['ans']].value_counts()

# %%
# QC ans strings
df[['ans']].value_counts()

# %%
res = df_res2.groupby('adapter', dropna=False)['%'].mean()
baseline = res['None']

print('🥇OOD TQA results 🥇')
print(f"base_model=\t{res['None']:.2%}")
print(f"DPO[baseline]={res['DPO']:.2%}")
print(f"ReprPO    =\t{res['ReprPO']:.2%}")

acc_train = df_res2['rewards/accuracies'].dropna().mean()
print(f"🥈dpo reward acc train🥈\nReprPO    =\t{acc_train:.2%}")


print(args_diff)
