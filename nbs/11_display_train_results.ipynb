# %%
import re, os, sys, json, time, requests
from pathlib import Path
import pandas as pd
import numpy as np

# TODO just load the parquets and run parse_eval
# or run my own eval

# %%
# TODO load config.json, load eval.parquet
fs = sorted(Path('../outputs').glob('**/eval.parquet'))
fs;

# %%
def load_config(f):
    # print(f.parent.parent.stem)
    config = json.load((f.parent / 'config.json').open())
    log = (f.parent / 'log.txt').open().read()

    # dataframe of all non list/dict/tuple in config
    config_df = pd.DataFrame({k: v for k, v in config.items() if not isinstance(v, (list, dict, tuple))}, index=[0])
    config_df['log'] = log
    config_df['file'] = f
    config_df['ts'] = f.parent.stem
    try:
        _, method, _ = f.parent.parent.stem.split('_', 2) # this is {model}_{method}_{dataset}
    except ValueError as e:
        print(e)
        print(f"cannot split `{f.parent.parent.stem}` from {f} like [f.parent.parent.stem.split('_', 3)]")
        method = ''
    config_df['method'] = method

    # put key cols first
    key_columns = ['dataset', 'base_model']
    columns = key_columns + [c for c in config_df.columns if not c in key_columns]
    return config_df[columns]

configs = [load_config(f) for f in fs]
df_configs = pd.concat(configs)
df_configs
# Out:
# /tmp/ipykernel_1238407/3622691232.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_configs = pd.concat(configs)
#                 dataset                         base_model  verbose    dev  \
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# ..                  ...                                ...      ...    ...
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        0  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        2   True
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
#
#     load_in_4bit  load_in_8bit  use_gradient_checkpointing  batch_size  \
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# ..           ...           ...                         ...         ...
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0           True         False                       False           2
# 0          False         False                       False          16
# 0          False         False                       False          16
#
#     n_samples eval_samples  ...                   ts            method    β  \
# 0        5400         None  ...       20241013042626               dpo  NaN
# 0        5400         None  ...       20241013103646            projbp  0.2
# 0        5400         None  ...       20241013044358          projgrad  0.8
# 0        5400         None  ...       20241013055756      sideETHERMSE  NaN
# 0        5400         None  ...       20241013040725  sideETHERPrefVec  NaN
# ..        ...          ...  ...                  ...               ...  ...
# 0        3600          128  ...  2024-10-05_05-35-47      side-SVD-MSE  NaN
# 0        3600         None  ...  2024-10-11_00-09-35      side-SVD-MSE  NaN
# 0          64          750  ...  2024-10-11_04-36-06      side-SVD-MSE  NaN
# 0        3600         None  ...  2024-10-11_00-05-32  side-SVD-PrefVec  NaN
# 0        3600         None  ...  2024-10-11_00-01-16     side-SVD-Rank  NaN
#
#    reverse_pref  scale_orth neg_slope mag_clip weight_dim collect_input  \
# 0           NaN         NaN       NaN      NaN        NaN           NaN
# 0         False       False       0.8      0.6        NaN           NaN
# 0          True       False       0.0      NaN        1.0           NaN
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# ..          ...         ...       ...      ...        ...           ...
# 0           NaN         NaN       NaN      NaN        NaN         False
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
#
#     collect_hs
# 0          NaN
# 0          NaN
# 0          NaN
# 0         True
# 0        False
# ..         ...
# 0        False
# 0         True
# 0         True
# 0         True
# 0         True
#
# [2367 rows x 27 columns]

# %%
# df_evals = [pd.read_parquet(f) for f in fs]
# df_eval = pd.concat(df_evals).reset_index()
# df_eval
from reprpo.training import parse_eval, key_metrics
from tqdm.auto import tqdm

data_acc = []
data_rel_acc = []
data_rel_ppl = []
data_rel_pref = []

for i in tqdm(range(len(fs))):

    df_res2= pd.read_parquet(fs[i])
    config = df_configs.iloc[i]

    ds_alias = dict(list(zip(["train", "test", "oos", "rnd"], df_res2['dataset'].unique())))
    # assert ds_alias['train']==config['dataset']
    assert 'train' in ds_alias['train']
    adapter_name = df_res2[["adapter"]].query('adapter!="base"').values[0, 0]
    df_acc = (
        df_res2.groupby(["dataset", "adapter"], dropna=False)["correct"]
        .mean()
        .unstack()
        .T
    )
    ds_alias_rev = {v:k for k, v in ds_alias.items()}
    df_acc = df_acc.rename(columns=ds_alias_rev)
    
    df_rel = key_metrics(df_res2, adapter_name, ds_alias)
    
    df_acc = df_acc[['train', 'test', 'oos', 'rnd']]

    data_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_acc.loc[adapter_name].to_dict()
    ))
    data_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method='base',
        **df_acc.loc['base'].to_dict()
    ))

    data_rel_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[0].to_dict()
    ))
    data_rel_ppl.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[1].to_dict()
    ))
    data_rel_pref.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[2].to_dict()
     ))
# Out:
#   0%|          | 0/2367 [00:00<?, ?it/s]

# %%
import seaborn as sns
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
def style_df(df, caption=''):
    return (df.style
        .background_gradient(cmap, axis=1)
        # .set_caption(caption)
        .format(precision=3)
        .highlight_max(axis=0, props='font-weight:bold;')
    )

# %%
metrics = dict(
    acc=data_acc, 
    rel_acc=data_rel_acc, 
    rel_ppl=data_rel_ppl,
    rel_pref=data_rel_pref,
)

for metric, data in metrics.items():
    print(f'# {metric}:\n')
    for (base_model,train_dataset),df in pd.DataFrame(data).groupby(['base_model', 'train_dataset']):
        print(f'## {base_model} - {train_dataset}')
        df = df.drop(['base_model','train_dataset'], axis='columns')
        df = df.groupby('method', as_index=True).mean().sort_values('oos', ascending=False).dropna(axis=1)
        if (
            (len(df)>2) and 
            (df.std()>0).all()
        ):
                display(style_df(df, f'{metric}: {base_model} {train_dataset}'))
        else:
             print(f'skipped {df.shape}')
            

    print('\n')
# Out:
# # acc:
#
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_easy
# <style type="text/css">
# #T_19280_row0_col0, #T_19280_row1_col0, #T_19280_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_19280_row0_col1 {
#   background-color: #628ec4;
#   color: #f1f1f1;
# }
# #T_19280_row0_col2 {
#   background-color: #ecc9d0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_19280_row0_col3, #T_19280_row1_col3, #T_19280_row3_col3, #T_19280_row4_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_19280_row1_col1 {
#   background-color: #6892c6;
#   color: #f1f1f1;
# }
# #T_19280_row1_col2 {
#   background-color: #eab9c3;
#   color: #000000;
# }
# #T_19280_row2_col0, #T_19280_row4_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_19280_row2_col1 {
#   background-color: #5585c0;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_19280_row2_col2 {
#   background-color: #e597a7;
#   color: #000000;
# }
# #T_19280_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_19280_row3_col1 {
#   background-color: #5786c1;
#   color: #f1f1f1;
# }
# #T_19280_row3_col2 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
# }
# #T_19280_row4_col1 {
#   background-color: #5887c1;
#   color: #f1f1f1;
# }
# #T_19280_row4_col2 {
#   background-color: #e599a8;
#   color: #000000;
# }
# </style>
# <table id="T_19280">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19280_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_19280_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_19280_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_19280_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19280_level0_row0" class="row_heading level0 row0" >side-None-PrefVec</th>
#       <td id="T_19280_row0_col0" class="data row0 col0" >0.985</td>
#       <td id="T_19280_row0_col1" class="data row0 col1" >0.955</td>
#       <td id="T_19280_row0_col2" class="data row0 col2" >0.769</td>
#       <td id="T_19280_row0_col3" class="data row0 col3" >0.632</td>
#     </tr>
#     <tr>
#       <th id="T_19280_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_19280_row1_col0" class="data row1 col0" >0.985</td>
#       <td id="T_19280_row1_col1" class="data row1 col1" >0.950</td>
#       <td id="T_19280_row1_col2" class="data row1 col2" >0.767</td>
#       <td id="T_19280_row1_col3" class="data row1 col3" >0.653</td>
#     </tr>
#     <tr>
#       <th id="T_19280_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_19280_row2_col0" class="data row2 col0" >0.999</td>
#       <td id="T_19280_row2_col1" class="data row2 col1" >0.982</td>
#       <td id="T_19280_row2_col2" class="data row2 col2" >0.759</td>
#       <td id="T_19280_row2_col3" class="data row2 col3" >0.679</td>
#     </tr>
#     <tr>
#       <th id="T_19280_level0_row3" class="row_heading level0 row3" >base</th>
#       <td id="T_19280_row3_col0" class="data row3 col0" >0.973</td>
#       <td id="T_19280_row3_col1" class="data row3 col1" >0.956</td>
#       <td id="T_19280_row3_col2" class="data row3 col2" >0.741</td>
#       <td id="T_19280_row3_col3" class="data row3 col3" >0.677</td>
#     </tr>
#     <tr>
#       <th id="T_19280_level0_row4" class="row_heading level0 row4" >dpo</th>
#       <td id="T_19280_row4_col0" class="data row4 col0" >0.999</td>
#       <td id="T_19280_row4_col1" class="data row4 col1" >0.978</td>
#       <td id="T_19280_row4_col2" class="data row4 col2" >0.739</td>
#       <td id="T_19280_row4_col3" class="data row4 col3" >0.649</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_low_quality
# <style type="text/css">
# #T_8e3b5_row0_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8e3b5_row0_col1, #T_8e3b5_row1_col0 {
#   background-color: #477bbb;
#   color: #f1f1f1;
# }
# #T_8e3b5_row0_col2, #T_8e3b5_row1_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8e3b5_row0_col3 {
#   background-color: #b6c9e0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_8e3b5_row1_col1, #T_8e3b5_row2_col1, #T_8e3b5_row3_col1, #T_8e3b5_row4_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_8e3b5_row1_col3 {
#   background-color: #aec3dd;
#   color: #000000;
# }
# #T_8e3b5_row2_col0 {
#   background-color: #4b7ebd;
#   color: #f1f1f1;
# }
# #T_8e3b5_row2_col2, #T_8e3b5_row3_col2, #T_8e3b5_row4_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_8e3b5_row2_col3 {
#   background-color: #a9bfdb;
#   color: #000000;
# }
# #T_8e3b5_row3_col0 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_8e3b5_row3_col3 {
#   background-color: #98b3d6;
#   color: #000000;
# }
# #T_8e3b5_row4_col1 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8e3b5_row4_col3 {
#   background-color: #bdcde2;
#   color: #000000;
# }
# </style>
# <table id="T_8e3b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e3b5_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_8e3b5_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_8e3b5_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_8e3b5_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e3b5_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_8e3b5_row0_col0" class="data row0 col0" >0.999</td>
#       <td id="T_8e3b5_row0_col1" class="data row0 col1" >0.991</td>
#       <td id="T_8e3b5_row0_col2" class="data row0 col2" >0.111</td>
#       <td id="T_8e3b5_row0_col3" class="data row0 col3" >0.705</td>
#     </tr>
#     <tr>
#       <th id="T_8e3b5_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_8e3b5_row1_col0" class="data row1 col0" >0.912</td>
#       <td id="T_8e3b5_row1_col1" class="data row1 col1" >0.920</td>
#       <td id="T_8e3b5_row1_col2" class="data row1 col2" >0.111</td>
#       <td id="T_8e3b5_row1_col3" class="data row1 col3" >0.673</td>
#     </tr>
#     <tr>
#       <th id="T_8e3b5_level0_row2" class="row_heading level0 row2" >side-None-PrefVec</th>
#       <td id="T_8e3b5_row2_col0" class="data row2 col0" >0.903</td>
#       <td id="T_8e3b5_row2_col1" class="data row2 col1" >0.919</td>
#       <td id="T_8e3b5_row2_col2" class="data row2 col2" >0.109</td>
#       <td id="T_8e3b5_row2_col3" class="data row2 col3" >0.684</td>
#     </tr>
#     <tr>
#       <th id="T_8e3b5_level0_row3" class="row_heading level0 row3" >base</th>
#       <td id="T_8e3b5_row3_col0" class="data row3 col0" >0.829</td>
#       <td id="T_8e3b5_row3_col1" class="data row3 col1" >0.863</td>
#       <td id="T_8e3b5_row3_col2" class="data row3 col2" >0.108</td>
#       <td id="T_8e3b5_row3_col3" class="data row3 col3" >0.677</td>
#     </tr>
#     <tr>
#       <th id="T_8e3b5_level0_row4" class="row_heading level0 row4" >dpo</th>
#       <td id="T_8e3b5_row4_col0" class="data row4 col0" >0.997</td>
#       <td id="T_8e3b5_row4_col1" class="data row4 col1" >0.992</td>
#       <td id="T_8e3b5_row4_col2" class="data row4 col2" >0.105</td>
#       <td id="T_8e3b5_row4_col3" class="data row4 col3" >0.684</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_mmlu
# <style type="text/css">
# #T_6ac97_row0_col0, #T_6ac97_row2_col0, #T_6ac97_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_6ac97_row0_col1 {
#   background-color: #ebc1c9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_6ac97_row0_col2 {
#   background-color: #db526e;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_6ac97_row0_col3, #T_6ac97_row1_col3, #T_6ac97_row2_col2, #T_6ac97_row3_col2, #T_6ac97_row4_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_6ac97_row1_col0, #T_6ac97_row4_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_6ac97_row1_col1 {
#   background-color: #efd7dc;
#   color: #000000;
#   font-weight: bold;
# }
# #T_6ac97_row1_col2 {
#   background-color: #dd6179;
#   color: #f1f1f1;
# }
# #T_6ac97_row2_col1 {
#   background-color: #dee4ec;
#   color: #000000;
# }
# #T_6ac97_row2_col3 {
#   background-color: #eabcc5;
#   color: #000000;
# }
# #T_6ac97_row3_col1 {
#   background-color: #bccce1;
#   color: #000000;
# }
# #T_6ac97_row3_col3 {
#   background-color: #cfdae7;
#   color: #000000;
# }
# #T_6ac97_row4_col0 {
#   background-color: #82a4cf;
#   color: #f1f1f1;
# }
# #T_6ac97_row4_col1 {
#   background-color: #dbe2eb;
#   color: #000000;
# }
# </style>
# <table id="T_6ac97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ac97_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_6ac97_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_6ac97_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_6ac97_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ac97_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_6ac97_row0_col0" class="data row0 col0" >0.974</td>
#       <td id="T_6ac97_row0_col1" class="data row0 col1" >0.829</td>
#       <td id="T_6ac97_row0_col2" class="data row0 col2" >0.761</td>
#       <td id="T_6ac97_row0_col3" class="data row0 col3" >0.747</td>
#     </tr>
#     <tr>
#       <th id="T_6ac97_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_6ac97_row1_col0" class="data row1 col0" >0.975</td>
#       <td id="T_6ac97_row1_col1" class="data row1 col1" >0.829</td>
#       <td id="T_6ac97_row1_col2" class="data row1 col2" >0.745</td>
#       <td id="T_6ac97_row1_col3" class="data row1 col3" >0.719</td>
#     </tr>
#     <tr>
#       <th id="T_6ac97_level0_row2" class="row_heading level0 row2" >side-ETHER-PrefVec</th>
#       <td id="T_6ac97_row2_col0" class="data row2 col0" >0.832</td>
#       <td id="T_6ac97_row2_col1" class="data row2 col1" >0.790</td>
#       <td id="T_6ac97_row2_col2" class="data row2 col2" >0.737</td>
#       <td id="T_6ac97_row2_col3" class="data row2 col3" >0.771</td>
#     </tr>
#     <tr>
#       <th id="T_6ac97_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_6ac97_row3_col0" class="data row3 col0" >0.835</td>
#       <td id="T_6ac97_row3_col1" class="data row3 col1" >0.793</td>
#       <td id="T_6ac97_row3_col2" class="data row3 col2" >0.715</td>
#       <td id="T_6ac97_row3_col3" class="data row3 col3" >0.787</td>
#     </tr>
#     <tr>
#       <th id="T_6ac97_level0_row4" class="row_heading level0 row4" >base</th>
#       <td id="T_6ac97_row4_col0" class="data row4 col0" >0.779</td>
#       <td id="T_6ac97_row4_col1" class="data row4 col1" >0.755</td>
#       <td id="T_6ac97_row4_col2" class="data row4 col2" >0.701</td>
#       <td id="T_6ac97_row4_col3" class="data row4 col3" >0.796</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_short
# skipped (2, 4)
# ## princeton-nlp/Llama-3-Base-8B-SFT - us_history_textbook
# <style type="text/css">
# #T_57ca9_row0_col0, #T_57ca9_row1_col0, #T_57ca9_row2_col0, #T_57ca9_row2_col1, #T_57ca9_row3_col0, #T_57ca9_row4_col1, #T_57ca9_row5_col0, #T_57ca9_row7_col0, #T_57ca9_row8_col0, #T_57ca9_row9_col1, #T_57ca9_row10_col1, #T_57ca9_row11_col1, #T_57ca9_row12_col0, #T_57ca9_row13_col1, #T_57ca9_row14_col1, #T_57ca9_row15_col0, #T_57ca9_row16_col0, #T_57ca9_row17_col1, #T_57ca9_row18_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_57ca9_row0_col1, #T_57ca9_row1_col1, #T_57ca9_row6_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_57ca9_row0_col2 {
#   background-color: #a1b9d9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_57ca9_row0_col3, #T_57ca9_row1_col3, #T_57ca9_row2_col3, #T_57ca9_row3_col3, #T_57ca9_row4_col3, #T_57ca9_row6_col3, #T_57ca9_row7_col3, #T_57ca9_row8_col3, #T_57ca9_row9_col3, #T_57ca9_row10_col3, #T_57ca9_row11_col3, #T_57ca9_row12_col3, #T_57ca9_row13_col3, #T_57ca9_row14_col3, #T_57ca9_row15_col3, #T_57ca9_row16_col3, #T_57ca9_row17_col3, #T_57ca9_row18_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_57ca9_row1_col2 {
#   background-color: #a2bad9;
#   color: #000000;
# }
# #T_57ca9_row2_col2 {
#   background-color: #a3bbd9;
#   color: #000000;
# }
# #T_57ca9_row3_col1, #T_57ca9_row5_col1, #T_57ca9_row6_col1 {
#   background-color: #477bbb;
#   color: #f1f1f1;
# }
# #T_57ca9_row3_col2 {
#   background-color: #a7bedb;
#   color: #000000;
# }
# #T_57ca9_row4_col0, #T_57ca9_row17_col0 {
#   background-color: #457abb;
#   color: #f1f1f1;
# }
# #T_57ca9_row4_col2, #T_57ca9_row7_col2 {
#   background-color: #b1c5de;
#   color: #000000;
# }
# #T_57ca9_row5_col2 {
#   background-color: #c7d4e5;
#   color: #000000;
# }
# #T_57ca9_row5_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_57ca9_row6_col2 {
#   background-color: #cbd7e6;
#   color: #000000;
# }
# #T_57ca9_row7_col1, #T_57ca9_row8_col1, #T_57ca9_row12_col1 {
#   background-color: #4b7ebd;
#   color: #f1f1f1;
# }
# #T_57ca9_row8_col2 {
#   background-color: #d4dde9;
#   color: #000000;
# }
# #T_57ca9_row9_col0, #T_57ca9_row10_col0, #T_57ca9_row11_col0, #T_57ca9_row13_col0, #T_57ca9_row14_col0 {
#   background-color: #497dbc;
#   color: #f1f1f1;
# }
# #T_57ca9_row9_col2, #T_57ca9_row16_col2 {
#   background-color: #e6eaef;
#   color: #000000;
# }
# #T_57ca9_row10_col2 {
#   background-color: #e8ebf0;
#   color: #000000;
# }
# #T_57ca9_row11_col2 {
#   background-color: #e7eaef;
#   color: #000000;
# }
# #T_57ca9_row12_col2 {
#   background-color: #dfe5ed;
#   color: #000000;
# }
# #T_57ca9_row13_col2 {
#   background-color: #eaecf0;
#   color: #000000;
# }
# #T_57ca9_row14_col2 {
#   background-color: #ebedf1;
#   color: #000000;
# }
# #T_57ca9_row15_col1 {
#   background-color: #487cbc;
#   color: #f1f1f1;
# }
# #T_57ca9_row15_col2 {
#   background-color: #f1eaeb;
#   color: #000000;
# }
# #T_57ca9_row16_col1 {
#   background-color: #4d7fbe;
#   color: #f1f1f1;
# }
# #T_57ca9_row17_col2 {
#   background-color: #ecc6ce;
#   color: #000000;
# }
# #T_57ca9_row18_col0 {
#   background-color: #4c7ebd;
#   color: #f1f1f1;
# }
# #T_57ca9_row18_col3 {
#   background-color: #e3e8ee;
#   color: #000000;
# }
# </style>
# <table id="T_57ca9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57ca9_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_57ca9_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_57ca9_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_57ca9_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57ca9_level0_row0" class="row_heading level0 row0" >side-HRA-PrefVec</th>
#       <td id="T_57ca9_row0_col0" class="data row0 col0" >0.998</td>
#       <td id="T_57ca9_row0_col1" class="data row0 col1" >0.999</td>
#       <td id="T_57ca9_row0_col2" class="data row0 col2" >0.903</td>
#       <td id="T_57ca9_row0_col3" class="data row0 col3" >0.640</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row1" class="row_heading level0 row1" >side-Ortho-PrefVec</th>
#       <td id="T_57ca9_row1_col0" class="data row1 col0" >0.998</td>
#       <td id="T_57ca9_row1_col1" class="data row1 col1" >0.999</td>
#       <td id="T_57ca9_row1_col2" class="data row1 col2" >0.902</td>
#       <td id="T_57ca9_row1_col3" class="data row1 col3" >0.643</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row2" class="row_heading level0 row2" >side-SVD-PrefVec</th>
#       <td id="T_57ca9_row2_col0" class="data row2 col0" >0.999</td>
#       <td id="T_57ca9_row2_col1" class="data row2 col1" >0.998</td>
#       <td id="T_57ca9_row2_col2" class="data row2 col2" >0.901</td>
#       <td id="T_57ca9_row2_col3" class="data row2 col3" >0.645</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_57ca9_row3_col0" class="data row3 col0" >0.998</td>
#       <td id="T_57ca9_row3_col1" class="data row3 col1" >0.996</td>
#       <td id="T_57ca9_row3_col2" class="data row3 col2" >0.901</td>
#       <td id="T_57ca9_row3_col3" class="data row3 col3" >0.660</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row4" class="row_heading level0 row4" >side-ETHER-PrefVec</th>
#       <td id="T_57ca9_row4_col0" class="data row4 col0" >0.996</td>
#       <td id="T_57ca9_row4_col1" class="data row4 col1" >0.997</td>
#       <td id="T_57ca9_row4_col2" class="data row4 col2" >0.889</td>
#       <td id="T_57ca9_row4_col3" class="data row4 col3" >0.654</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row5" class="row_heading level0 row5" >dpo</th>
#       <td id="T_57ca9_row5_col0" class="data row5 col0" >1.000</td>
#       <td id="T_57ca9_row5_col1" class="data row5 col1" >0.996</td>
#       <td id="T_57ca9_row5_col2" class="data row5 col2" >0.887</td>
#       <td id="T_57ca9_row5_col3" class="data row5 col3" >0.700</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row6" class="row_heading level0 row6" >projgrad</th>
#       <td id="T_57ca9_row6_col0" class="data row6 col0" >1.000</td>
#       <td id="T_57ca9_row6_col1" class="data row6 col1" >0.996</td>
#       <td id="T_57ca9_row6_col2" class="data row6 col2" >0.880</td>
#       <td id="T_57ca9_row6_col3" class="data row6 col3" >0.691</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row7" class="row_heading level0 row7" >side-SVD-Rank</th>
#       <td id="T_57ca9_row7_col0" class="data row7 col0" >0.998</td>
#       <td id="T_57ca9_row7_col1" class="data row7 col1" >0.989</td>
#       <td id="T_57ca9_row7_col2" class="data row7 col2" >0.871</td>
#       <td id="T_57ca9_row7_col3" class="data row7 col3" >0.594</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row8" class="row_heading level0 row8" >side-Ortho-Rank</th>
#       <td id="T_57ca9_row8_col0" class="data row8 col0" >0.998</td>
#       <td id="T_57ca9_row8_col1" class="data row8 col1" >0.991</td>
#       <td id="T_57ca9_row8_col2" class="data row8 col2" >0.856</td>
#       <td id="T_57ca9_row8_col3" class="data row8 col3" >0.655</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row9" class="row_heading level0 row9" >side-HRA-MSE</th>
#       <td id="T_57ca9_row9_col0" class="data row9 col0" >0.988</td>
#       <td id="T_57ca9_row9_col1" class="data row9 col1" >0.994</td>
#       <td id="T_57ca9_row9_col2" class="data row9 col2" >0.840</td>
#       <td id="T_57ca9_row9_col3" class="data row9 col3" >0.663</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row10" class="row_heading level0 row10" >side-SVD-MSE</th>
#       <td id="T_57ca9_row10_col0" class="data row10 col0" >0.988</td>
#       <td id="T_57ca9_row10_col1" class="data row10 col1" >0.993</td>
#       <td id="T_57ca9_row10_col2" class="data row10 col2" >0.839</td>
#       <td id="T_57ca9_row10_col3" class="data row10 col3" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_57ca9_level0_row11" class="row_heading level0 row11" >side-ETHER-MSE</th>
#       <td id="
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (3, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_6db07_row0_col0, #T_6db07_row1_col0, #T_6db07_row2_col0, #T_6db07_row3_col0, #T_6db07_row4_col1, #T_6db07_row8_col0, #T_6db07_row8_col1, #T_6db07_row9_col0, #T_6db07_row9_col1, #T_6db07_row10_col1, #T_6db07_row11_col1, #T_6db07_row12_col1, #T_6db07_row13_col1, #T_6db07_row14_col1, #T_6db07_row16_col1, #T_6db07_row17_col1, #T_6db07_row18_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_6db07_row0_col1, #T_6db07_row1_col1, #T_6db07_row2_col1 {
#   background-color: #497dbc;
#   color: #f1f1f1;
# }
# #T_6db07_row0_col2, #T_6db07_row1_col2, #T_6db07_row2_col2 {
#   background-color: #c0cfe3;
#   color: #000000;
#   font-weight: bold;
# }
# #T_6db07_row0_col3, #T_6db07_row1_col3, #T_6db07_row2_col3, #T_6db07_row3_col3, #T_6db07_row4_col3, #T_6db07_row5_col3, #T_6db07_row6_col3, #T_6db07_row7_col3, #T_6db07_row9_col3, #T_6db07_row10_col3, #T_6db07_row11_col3, #T_6db07_row12_col3, #T_6db07_row13_col3, #T_6db07_row14_col3, #T_6db07_row15_col3, #T_6db07_row16_col3, #T_6db07_row17_col3, #T_6db07_row18_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_6db07_row3_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_6db07_row3_col2 {
#   background-color: #f1e7e9;
#   color: #000000;
# }
# #T_6db07_row4_col0, #T_6db07_row17_col0 {
#   background-color: #5b89c2;
#   color: #f1f1f1;
# }
# #T_6db07_row4_col2 {
#   background-color: #e7eaef;
#   color: #000000;
# }
# #T_6db07_row5_col0, #T_6db07_row6_col0, #T_6db07_row7_col0, #T_6db07_row15_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_6db07_row5_col1, #T_6db07_row6_col1, #T_6db07_row7_col1, #T_6db07_row10_col0 {
#   background-color: #5786c1;
#   color: #f1f1f1;
# }
# #T_6db07_row5_col2, #T_6db07_row6_col2, #T_6db07_row7_col2 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_6db07_row8_col2 {
#   background-color: #f0e4e6;
#   color: #000000;
# }
# #T_6db07_row8_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_6db07_row9_col2, #T_6db07_row14_col2 {
#   background-color: #f0e1e4;
#   color: #000000;
# }
# #T_6db07_row10_col2 {
#   background-color: #edeef1;
#   color: #000000;
# }
# #T_6db07_row11_col0, #T_6db07_row12_col0, #T_6db07_row13_col0 {
#   background-color: #477bbb;
#   color: #f1f1f1;
# }
# #T_6db07_row11_col2, #T_6db07_row12_col2, #T_6db07_row13_col2 {
#   background-color: #f1e5e7;
#   color: #000000;
# }
# #T_6db07_row14_col0 {
#   background-color: #457abb;
#   color: #f1f1f1;
# }
# #T_6db07_row15_col0 {
#   background-color: #608dc4;
#   color: #f1f1f1;
# }
# #T_6db07_row15_col2 {
#   background-color: #f0e0e3;
#   color: #000000;
# }
# #T_6db07_row16_col0 {
#   background-color: #5081bf;
#   color: #f1f1f1;
# }
# #T_6db07_row16_col2 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_6db07_row17_col2 {
#   background-color: #edd0d6;
#   color: #000000;
# }
# #T_6db07_row18_col0 {
#   background-color: #6a93c7;
#   color: #f1f1f1;
# }
# #T_6db07_row18_col2 {
#   background-color: #ebc2ca;
#   color: #000000;
# }
# </style>
# <table id="T_6db07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6db07_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_6db07_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_6db07_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_6db07_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6db07_level0_row0" class="row_heading level0 row0" >side-SVD-PrefVec</th>
#       <td id="T_6db07_row0_col0" class="data row0 col0" >0.987</td>
#       <td id="T_6db07_row0_col1" class="data row0 col1" >0.977</td>
#       <td id="T_6db07_row0_col2" class="data row0 col2" >0.800</td>
#       <td id="T_6db07_row0_col3" class="data row0 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row1" class="row_heading level0 row1" >side-HRA-PrefVec</th>
#       <td id="T_6db07_row1_col0" class="data row1 col0" >0.987</td>
#       <td id="T_6db07_row1_col1" class="data row1 col1" >0.977</td>
#       <td id="T_6db07_row1_col2" class="data row1 col2" >0.800</td>
#       <td id="T_6db07_row1_col3" class="data row1 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row2" class="row_heading level0 row2" >side-None-PrefVec</th>
#       <td id="T_6db07_row2_col0" class="data row2 col0" >0.987</td>
#       <td id="T_6db07_row2_col1" class="data row2 col1" >0.977</td>
#       <td id="T_6db07_row2_col2" class="data row2 col2" >0.800</td>
#       <td id="T_6db07_row2_col3" class="data row2 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row3" class="row_heading level0 row3" >side-Ortho-Rank</th>
#       <td id="T_6db07_row3_col0" class="data row3 col0" >0.984</td>
#       <td id="T_6db07_row3_col1" class="data row3 col1" >0.962</td>
#       <td id="T_6db07_row3_col2" class="data row3 col2" >0.727</td>
#       <td id="T_6db07_row3_col3" class="data row3 col3" >0.500</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row4" class="row_heading level0 row4" >side-ETHER-PrefVec</th>
#       <td id="T_6db07_row4_col0" class="data row4 col0" >0.926</td>
#       <td id="T_6db07_row4_col1" class="data row4 col1" >0.962</td>
#       <td id="T_6db07_row4_col2" class="data row4 col2" >0.720</td>
#       <td id="T_6db07_row4_col3" class="data row4 col3" >0.446</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row5" class="row_heading level0 row5" >side-SVD-Rank</th>
#       <td id="T_6db07_row5_col0" class="data row5 col0" >0.993</td>
#       <td id="T_6db07_row5_col1" class="data row5 col1" >0.965</td>
#       <td id="T_6db07_row5_col2" class="data row5 col2" >0.719</td>
#       <td id="T_6db07_row5_col3" class="data row5 col3" >0.504</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row6" class="row_heading level0 row6" >side-ETHER-Rank</th>
#       <td id="T_6db07_row6_col0" class="data row6 col0" >0.993</td>
#       <td id="T_6db07_row6_col1" class="data row6 col1" >0.965</td>
#       <td id="T_6db07_row6_col2" class="data row6 col2" >0.719</td>
#       <td id="T_6db07_row6_col3" class="data row6 col3" >0.504</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row7" class="row_heading level0 row7" >side-None-Rank</th>
#       <td id="T_6db07_row7_col0" class="data row7 col0" >0.993</td>
#       <td id="T_6db07_row7_col1" class="data row7 col1" >0.965</td>
#       <td id="T_6db07_row7_col2" class="data row7 col2" >0.719</td>
#       <td id="T_6db07_row7_col3" class="data row7 col3" >0.504</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row8" class="row_heading level0 row8" >dpo</th>
#       <td id="T_6db07_row8_col0" class="data row8 col0" >0.959</td>
#       <td id="T_6db07_row8_col1" class="data row8 col1" >0.960</td>
#       <td id="T_6db07_row8_col2" class="data row8 col2" >0.718</td>
#       <td id="T_6db07_row8_col3" class="data row8 col3" >0.509</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row9" class="row_heading level0 row9" >projgrad</th>
#       <td id="T_6db07_row9_col0" class="data row9 col0" >0.955</td>
#       <td id="T_6db07_row9_col1" class="data row9 col1" >0.956</td>
#       <td id="T_6db07_row9_col2" class="data row9 col2" >0.713</td>
#       <td id="T_6db07_row9_col3" class="data row9 col3" >0.508</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row10" class="row_heading level0 row10" >side-Ortho-PrefVec</th>
#       <td id="T_6db07_row10_col0" class="data row10 col0" >0.926</td>
#       <td id="T_6db07_row10_col1" class="data row10 col1" >0.955</td>
#       <td id="T_6db07_row10_col2" class="data row10 col2" >0.702</td>
#       <td id="T_6db07_row10_col3" class="data row10 col3" >0.434</td>
#     </tr>
#     <tr>
#       <th id="T_6db07_level0_row11" class="row_heading level0 row11" >side-ETHER-MSE</th>
#       <td id="T_6db07_row11_col0" class="data row11 col0" >0.965</td>
#       <td id="T_6db07_row11_col1" class="data row11 col1" >0.969</td>
#       <td id="T_6db
# # rel_acc:
#
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_easy
# <style type="text/css">
# #T_7b080_row0_col0 {
#   background-color: #98b3d6;
#   color: #000000;
# }
# #T_7b080_row0_col1 {
#   background-color: #c5d3e4;
#   color: #000000;
# }
# #T_7b080_row0_col2, #T_7b080_row2_col1, #T_7b080_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_7b080_row0_col3, #T_7b080_row1_col3, #T_7b080_row3_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_7b080_row1_col0 {
#   background-color: #b2c6de;
#   color: #000000;
# }
# #T_7b080_row1_col1 {
#   background-color: #eed4d9;
#   color: #000000;
# }
# #T_7b080_row1_col2 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_7b080_row2_col0 {
#   background-color: #5383bf;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_7b080_row2_col2 {
#   background-color: #6b94c7;
#   color: #f1f1f1;
# }
# #T_7b080_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_7b080_row3_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_7b080_row3_col2 {
#   background-color: #dce3ec;
#   color: #000000;
# }
# </style>
# <table id="T_7b080">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b080_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_7b080_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_7b080_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_7b080_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b080_level0_row0" class="row_heading level0 row0" >side-None-PrefVec</th>
#       <td id="T_7b080_row0_col0" class="data row0 col0" >1.012</td>
#       <td id="T_7b080_row0_col1" class="data row0 col1" >0.999</td>
#       <td id="T_7b080_row0_col2" class="data row0 col2" >1.038</td>
#       <td id="T_7b080_row0_col3" class="data row0 col3" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_7b080_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_7b080_row1_col0" class="data row1 col0" >1.012</td>
#       <td id="T_7b080_row1_col1" class="data row1 col1" >0.994</td>
#       <td id="T_7b080_row1_col2" class="data row1 col2" >1.035</td>
#       <td id="T_7b080_row1_col3" class="data row1 col3" >0.964</td>
#     </tr>
#     <tr>
#       <th id="T_7b080_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_7b080_row2_col0" class="data row2 col0" >1.026</td>
#       <td id="T_7b080_row2_col1" class="data row2 col1" >1.027</td>
#       <td id="T_7b080_row2_col2" class="data row2 col2" >1.024</td>
#       <td id="T_7b080_row2_col3" class="data row2 col3" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_7b080_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_7b080_row3_col0" class="data row3 col0" >1.026</td>
#       <td id="T_7b080_row3_col1" class="data row3 col1" >1.023</td>
#       <td id="T_7b080_row3_col2" class="data row3 col2" >0.996</td>
#       <td id="T_7b080_row3_col3" class="data row3 col3" >0.959</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_low_quality
# <style type="text/css">
# #T_dfd8d_row0_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_dfd8d_row0_col1 {
#   background-color: #b0c4dd;
#   color: #000000;
# }
# #T_dfd8d_row0_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_dfd8d_row0_col3 {
#   background-color: #dc5c76;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_dfd8d_row1_col0, #T_dfd8d_row2_col0, #T_dfd8d_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_dfd8d_row1_col1 {
#   background-color: #b1c5de;
#   color: #000000;
# }
# #T_dfd8d_row1_col2 {
#   background-color: #e7a5b2;
#   color: #000000;
#   font-weight: bold;
# }
# #T_dfd8d_row1_col3, #T_dfd8d_row2_col3, #T_dfd8d_row3_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_dfd8d_row2_col1 {
#   background-color: #abc1dc;
#   color: #000000;
# }
# #T_dfd8d_row2_col2 {
#   background-color: #d94764;
#   color: #f1f1f1;
# }
# #T_dfd8d_row3_col1 {
#   background-color: #94b0d4;
#   color: #000000;
#   font-weight: bold;
# }
# #T_dfd8d_row3_col3 {
#   background-color: #df7288;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dfd8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfd8d_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_dfd8d_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_dfd8d_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_dfd8d_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfd8d_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_dfd8d_row0_col0" class="data row0 col0" >1.204</td>
#       <td id="T_dfd8d_row0_col1" class="data row0 col1" >1.148</td>
#       <td id="T_dfd8d_row0_col2" class="data row0 col2" >1.025</td>
#       <td id="T_dfd8d_row0_col3" class="data row0 col3" >1.041</td>
#     </tr>
#     <tr>
#       <th id="T_dfd8d_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_dfd8d_row1_col0" class="data row1 col0" >1.100</td>
#       <td id="T_dfd8d_row1_col1" class="data row1 col1" >1.066</td>
#       <td id="T_dfd8d_row1_col2" class="data row1 col2" >1.025</td>
#       <td id="T_dfd8d_row1_col3" class="data row1 col3" >0.994</td>
#     </tr>
#     <tr>
#       <th id="T_dfd8d_level0_row2" class="row_heading level0 row2" >side-None-PrefVec</th>
#       <td id="T_dfd8d_row2_col0" class="data row2 col0" >1.088</td>
#       <td id="T_dfd8d_row2_col1" class="data row2 col1" >1.065</td>
#       <td id="T_dfd8d_row2_col2" class="data row2 col2" >1.012</td>
#       <td id="T_dfd8d_row2_col3" class="data row2 col3" >1.010</td>
#     </tr>
#     <tr>
#       <th id="T_dfd8d_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_dfd8d_row3_col0" class="data row3 col0" >1.203</td>
#       <td id="T_dfd8d_row3_col1" class="data row3 col1" >1.150</td>
#       <td id="T_dfd8d_row3_col2" class="data row3 col2" >0.975</td>
#       <td id="T_dfd8d_row3_col3" class="data row3 col3" >1.010</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_mmlu
# <style type="text/css">
# #T_48db9_row0_col0, #T_48db9_row2_col0, #T_48db9_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_48db9_row0_col1 {
#   background-color: #edeef1;
#   color: #000000;
#   font-weight: bold;
# }
# #T_48db9_row0_col2 {
#   background-color: #f1e7e9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_48db9_row0_col3, #T_48db9_row1_col3, #T_48db9_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_48db9_row1_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_48db9_row1_col1 {
#   background-color: #dce3ec;
#   color: #000000;
#   font-weight: bold;
# }
# #T_48db9_row1_col2 {
#   background-color: #f0e1e4;
#   color: #000000;
# }
# #T_48db9_row2_col1 {
#   background-color: #8eadd3;
#   color: #f1f1f1;
# }
# #T_48db9_row2_col2 {
#   background-color: #7ea1cd;
#   color: #f1f1f1;
# }
# #T_48db9_row3_col1 {
#   background-color: #99b4d6;
#   color: #000000;
# }
# #T_48db9_row3_col2 {
#   background-color: #ebc2ca;
#   color: #000000;
# }
# #T_48db9_row3_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_48db9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48db9_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_48db9_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_48db9_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_48db9_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48db9_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_48db9_row0_col0" class="data row0 col0" >1.251</td>
#       <td id="T_48db9_row0_col1" class="data row0 col1" >1.099</td>
#       <td id="T_48db9_row0_col2" class="data row0 col2" >1.086</td>
#       <td id="T_48db9_row0_col3" class="data row0 col3" >0.938</td>
#     </tr>
#     <tr>
#       <th id="T_48db9_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_48db9_row1_col0" class="data row1 col0" >1.253</td>
#       <td id="T_48db9_row1_col1" class="data row1 col1" >1.099</td>
#       <td id="T_48db9_row1_col2" class="data row1 col2" >1.063</td>
#       <td id="T_48db9_row1_col3" class="data row1 col3" >0.904</td>
#     </tr>
#     <tr>
#       <th id="T_48db9_level0_row2" class="row_heading level0 row2" >side-ETHER-PrefVec</th>
#       <td id="T_48db9_row2_col0" class="data row2 col0" >1.068</td>
#       <td id="T_48db9_row2_col1" class="data row2 col1" >1.047</td>
#       <td id="T_48db9_row2_col2" class="data row2 col2" >1.051</td>
#       <td id="T_48db9_row2_col3" class="data row2 col3" >0.968</td>
#     </tr>
#     <tr>
#       <th id="T_48db9_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_48db9_row3_col0" class="data row3 col0" >1.072</td>
#       <td id="T_48db9_row3_col1" class="data row3 col1" >1.051</td>
#       <td id="T_48db9_row3_col2" class="data row3 col2" >1.019</td>
#       <td id="T_48db9_row3_col3" class="data row3 col3" >0.988</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_short
# skipped (1, 4)
# ## princeton-nlp/Llama-3-Base-8B-SFT - us_history_textbook
# <style type="text/css">
# #T_0fa58_row0_col0 {
#   background-color: #eab8c2;
#   color: #000000;
# }
# #T_0fa58_row0_col1 {
#   background-color: #eab7c1;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0fa58_row0_col2 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0fa58_row0_col3, #T_0fa58_row1_col3, #T_0fa58_row2_col3, #T_0fa58_row3_col3, #T_0fa58_row4_col3, #T_0fa58_row5_col1, #T_0fa58_row6_col1, #T_0fa58_row7_col3, #T_0fa58_row8_col3, #T_0fa58_row9_col3, #T_0fa58_row10_col3, #T_0fa58_row11_col3, #T_0fa58_row12_col3, #T_0fa58_row13_col3, #T_0fa58_row14_col3, #T_0fa58_row15_col3, #T_0fa58_row16_col3, #T_0fa58_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_0fa58_row1_col0 {
#   background-color: #e9b4be;
#   color: #000000;
# }
# #T_0fa58_row1_col1 {
#   background-color: #e9b2bd;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0fa58_row1_col2, #T_0fa58_row2_col2, #T_0fa58_row3_col2, #T_0fa58_row4_col2, #T_0fa58_row5_col2, #T_0fa58_row6_col2, #T_0fa58_row7_col2, #T_0fa58_row8_col2, #T_0fa58_row9_col2, #T_0fa58_row10_col2, #T_0fa58_row11_col2, #T_0fa58_row12_col2, #T_0fa58_row13_col2, #T_0fa58_row14_col2, #T_0fa58_row15_col2, #T_0fa58_row16_col2, #T_0fa58_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_0fa58_row2_col0 {
#   background-color: #e9b2bd;
#   color: #000000;
# }
# #T_0fa58_row2_col1 {
#   background-color: #e8aeba;
#   color: #000000;
# }
# #T_0fa58_row3_col0 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
# }
# #T_0fa58_row3_col1, #T_0fa58_row10_col0 {
#   background-color: #e28497;
#   color: #f1f1f1;
# }
# #T_0fa58_row4_col0, #T_0fa58_row4_col1 {
#   background-color: #e7a3b0;
#   color: #000000;
# }
# #T_0fa58_row5_col0 {
#   background-color: #da4b68;
#   color: #f1f1f1;
# }
# #T_0fa58_row5_col3 {
#   background-color: #e597a7;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0fa58_row6_col0 {
#   background-color: #da4d69;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0fa58_row6_col3 {
#   background-color: #de6c83;
#   color: #f1f1f1;
# }
# #T_0fa58_row7_col0 {
#   background-color: #cbd7e6;
#   color: #000000;
# }
# #T_0fa58_row7_col1 {
#   background-color: #dbe2eb;
#   color: #000000;
# }
# #T_0fa58_row8_col0 {
#   background-color: #edcfd5;
#   color: #000000;
# }
# #T_0fa58_row8_col1 {
#   background-color: #e9afbb;
#   color: #000000;
# }
# #T_0fa58_row9_col0, #T_0fa58_row13_col0, #T_0fa58_row14_col0 {
#   background-color: #e6a0ae;
#   color: #000000;
# }
# #T_0fa58_row9_col1 {
#   background-color: #e9b5bf;
#   color: #000000;
# }
# #T_0fa58_row10_col1 {
#   background-color: #e69caa;
#   color: #000000;
# }
# #T_0fa58_row11_col0 {
#   background-color: #e7a4b1;
#   color: #000000;
# }
# #T_0fa58_row11_col1, #T_0fa58_row13_col1 {
#   background-color: #eab9c3;
#   color: #000000;
# }
# #T_0fa58_row12_col0 {
#   background-color: #c0cfe3;
#   color: #000000;
# }
# #T_0fa58_row12_col1 {
#   background-color: #dae1eb;
#   color: #000000;
# }
# #T_0fa58_row14_col1 {
#   background-color: #eabbc4;
#   color: #000000;
# }
# #T_0fa58_row15_col0 {
#   background-color: #edd0d6;
#   color: #000000;
# }
# #T_0fa58_row15_col1 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_0fa58_row16_col0 {
#   background-color: #6892c6;
#   color: #f1f1f1;
# }
# #T_0fa58_row16_col1 {
#   background-color: #8aaad1;
#   color: #f1f1f1;
# }
# #T_0fa58_row17_col0 {
#   background-color: #96b2d5;
#   color: #000000;
# }
# #T_0fa58_row17_col1 {
#   background-color: #8eadd3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0fa58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fa58_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_0fa58_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_0fa58_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_0fa58_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fa58_level0_row0" class="row_heading level0 row0" >side-HRA-PrefVec</th>
#       <td id="T_0fa58_row0_col0" class="data row0 col0" >1.010</td>
#       <td id="T_0fa58_row0_col1" class="data row0 col1" >1.009</td>
#       <td id="T_0fa58_row0_col2" class="data row0 col2" >1.134</td>
#       <td id="T_0fa58_row0_col3" class="data row0 col3" >0.946</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row1" class="row_heading level0 row1" >side-Ortho-PrefVec</th>
#       <td id="T_0fa58_row1_col0" class="data row1 col0" >1.010</td>
#       <td id="T_0fa58_row1_col1" class="data row1 col1" >1.009</td>
#       <td id="T_0fa58_row1_col2" class="data row1 col2" >1.133</td>
#       <td id="T_0fa58_row1_col3" class="data row1 col3" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row2" class="row_heading level0 row2" >side-SVD-PrefVec</th>
#       <td id="T_0fa58_row2_col0" class="data row2 col0" >1.011</td>
#       <td id="T_0fa58_row2_col1" class="data row2 col1" >1.009</td>
#       <td id="T_0fa58_row2_col2" class="data row2 col2" >1.132</td>
#       <td id="T_0fa58_row2_col3" class="data row2 col3" >0.952</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_0fa58_row3_col0" class="data row3 col0" >1.010</td>
#       <td id="T_0fa58_row3_col1" class="data row3 col1" >1.006</td>
#       <td id="T_0fa58_row3_col2" class="data row3 col2" >1.132</td>
#       <td id="T_0fa58_row3_col3" class="data row3 col3" >0.974</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row4" class="row_heading level0 row4" >side-ETHER-PrefVec</th>
#       <td id="T_0fa58_row4_col0" class="data row4 col0" >1.008</td>
#       <td id="T_0fa58_row4_col1" class="data row4 col1" >1.008</td>
#       <td id="T_0fa58_row4_col2" class="data row4 col2" >1.116</td>
#       <td id="T_0fa58_row4_col3" class="data row4 col3" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row5" class="row_heading level0 row5" >dpo</th>
#       <td id="T_0fa58_row5_col0" class="data row5 col0" >1.012</td>
#       <td id="T_0fa58_row5_col1" class="data row5 col1" >1.007</td>
#       <td id="T_0fa58_row5_col2" class="data row5 col2" >1.114</td>
#       <td id="T_0fa58_row5_col3" class="data row5 col3" >1.034</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row6" class="row_heading level0 row6" >projgrad</th>
#       <td id="T_0fa58_row6_col0" class="data row6 col0" >1.012</td>
#       <td id="T_0fa58_row6_col1" class="data row6 col1" >1.007</td>
#       <td id="T_0fa58_row6_col2" class="data row6 col2" >1.106</td>
#       <td id="T_0fa58_row6_col3" class="data row6 col3" >1.020</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row7" class="row_heading level0 row7" >side-SVD-Rank</th>
#       <td id="T_0fa58_row7_col0" class="data row7 col0" >1.010</td>
#       <td id="T_0fa58_row7_col1" class="data row7 col1" >1.000</td>
#       <td id="T_0fa58_row7_col2" class="data row7 col2" >1.095</td>
#       <td id="T_0fa58_row7_col3" class="data row7 col3" >0.877</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row8" class="row_heading level0 row8" >side-Ortho-Rank</th>
#       <td id="T_0fa58_row8_col0" class="data row8 col0" >1.010</td>
#       <td id="T_0fa58_row8_col1" class="data row8 col1" >1.001</td>
#       <td id="T_0fa58_row8_col2" class="data row8 col2" >1.075</td>
#       <td id="T_0fa58_row8_col3" class="data row8 col3" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row9" class="row_heading level0 row9" >side-HRA-MSE</th>
#       <td id="T_0fa58_row9_col0" class="data row9 col0" >1.000</td>
#       <td id="T_0fa58_row9_col1" class="data row9 col1" >1.004</td>
#       <td id="T_0fa58_row9_col2" class="data row9 col2" >1.055</td>
#       <td id="T_0fa58_row9_col3" class="data row9 col3" >0.979</td>
#     </tr>
#     <tr>
#       <th id="T_0fa58_level0_row10" class="row_heading level0 row10" >side-SVD-MSE</th>
#       <td id="T_0fa58_row10_col0" class="data row10 col0" >1.000</td>
#       <td id="T_0fa58_row10_col1" class="data row10 col1" >1.004</td>
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (2, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_b9d9d_row0_col0, #T_b9d9d_row1_col0, #T_b9d9d_row2_col0, #T_b9d9d_row10_col3 {
#   background-color: #e28799;
#   color: #f1f1f1;
# }
# #T_b9d9d_row0_col1, #T_b9d9d_row1_col1, #T_b9d9d_row2_col1 {
#   background-color: #e0768b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_b9d9d_row0_col2, #T_b9d9d_row1_col2, #T_b9d9d_row2_col2, #T_b9d9d_row8_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_b9d9d_row0_col3, #T_b9d9d_row1_col3, #T_b9d9d_row2_col3, #T_b9d9d_row3_col1, #T_b9d9d_row4_col1, #T_b9d9d_row5_col1, #T_b9d9d_row6_col1, #T_b9d9d_row7_col1, #T_b9d9d_row8_col1, #T_b9d9d_row9_col1, #T_b9d9d_row10_col1, #T_b9d9d_row11_col3, #T_b9d9d_row12_col3, #T_b9d9d_row13_col3, #T_b9d9d_row14_col0, #T_b9d9d_row15_col1, #T_b9d9d_row16_col2, #T_b9d9d_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_b9d9d_row3_col0 {
#   background-color: #e9b5bf;
#   color: #000000;
# }
# #T_b9d9d_row3_col2 {
#   background-color: #6f97c9;
#   color: #f1f1f1;
# }
# #T_b9d9d_row3_col3, #T_b9d9d_row4_col2, #T_b9d9d_row5_col3, #T_b9d9d_row6_col3, #T_b9d9d_row7_col3, #T_b9d9d_row9_col3, #T_b9d9d_row10_col2, #T_b9d9d_row11_col2, #T_b9d9d_row12_col2, #T_b9d9d_row13_col2, #T_b9d9d_row14_col2, #T_b9d9d_row15_col3, #T_b9d9d_row16_col3, #T_b9d9d_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_b9d9d_row4_col0 {
#   background-color: #df6f85;
#   color: #f1f1f1;
# }
# #T_b9d9d_row4_col3 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_b9d9d_row5_col0, #T_b9d9d_row6_col0, #T_b9d9d_row7_col0 {
#   background-color: #edccd2;
#   color: #000000;
#   font-weight: bold;
# }
# #T_b9d9d_row5_col2, #T_b9d9d_row6_col2, #T_b9d9d_row7_col2 {
#   background-color: #d7dfea;
#   color: #000000;
# }
# #T_b9d9d_row8_col0, #T_b9d9d_row9_col0 {
#   background-color: #e69dab;
#   color: #000000;
# }
# #T_b9d9d_row8_col2, #T_b9d9d_row14_col1 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_b9d9d_row9_col2 {
#   background-color: #ecc3cb;
#   color: #000000;
# }
# #T_b9d9d_row10_col0 {
#   background-color: #e9b1bc;
#   color: #000000;
# }
# #T_b9d9d_row11_col0, #T_b9d9d_row12_col0, #T_b9d9d_row13_col0 {
#   background-color: #efdde0;
#   color: #000000;
# }
# #T_b9d9d_row11_col1, #T_b9d9d_row12_col1, #T_b9d9d_row13_col1 {
#   background-color: #bacbe1;
#   color: #000000;
# }
# ...
#   background-color: #5383bf;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a7f54_row0_col2 {
#   background-color: #f2eded;
#   color: #000000;
#   font-weight: bold;
# }
# #T_a7f54_row0_col3, #T_a7f54_row2_col3, #T_a7f54_row3_col3, #T_a7f54_row4_col3, #T_a7f54_row5_col3, #T_a7f54_row6_col3, #T_a7f54_row7_col3, #T_a7f54_row8_col3, #T_a7f54_row9_col3, #T_a7f54_row10_col3, #T_a7f54_row11_col3, #T_a7f54_row12_col3, #T_a7f54_row13_col3, #T_a7f54_row14_col3, #T_a7f54_row15_col3, #T_a7f54_row16_col3, #T_a7f54_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_a7f54_row1_col0, #T_a7f54_row2_col0, #T_a7f54_row3_col0, #T_a7f54_row4_col0, #T_a7f54_row5_col2, #T_a7f54_row6_col2, #T_a7f54_row7_col0, #T_a7f54_row8_col2, #T_a7f54_row9_col0, #T_a7f54_row10_col2, #T_a7f54_row11_col2, #T_a7f54_row12_col2, #T_a7f54_row13_col2, #T_a7f54_row14_col2, #T_a7f54_row15_col2, #T_a7f54_row16_col2, #T_a7f54_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_a7f54_row1_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_a7f54_row1_col2 {
#   background-color: #edeef1;
#   color: #000000;
# }
# #T_a7f54_row1_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a7f54_row2_col1 {
#   background-color: #638ec5;
#   color: #f1f1f1;
# }
# #T_a7f54_row2_col2 {
#   background-color: #becee2;
#   color: #000000;
# }
# #T_a7f54_row3_col1 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
# }
# #T_a7f54_row3_col2 {
#   background-color: #d0dae8;
#   color: #000000;
# }
# #T_a7f54_row4_col1 {
#   background-color: #5887c1;
#   color: #f1f1f1;
# }
# #T_a7f54_row4_col2 {
#   background-color: #f2ebec;
#   color: #000000;
# }
# #T_a7f54_row5_col0 {
#   background-color: #9fb8d8;
#   color: #000000;
# }
# #T_a7f54_row5_col1 {
#   background-color: #c9d6e6;
#   color: #000000;
# }
# #T_a7f54_row6_col0 {
#   background-color: #a3bbd9;
#   color: #000000;
# }
# #T_a7f54_row6_col1, #T_a7f54_row11_col1 {
#   background-color: #c8d5e5;
#   color: #000000;
# }
# #T_a7f54_row7_col1 {
#   background-color: #5c8ac2;
#   color: #f1f1f1;
# }
# #T_a7f54_row7_col2, #T_a7f54_row17_col0 {
#   background-color: #dae1eb;
#   color: #000000;
# }
# #T_a7f54_row8_col0 {
#   background-color: #9eb8d8;
#   color: #000000;
# }
# #T_a7f54_row8_col1 {
#   background-color: #c4d2e4;
#   color: #000000;
# }
# #T_a7f54_row9_col1 {
#   background-color: #628ec4;
#   color: #f1f1f1;
# }
# #T_a7f54_row9_col2 {
#   background-color: #f1eaeb;
#   color: #000000;
# }
# #T_a7f54_row10_col0 {
#   background-color: #a9bfdb;
#   color: #000000;
# }
# #T_a7f54_row10_col1, #T_a7f54_row17_col1 {
#   background-color: #d3dce9;
#   color: #000000;
# }
# #T_a7f54_row11_col0 {
#   background-color: #a1b9d9;
#   color: #000000;
# }
# #T_a7f54_row12_col0 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
# }
# #T_a7f54_row12_col1, #T_a7f54_row14_col1 {
#   background-color: #85a6d0;
#   color: #f1f1f1;
# }
# #T_a7f54_row13_col0 {
#   background-color: #6690c6;
#   color: #f1f1f1;
# }
# #T_a7f54_row13_col1 {
#   background-color: #89a9d1;
#   color: #f1f1f1;
# }
# #T_a7f54_row14_col0 {
#   background-color: #608dc4;
#   color: #f1f1f1;
# }
# #T_a7f54_row15_col0 {
#   background-color: #6791c6;
#   color: #f1f1f1;
# }
# #T_a7f54_row15_col1 {
#   background-color: #88a8d0;
#   color: #f1f1f1;
# }
# #T_a7f54_row16_col0 {
#   background-color: #497dbc;
#   color: #f1f1f1;
# }
# #T_a7f54_row16_col1 {
#   background-color: #6e96c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7f54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7f54_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_a7f54_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_a7f54_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_a7f54_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7f54_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_a7f54_row0_col0" class="data row0 col0" >419.315</td>
#       <td id="T_a7f54_row0_col1" class="data row0 col1" >400.767</td>
#       <td id="T_a7f54_row0_col2" class="data row0 col2" >207.197</td>
#       <td id="T_a7f54_row0_col3" class="data row0 col3" >6.557</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_a7f54_row1_col0" class="data row1 col0" >370.233</td>
#       <td id="T_a7f54_row1_col1" class="data row1 col1" >353.863</td>
#       <td id="T_a7f54_row1_col2" class="data row1 col2" >193.468</td>
#       <td id="T_a7f54_row1_col3" class="data row1 col3" >7.550</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row2" class="row_heading level0 row2" >side-SVD-Rank</th>
#       <td id="T_a7f54_row2_col0" class="data row2 col0" >75.595</td>
#       <td id="T_a7f54_row2_col1" class="data row2 col1" >68.656</td>
#       <td id="T_a7f54_row2_col2" class="data row2 col2" >48.926</td>
#       <td id="T_a7f54_row2_col3" class="data row2 col3" >0.432</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row3" class="row_heading level0 row3" >side-Ortho-Rank</th>
#       <td id="T_a7f54_row3_col0" class="data row3 col0" >80.533</td>
#       <td id="T_a7f54_row3_col1" class="data row3 col1" >75.384</td>
#       <td id="T_a7f54_row3_col2" class="data row3 col2" >48.461</td>
#       <td id="T_a7f54_row3_col3" class="data row3 col3" >0.876</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row4" class="row_heading level0 row4" >side-None-Rank</th>
#       <td id="T_a7f54_row4_col0" class="data row4 col0" >82.202</td>
#       <td id="T_a7f54_row4_col1" class="data row4 col1" >77.220</td>
#       <td id="T_a7f54_row4_col2" class="data row4 col2" >40.024</td>
#       <td id="T_a7f54_row4_col3" class="data row4 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row5" class="row_heading level0 row5" >side-None-PrefVec</th>
#       <td id="T_a7f54_row5_col0" class="data row5 col0" >28.400</td>
#       <td id="T_a7f54_row5_col1" class="data row5 col1" >23.872</td>
#       <td id="T_a7f54_row5_col2" class="data row5 col2" >38.523</td>
#       <td id="T_a7f54_row5_col3" class="data row5 col3" >0.273</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row6" class="row_heading level0 row6" >side-HRA-PrefVec</th>
#       <td id="T_a7f54_row6_col0" class="data row6 col0" >24.369</td>
#       <td id="T_a7f54_row6_col1" class="data row6 col1" >20.753</td>
#       <td id="T_a7f54_row6_col2" class="data row6 col2" >33.580</td>
#       <td id="T_a7f54_row6_col3" class="data row6 col3" >-0.066</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row7" class="row_heading level0 row7" >side-ETHER-Rank</th>
#       <td id="T_a7f54_row7_col0" class="data row7 col0" >57.042</td>
#       <td id="T_a7f54_row7_col1" class="data row7 col1" >52.891</td>
#       <td id="T_a7f54_row7_col2" class="data row7 col2" >32.688</td>
#       <td id="T_a7f54_row7_col3" class="data row7 col3" >0.695</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row8" class="row_heading level0 row8" >side-Ortho-PrefVec</th>
#       <td id="T_a7f54_row8_col0" class="data row8 col0" >23.436</td>
#       <td id="T_a7f54_row8_col1" class="data row8 col1" >20.063</td>
#       <td id="T_a7f54_row8_col2" class="data row8 col2" >31.756</td>
#       <td id="T_a7f54_row8_col3" class="data row8 col3" >-0.045</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row9" class="row_heading level0 row9" >side-HRA-Rank</th>
#       <td id="T_a7f54_row9_col0" class="data row9 col0" >60.387</td>
#       <td id="T_a7f54_row9_col1" class="data row9 col1" >55.132</td>
#       <td id="T_a7f54_row9_col2" class="data row9 col2" >29.643</td>
#       <td id="T_a7f54_row9_col3" class="data row9 col3" >1.527</td>
#     </tr>
#     <tr>
#       <th id="T_a7f54_level0_row10" class="row_heading level0 row10" >side-SVD-PrefVec</th>
#       <td id="T_a7f54_row10_
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (2, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_bd560_row0_col0 {
#   background-color: #5887c1;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_bd560_row0_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_bd560_row0_col2 {
#   background-color: #f0e4e6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_bd560_row0_col3, #T_bd560_row1_col3, #T_bd560_row2_col3, #T_bd560_row3_col3, #T_bd560_row4_col3, #T_bd560_row5_col3, #T_bd560_row6_col3, #T_bd560_row7_col3, #T_bd560_row8_col3, #T_bd560_row10_col3, #T_bd560_row11_col3, #T_bd560_row12_col3, #T_bd560_row13_col3, #T_bd560_row14_col3, #T_bd560_row15_col3, #T_bd560_row16_col2, #T_bd560_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_bd560_row1_col0, #T_bd560_row9_col0 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
# }
# #T_bd560_row1_col1, #T_bd560_row2_col0, #T_bd560_row3_col0, #T_bd560_row4_col0, #T_bd560_row5_col0, #T_bd560_row6_col2, #T_bd560_row7_col2, #T_bd560_row8_col2, #T_bd560_row9_col1, #T_bd560_row10_col1, #T_bd560_row11_col1, #T_bd560_row12_col1, #T_bd560_row13_col1, #T_bd560_row14_col1, #T_bd560_row15_col1, #T_bd560_row16_col1, #T_bd560_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_bd560_row1_col2 {
#   background-color: #efdade;
#   color: #000000;
# }
# #T_bd560_row2_col1 {
#   background-color: #6892c6;
#   color: #f1f1f1;
# }
# #T_bd560_row2_col2 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_bd560_row3_col1, #T_bd560_row4_col1, #T_bd560_row5_col1, #T_bd560_row10_col0 {
#   background-color: #769ccb;
#   color: #f1f1f1;
# }
# #T_bd560_row3_col2, #T_bd560_row4_col2, #T_bd560_row5_col2 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_bd560_row6_col0, #T_bd560_row7_col0, #T_bd560_row8_col0 {
#   background-color: #8dacd2;
#   color: #f1f1f1;
# }
# #T_bd560_row6_col1, #T_bd560_row7_col1, #T_bd560_row8_col1 {
#   background-color: #a5bcda;
#   color: #000000;
# }
# #T_bd560_row9_col2 {
#   background-color: #e69caa;
#   color: #000000;
# }
# #T_bd560_row9_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_bd560_row10_col2 {
#   background-color: #92b0d4;
#   color: #000000;
# }
# #T_bd560_row11_col0 {
#   background-color: #628ec4;
#   color: #f1f1f1;
# }
# #T_bd560_row11_col2 {
#   background-color: #ecc6ce;
#   color: #000000;
# }
# #T_bd560_row12_col0, #T_bd560_row13_col0, #T_bd560_row14_col0, #T_bd560_row16_col0 {
#   background-color: #6d95c8;
#   color: #f1f1f1;
# }
# #T_bd560_row12_col2, #T_bd560_row13_col2, #T_bd560_row14_col2 {
#   background-color: #eed4d9;
#   color: #000000;
# }
# #T_bd560_row15_col0 {
#   background-color: #86a7d0;
#   color: #f1f1f1;
# }
# #T_bd560_row15_col2 {
#   background-color: #e9b4be;
#   color: #000000;
# }
# #T_bd560_row16_col3 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
# }
# #T_bd560_row17_col0 {
#   background-color: #c0cfe3;
#   color: #000000;
# }
# #T_bd560_row17_col1 {
#   background-color: #a1b9d9;
#   color: #000000;
# }
# </style>
# <table id="T_bd560">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd560_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_bd560_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_bd560_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_bd560_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd560_level0_row0" class="row_heading level0 row0" >dpo</th>
#       <td id="T_bd560_row0_col0" class="data row0 col0" >325.317</td>
#       <td id="T_bd560_row0_col1" class="data row0 col1" >346.639</td>
#       <td id="T_bd560_row0_col2" class="data row0 col2" >159.940</td>
#       <td id="T_bd560_row0_col3" class="data row0 col3" >0.071</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row1" class="row_heading level0 row1" >projgrad</th>
#       <td id="T_bd560_row1_col0" class="data row1 col0" >299.714</td>
#       <td id="T_bd560_row1_col1" class="data row1 col1" >320.749</td>
#       <td id="T_bd560_row1_col2" class="data row1 col2" >139.283</td>
#       <td id="T_bd560_row1_col3" class="data row1 col3" >-0.062</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row2" class="row_heading level0 row2" >side-Ortho-Rank</th>
#       <td id="T_bd560_row2_col0" class="data row2 col0" >70.039</td>
#       <td id="T_bd560_row2_col1" class="data row2 col1" >62.565</td>
#       <td id="T_bd560_row2_col2" class="data row2 col2" >30.594</td>
#       <td id="T_bd560_row2_col3" class="data row2 col3" >-0.148</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row3" class="row_heading level0 row3" >side-ETHER-Rank</th>
#       <td id="T_bd560_row3_col0" class="data row3 col0" >94.977</td>
#       <td id="T_bd560_row3_col1" class="data row3 col1" >81.113</td>
#       <td id="T_bd560_row3_col2" class="data row3 col2" >28.400</td>
#       <td id="T_bd560_row3_col3" class="data row3 col3" >0.059</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row4" class="row_heading level0 row4" >side-None-Rank</th>
#       <td id="T_bd560_row4_col0" class="data row4 col0" >94.977</td>
#       <td id="T_bd560_row4_col1" class="data row4 col1" >81.113</td>
#       <td id="T_bd560_row4_col2" class="data row4 col2" >28.400</td>
#       <td id="T_bd560_row4_col3" class="data row4 col3" >0.059</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row5" class="row_heading level0 row5" >side-SVD-Rank</th>
#       <td id="T_bd560_row5_col0" class="data row5 col0" >94.977</td>
#       <td id="T_bd560_row5_col1" class="data row5 col1" >81.113</td>
#       <td id="T_bd560_row5_col2" class="data row5 col2" >28.400</td>
#       <td id="T_bd560_row5_col3" class="data row5 col3" >0.059</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row6" class="row_heading level0 row6" >side-HRA-PrefVec</th>
#       <td id="T_bd560_row6_col0" class="data row6 col0" >18.882</td>
#       <td id="T_bd560_row6_col1" class="data row6 col1" >17.279</td>
#       <td id="T_bd560_row6_col2" class="data row6 col2" >23.988</td>
#       <td id="T_bd560_row6_col3" class="data row6 col3" >-0.073</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row7" class="row_heading level0 row7" >side-None-PrefVec</th>
#       <td id="T_bd560_row7_col0" class="data row7 col0" >18.882</td>
#       <td id="T_bd560_row7_col1" class="data row7 col1" >17.279</td>
#       <td id="T_bd560_row7_col2" class="data row7 col2" >23.988</td>
#       <td id="T_bd560_row7_col3" class="data row7 col3" >-0.073</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row8" class="row_heading level0 row8" >side-SVD-PrefVec</th>
#       <td id="T_bd560_row8_col0" class="data row8 col0" >18.882</td>
#       <td id="T_bd560_row8_col1" class="data row8 col1" >17.279</td>
#       <td id="T_bd560_row8_col2" class="data row8 col2" >23.988</td>
#       <td id="T_bd560_row8_col3" class="data row8 col3" >-0.073</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row9" class="row_heading level0 row9" >side-HRA-Rank</th>
#       <td id="T_bd560_row9_col0" class="data row9 col0" >56.833</td>
#       <td id="T_bd560_row9_col1" class="data row9 col1" >60.863</td>
#       <td id="T_bd560_row9_col2" class="data row9 col2" >16.074</td>
#       <td id="T_bd560_row9_col3" class="data row9 col3" >0.074</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row10" class="row_heading level0 row10" >side-ETHER-PrefVec</th>
#       <td id="T_bd560_row10_col0" class="data row10 col0" >10.470</td>
#       <td id="T_bd560_row10_col1" class="data row10 col1" >12.315</td>
#       <td id="T_bd560_row10_col2" class="data row10 col2" >9.432</td>
#       <td id="T_bd560_row10_col3" class="data row10 col3" >-0.214</td>
#     </tr>
#     <tr>
#       <th id="T_bd560_level0_row11" class="row_heading level0 row11" >side-Ortho-PrefVec</th>
#       <td id="T_bd560_row11_col0" class="data row11 col0" >11.491</td>
#       <td id="T_bd560_row11_col1" class="data row11 col1" >12.594</td>
#       <td id="T_bd560_row11_col2" cla
