# %%
import re, os, sys, json, time, requests
from pathlib import Path
import pandas as pd
import numpy as np

# TODO just load the parquets and run parse_eval
# or run my own eval

# %%
# TODO load config.json, load eval.parquet
fs = sorted(Path('../outputs').glob('**/eval.parquet'))
fs;

# %%
def load_config(f):
    # print(f.parent.parent.stem)
    config = json.load((f.parent / 'config.json').open())
    log = (f.parent / 'log.txt').open().read()

    # dataframe of all non list/dict/tuple in config
    config_df = pd.DataFrame({k: v for k, v in config.items() if not isinstance(v, (list, dict, tuple))}, index=[0])
    config_df['log'] = log
    config_df['file'] = f
    config_df['ts'] = f.parent.stem
    try:
        _, method, _ = f.parent.parent.stem.split('_', 2) # this is {model}_{method}_{dataset}
    except ValueError as e:
        print(e)
        print(f"cannot split `{f.parent.parent.stem}` from {f} like [f.parent.parent.stem.split('_', 3)]")
        method = ''
    config_df['method'] = method

    # put key cols first
    key_columns = ['dataset', 'base_model']
    columns = key_columns + [c for c in config_df.columns if not c in key_columns]
    return config_df[columns]

configs = [load_config(f) for f in fs]
df_configs = pd.concat(configs)
df_configs
# Out:
# /tmp/ipykernel_1226420/3622691232.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_configs = pd.concat(configs)
#                 dataset                         base_model  verbose    dev  \
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# 0   us_history_textbook  princeton-nlp/Llama-3-Base-8B-SFT        1  False
# ..                  ...                                ...      ...    ...
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        0  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        2   True
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
# 0   us_history_textbook          wassname/llama-3-2-1b-sft        1  False
#
#     load_in_4bit  load_in_8bit  use_gradient_checkpointing  batch_size  \
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0          False         False                       False          16
# ..           ...           ...                         ...         ...
# 0          False         False                       False          16
# 0          False         False                       False          16
# 0           True         False                       False           2
# 0          False         False                       False          16
# 0          False         False                       False          16
#
#     n_samples eval_samples  ...                   ts            method    β  \
# 0        5400         None  ...       20241013042626               dpo  NaN
# 0        5400         None  ...       20241013103646            projbp  0.2
# 0        5400         None  ...       20241013044358          projgrad  0.8
# 0        5400         None  ...       20241013055756      sideETHERMSE  NaN
# 0        5400         None  ...       20241013040725  sideETHERPrefVec  NaN
# ..        ...          ...  ...                  ...               ...  ...
# 0        3600          128  ...  2024-10-05_05-35-47      side-SVD-MSE  NaN
# 0        3600         None  ...  2024-10-11_00-09-35      side-SVD-MSE  NaN
# 0          64          750  ...  2024-10-11_04-36-06      side-SVD-MSE  NaN
# 0        3600         None  ...  2024-10-11_00-05-32  side-SVD-PrefVec  NaN
# 0        3600         None  ...  2024-10-11_00-01-16     side-SVD-Rank  NaN
#
#    reverse_pref  scale_orth neg_slope mag_clip weight_dim collect_input  \
# 0           NaN         NaN       NaN      NaN        NaN           NaN
# 0         False       False       0.8      0.6        NaN           NaN
# 0          True       False       0.0      NaN        1.0           NaN
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# ..          ...         ...       ...      ...        ...           ...
# 0           NaN         NaN       NaN      NaN        NaN         False
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
# 0           NaN         NaN       NaN      NaN        NaN          True
#
#     collect_hs
# 0          NaN
# 0          NaN
# 0          NaN
# 0         True
# 0        False
# ..         ...
# 0        False
# 0         True
# 0         True
# 0         True
# 0         True
#
# [2367 rows x 27 columns]

# %%
# df_evals = [pd.read_parquet(f) for f in fs]
# df_eval = pd.concat(df_evals).reset_index()
# df_eval
from reprpo.training import parse_eval, key_metrics
from tqdm.auto import tqdm

data_acc = []
data_rel_acc = []
data_rel_ppl = []
data_rel_pref = []

for i in tqdm(range(len(fs))):

    df_res2= pd.read_parquet(fs[i])
    config = df_configs.iloc[i]

    ds_alias = dict(list(zip(["train", "test", "oos", "rnd"], df_res2['dataset'].unique())))
    # assert ds_alias['train']==config['dataset']
    assert 'train' in ds_alias['train']
    adapter_name = df_res2[["adapter"]].query('adapter!="base"').values[0, 0]
    df_acc = (
        df_res2.groupby(["dataset", "adapter"], dropna=False)["correct"]
        .mean()
        .unstack()
        .T
    )
    ds_alias_rev = {v:k for k, v in ds_alias.items()}
    df_acc = df_acc.rename(columns=ds_alias_rev)
    
    df_rel = key_metrics(df_res2, adapter_name, ds_alias)
    
    df_acc = df_acc[['train', 'test', 'oos', 'rnd']]

    data_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_acc.iloc[0].to_dict()
    ))
    data_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method='base',
        **df_acc.iloc[1].to_dict()
    ))

    data_rel_acc.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[0].to_dict()
    ))
    data_rel_ppl.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[1].to_dict()
    ))
    data_rel_pref.append(dict(
        base_model=config['base_model'],
        train_dataset=config['dataset'],
        method=adapter_name,
        **df_rel.iloc[2].to_dict()
     ))
# Out:
#   0%|          | 0/2367 [00:00<?, ?it/s]

# %%
import seaborn as sns
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
def style_df(df, caption=''):
    return (df.style
        .background_gradient(cmap, axis=1)
        # .set_caption(caption)
        .format(precision=2)
        .highlight_max(axis=0, props='font-weight:bold;')
    )

# %%
metrics = dict(
    acc=data_acc, 
    rel_acc=data_rel_acc, 
    rel_ppl=data_rel_ppl,
    rel_pref=data_rel_pref,
)

for metric, data in metrics.items():
    print(f'# {metric}:\n')
    for (base_model,train_dataset),df in pd.DataFrame(data).groupby(['base_model', 'train_dataset']):
        print(f'## {base_model} - {train_dataset}')
        df = df.drop(['base_model','train_dataset'], axis='columns')
        df = df.groupby('method', as_index=True).mean().sort_values('oos', ascending=False).dropna(axis=1)
        if (
            (len(df)>2) and 
            (df.std()>0).all()
        ):
                display(style_df(df, f'{metric}: {base_model} {train_dataset}'))
        else:
             print(f'skipped {df.shape}')
            

    print('\n')
# Out:
# # acc:
#
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_easy
# <style type="text/css">
# #T_095f1_row0_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_095f1_row0_col1 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_095f1_row0_col2 {
#   background-color: #e7a8b5;
#   color: #000000;
#   font-weight: bold;
# }
# #T_095f1_row0_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_095f1_row1_col0, #T_095f1_row2_col0, #T_095f1_row3_col0, #T_095f1_row4_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_095f1_row1_col1, #T_095f1_row2_col1, #T_095f1_row3_col1, #T_095f1_row4_col1 {
#   background-color: #5786c1;
#   color: #f1f1f1;
# }
# #T_095f1_row1_col2, #T_095f1_row2_col2, #T_095f1_row3_col2, #T_095f1_row4_col2 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
# }
# #T_095f1_row1_col3, #T_095f1_row2_col3, #T_095f1_row3_col3, #T_095f1_row4_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_095f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_095f1_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_095f1_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_095f1_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_095f1_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_095f1_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_095f1_row0_col0" class="data row0 col0" >0.99</td>
#       <td id="T_095f1_row0_col1" class="data row0 col1" >0.97</td>
#       <td id="T_095f1_row0_col2" class="data row0 col2" >0.76</td>
#       <td id="T_095f1_row0_col3" class="data row0 col3" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_095f1_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_095f1_row1_col0" class="data row1 col0" >0.97</td>
#       <td id="T_095f1_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_095f1_row1_col2" class="data row1 col2" >0.74</td>
#       <td id="T_095f1_row1_col3" class="data row1 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_095f1_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_095f1_row2_col0" class="data row2 col0" >0.97</td>
#       <td id="T_095f1_row2_col1" class="data row2 col1" >0.96</td>
#       <td id="T_095f1_row2_col2" class="data row2 col2" >0.74</td>
#       <td id="T_095f1_row2_col3" class="data row2 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_095f1_level0_row3" class="row_heading level0 row3" >side-ETHER-PrefVec</th>
#       <td id="T_095f1_row3_col0" class="data row3 col0" >0.97</td>
#       <td id="T_095f1_row3_col1" class="data row3 col1" >0.96</td>
#       <td id="T_095f1_row3_col2" class="data row3 col2" >0.74</td>
#       <td id="T_095f1_row3_col3" class="data row3 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_095f1_level0_row4" class="row_heading level0 row4" >side-None-PrefVec</th>
#       <td id="T_095f1_row4_col0" class="data row4 col0" >0.97</td>
#       <td id="T_095f1_row4_col1" class="data row4 col1" >0.96</td>
#       <td id="T_095f1_row4_col2" class="data row4 col2" >0.74</td>
#       <td id="T_095f1_row4_col3" class="data row4 col3" >0.68</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_low_quality
# <style type="text/css">
# #T_99cd5_row0_col0, #T_99cd5_row0_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_99cd5_row0_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_99cd5_row0_col3 {
#   background-color: #b2c6de;
#   color: #000000;
#   font-weight: bold;
# }
# #T_99cd5_row1_col0, #T_99cd5_row2_col0, #T_99cd5_row3_col0, #T_99cd5_row4_col0 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_99cd5_row1_col1, #T_99cd5_row2_col1, #T_99cd5_row3_col1, #T_99cd5_row4_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_99cd5_row1_col2, #T_99cd5_row2_col2, #T_99cd5_row3_col2, #T_99cd5_row4_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_99cd5_row1_col3, #T_99cd5_row2_col3, #T_99cd5_row3_col3, #T_99cd5_row4_col3 {
#   background-color: #98b3d6;
#   color: #000000;
# }
# </style>
# <table id="T_99cd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99cd5_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_99cd5_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_99cd5_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_99cd5_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99cd5_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_99cd5_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_99cd5_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_99cd5_row0_col2" class="data row0 col2" >0.11</td>
#       <td id="T_99cd5_row0_col3" class="data row0 col3" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_99cd5_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_99cd5_row1_col0" class="data row1 col0" >0.83</td>
#       <td id="T_99cd5_row1_col1" class="data row1 col1" >0.86</td>
#       <td id="T_99cd5_row1_col2" class="data row1 col2" >0.11</td>
#       <td id="T_99cd5_row1_col3" class="data row1 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_99cd5_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_99cd5_row2_col0" class="data row2 col0" >0.83</td>
#       <td id="T_99cd5_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_99cd5_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_99cd5_row2_col3" class="data row2 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_99cd5_level0_row3" class="row_heading level0 row3" >side-ETHER-PrefVec</th>
#       <td id="T_99cd5_row3_col0" class="data row3 col0" >0.83</td>
#       <td id="T_99cd5_row3_col1" class="data row3 col1" >0.86</td>
#       <td id="T_99cd5_row3_col2" class="data row3 col2" >0.11</td>
#       <td id="T_99cd5_row3_col3" class="data row3 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_99cd5_level0_row4" class="row_heading level0 row4" >side-None-PrefVec</th>
#       <td id="T_99cd5_row4_col0" class="data row4 col0" >0.83</td>
#       <td id="T_99cd5_row4_col1" class="data row4 col1" >0.86</td>
#       <td id="T_99cd5_row4_col2" class="data row4 col2" >0.11</td>
#       <td id="T_99cd5_row4_col3" class="data row4 col3" >0.68</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_mmlu
# <style type="text/css">
# #T_769a3_row0_col0, #T_769a3_row1_col3, #T_769a3_row2_col3, #T_769a3_row3_col3, #T_769a3_row4_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_769a3_row0_col1 {
#   background-color: #edd0d6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_769a3_row0_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_769a3_row0_col3 {
#   background-color: #da4d69;
#   color: #f1f1f1;
# }
# #T_769a3_row1_col0, #T_769a3_row2_col0, #T_769a3_row3_col0, #T_769a3_row4_col0 {
#   background-color: #82a4cf;
#   color: #f1f1f1;
# }
# #T_769a3_row1_col1, #T_769a3_row2_col1, #T_769a3_row3_col1, #T_769a3_row4_col1 {
#   background-color: #dbe2eb;
#   color: #000000;
# }
# #T_769a3_row1_col2, #T_769a3_row2_col2, #T_769a3_row3_col2, #T_769a3_row4_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_769a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_769a3_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_769a3_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_769a3_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_769a3_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_769a3_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_769a3_row0_col0" class="data row0 col0" >0.91</td>
#       <td id="T_769a3_row0_col1" class="data row0 col1" >0.81</td>
#       <td id="T_769a3_row0_col2" class="data row0 col2" >0.74</td>
#       <td id="T_769a3_row0_col3" class="data row0 col3" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_769a3_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_769a3_row1_col0" class="data row1 col0" >0.78</td>
#       <td id="T_769a3_row1_col1" class="data row1 col1" >0.75</td>
#       <td id="T_769a3_row1_col2" class="data row1 col2" >0.70</td>
#       <td id="T_769a3_row1_col3" class="data row1 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_769a3_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_769a3_row2_col0" class="data row2 col0" >0.78</td>
#       <td id="T_769a3_row2_col1" class="data row2 col1" >0.75</td>
#       <td id="T_769a3_row2_col2" class="data row2 col2" >0.70</td>
#       <td id="T_769a3_row2_col3" class="data row2 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_769a3_level0_row3" class="row_heading level0 row3" >side-ETHER-PrefVec</th>
#       <td id="T_769a3_row3_col0" class="data row3 col0" >0.78</td>
#       <td id="T_769a3_row3_col1" class="data row3 col1" >0.75</td>
#       <td id="T_769a3_row3_col2" class="data row3 col2" >0.70</td>
#       <td id="T_769a3_row3_col3" class="data row3 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_769a3_level0_row4" class="row_heading level0 row4" >side-None-PrefVec</th>
#       <td id="T_769a3_row4_col0" class="data row4 col0" >0.78</td>
#       <td id="T_769a3_row4_col1" class="data row4 col1" >0.75</td>
#       <td id="T_769a3_row4_col2" class="data row4 col2" >0.70</td>
#       <td id="T_769a3_row4_col3" class="data row4 col3" >0.80</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_short
# skipped (2, 4)
# ## princeton-nlp/Llama-3-Base-8B-SFT - us_history_textbook
# <style type="text/css">
# #T_ec24a_row0_col0, #T_ec24a_row0_col1, #T_ec24a_row8_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_ec24a_row0_col2 {
#   background-color: #d5deea;
#   color: #000000;
#   font-weight: bold;
# }
# #T_ec24a_row0_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_ec24a_row1_col0, #T_ec24a_row2_col0, #T_ec24a_row3_col0, #T_ec24a_row4_col0, #T_ec24a_row5_col0, #T_ec24a_row6_col0, #T_ec24a_row7_col0, #T_ec24a_row8_col0, #T_ec24a_row9_col0, #T_ec24a_row10_col0, #T_ec24a_row11_col0, #T_ec24a_row12_col0, #T_ec24a_row13_col0, #T_ec24a_row14_col0, #T_ec24a_row15_col0, #T_ec24a_row16_col0, #T_ec24a_row17_col0, #T_ec24a_row18_col0 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ec24a_row1_col1, #T_ec24a_row2_col1, #T_ec24a_row3_col1, #T_ec24a_row4_col1, #T_ec24a_row5_col1, #T_ec24a_row6_col1, #T_ec24a_row7_col1, #T_ec24a_row9_col1, #T_ec24a_row10_col1, #T_ec24a_row11_col1, #T_ec24a_row12_col1, #T_ec24a_row13_col1, #T_ec24a_row14_col1, #T_ec24a_row15_col1, #T_ec24a_row16_col1, #T_ec24a_row17_col1, #T_ec24a_row18_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ec24a_row1_col2, #T_ec24a_row2_col2, #T_ec24a_row3_col2, #T_ec24a_row4_col2, #T_ec24a_row5_col2, #T_ec24a_row6_col2, #T_ec24a_row7_col2, #T_ec24a_row8_col2, #T_ec24a_row9_col2, #T_ec24a_row10_col2, #T_ec24a_row11_col2, #T_ec24a_row12_col2, #T_ec24a_row13_col2, #T_ec24a_row14_col2, #T_ec24a_row15_col2, #T_ec24a_row16_col2, #T_ec24a_row17_col2, #T_ec24a_row18_col2 {
#   background-color: #ecc6ce;
#   color: #000000;
# }
# #T_ec24a_row1_col3, #T_ec24a_row2_col3, #T_ec24a_row3_col3, #T_ec24a_row4_col3, #T_ec24a_row5_col3, #T_ec24a_row6_col3, #T_ec24a_row7_col3, #T_ec24a_row8_col3, #T_ec24a_row9_col3, #T_ec24a_row10_col3, #T_ec24a_row11_col3, #T_ec24a_row12_col3, #T_ec24a_row13_col3, #T_ec24a_row14_col3, #T_ec24a_row15_col3, #T_ec24a_row16_col3, #T_ec24a_row17_col3, #T_ec24a_row18_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_ec24a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec24a_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_ec24a_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_ec24a_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_ec24a_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec24a_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_ec24a_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_ec24a_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_ec24a_row0_col2" class="data row0 col2" >0.84</td>
#       <td id="T_ec24a_row0_col3" class="data row0 col3" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_ec24a_row1_col0" class="data row1 col0" >0.99</td>
#       <td id="T_ec24a_row1_col1" class="data row1 col1" >0.99</td>
#       <td id="T_ec24a_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_ec24a_row1_col3" class="data row1 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row2" class="row_heading level0 row2" >side-SVD-PrefVec</th>
#       <td id="T_ec24a_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_ec24a_row2_col1" class="data row2 col1" >0.99</td>
#       <td id="T_ec24a_row2_col2" class="data row2 col2" >0.80</td>
#       <td id="T_ec24a_row2_col3" class="data row2 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row3" class="row_heading level0 row3" >side-Ortho-Rank</th>
#       <td id="T_ec24a_row3_col0" class="data row3 col0" >0.99</td>
#       <td id="T_ec24a_row3_col1" class="data row3 col1" >0.99</td>
#       <td id="T_ec24a_row3_col2" class="data row3 col2" >0.80</td>
#       <td id="T_ec24a_row3_col3" class="data row3 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row4" class="row_heading level0 row4" >side-Ortho-PrefVec</th>
#       <td id="T_ec24a_row4_col0" class="data row4 col0" >0.99</td>
#       <td id="T_ec24a_row4_col1" class="data row4 col1" >0.99</td>
#       <td id="T_ec24a_row4_col2" class="data row4 col2" >0.80</td>
#       <td id="T_ec24a_row4_col3" class="data row4 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row5" class="row_heading level0 row5" >side-Ortho-MSE</th>
#       <td id="T_ec24a_row5_col0" class="data row5 col0" >0.99</td>
#       <td id="T_ec24a_row5_col1" class="data row5 col1" >0.99</td>
#       <td id="T_ec24a_row5_col2" class="data row5 col2" >0.80</td>
#       <td id="T_ec24a_row5_col3" class="data row5 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row6" class="row_heading level0 row6" >side-None-Rank</th>
#       <td id="T_ec24a_row6_col0" class="data row6 col0" >0.99</td>
#       <td id="T_ec24a_row6_col1" class="data row6 col1" >0.99</td>
#       <td id="T_ec24a_row6_col2" class="data row6 col2" >0.80</td>
#       <td id="T_ec24a_row6_col3" class="data row6 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row7" class="row_heading level0 row7" >side-SVD-Rank</th>
#       <td id="T_ec24a_row7_col0" class="data row7 col0" >0.99</td>
#       <td id="T_ec24a_row7_col1" class="data row7 col1" >0.99</td>
#       <td id="T_ec24a_row7_col2" class="data row7 col2" >0.80</td>
#       <td id="T_ec24a_row7_col3" class="data row7 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row8" class="row_heading level0 row8" >side-ETHER-PrefVec</th>
#       <td id="T_ec24a_row8_col0" class="data row8 col0" >0.99</td>
#       <td id="T_ec24a_row8_col1" class="data row8 col1" >0.99</td>
#       <td id="T_ec24a_row8_col2" class="data row8 col2" >0.80</td>
#       <td id="T_ec24a_row8_col3" class="data row8 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row9" class="row_heading level0 row9" >side-HRA-PrefVec</th>
#       <td id="T_ec24a_row9_col0" class="data row9 col0" >0.99</td>
#       <td id="T_ec24a_row9_col1" class="data row9 col1" >0.99</td>
#       <td id="T_ec24a_row9_col2" class="data row9 col2" >0.80</td>
#       <td id="T_ec24a_row9_col3" class="data row9 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row10" class="row_heading level0 row10" >side-HRA-MSE</th>
#       <td id="T_ec24a_row10_col0" class="data row10 col0" >0.99</td>
#       <td id="T_ec24a_row10_col1" class="data row10 col1" >0.99</td>
#       <td id="T_ec24a_row10_col2" class="data row10 col2" >0.80</td>
#       <td id="T_ec24a_row10_col3" class="data row10 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row11" class="row_heading level0 row11" >side-None-MSE</th>
#       <td id="T_ec24a_row11_col0" class="data row11 col0" >0.99</td>
#       <td id="T_ec24a_row11_col1" class="data row11 col1" >0.99</td>
#       <td id="T_ec24a_row11_col2" class="data row11 col2" >0.80</td>
#       <td id="T_ec24a_row11_col3" class="data row11 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row12" class="row_heading level0 row12" >side-None-PrefVec</th>
#       <td id="T_ec24a_row12_col0" class="data row12 col0" >0.99</td>
#       <td id="T_ec24a_row12_col1" class="data row12 col1" >0.99</td>
#       <td id="T_ec24a_row12_col2" class="data row12 col2" >0.80</td>
#       <td id="T_ec24a_row12_col3" class="data row12 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_level0_row13" class="row_heading level0 row13" >side-ETHER-Rank</th>
#       <td id="T_ec24a_row13_col0" class="data row13 col0" >0.99</td>
#       <td id="T_ec24a_row13_col1" class="data row13 col1" >0.99</td>
#       <td id="T_ec24a_row13_col2" class="data row13 col2" >0.80</td>
#       <td id="T_ec24a_row13_col3" class="data row13 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_ec24a_le
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (3, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_05735_row0_col0 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_05735_row0_col1, #T_05735_row1_col1, #T_05735_row2_col1, #T_05735_row3_col1, #T_05735_row4_col1, #T_05735_row5_col1, #T_05735_row6_col1, #T_05735_row7_col1, #T_05735_row8_col1, #T_05735_row10_col1, #T_05735_row11_col1, #T_05735_row12_col1, #T_05735_row13_col1, #T_05735_row14_col1, #T_05735_row15_col1, #T_05735_row16_col1, #T_05735_row17_col1, #T_05735_row18_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_05735_row0_col2 {
#   background-color: #f1e5e7;
#   color: #000000;
#   font-weight: bold;
# }
# #T_05735_row0_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_05735_row1_col0, #T_05735_row6_col0, #T_05735_row9_col0, #T_05735_row10_col0, #T_05735_row15_col0, #T_05735_row16_col0 {
#   background-color: #608dc4;
#   color: #f1f1f1;
# }
# #T_05735_row1_col2, #T_05735_row2_col2, #T_05735_row6_col2, #T_05735_row9_col2, #T_05735_row10_col2, #T_05735_row15_col2, #T_05735_row16_col2 {
#   background-color: #f0e0e3;
#   color: #000000;
# }
# #T_05735_row1_col3, #T_05735_row2_col3, #T_05735_row3_col3, #T_05735_row4_col3, #T_05735_row5_col3, #T_05735_row6_col3, #T_05735_row7_col3, #T_05735_row8_col3, #T_05735_row9_col3, #T_05735_row10_col3, #T_05735_row11_col3, #T_05735_row12_col3, #T_05735_row13_col3, #T_05735_row14_col3, #T_05735_row15_col3, #T_05735_row16_col3, #T_05735_row17_col3, #T_05735_row18_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_05735_row2_col0 {
#   background-color: #5f8cc3;
#   color: #f1f1f1;
# }
# #T_05735_row3_col0, #T_05735_row4_col0, #T_05735_row5_col0, #T_05735_row7_col0, #T_05735_row8_col0, #T_05735_row9_col1, #T_05735_row11_col0, #T_05735_row12_col0, #T_05735_row13_col0, #T_05735_row14_col0, #T_05735_row17_col0, #T_05735_row18_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_05735_row3_col2, #T_05735_row4_col2, #T_05735_row5_col2, #T_05735_row7_col2, #T_05735_row8_col2, #T_05735_row11_col2, #T_05735_row12_col2, #T_05735_row13_col2, #T_05735_row14_col2, #T_05735_row17_col2, #T_05735_row18_col2 {
#   background-color: #efdde0;
#   color: #000000;
# }
# </style>
# <table id="T_05735">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05735_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_05735_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_05735_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_05735_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05735_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_05735_row0_col0" class="data row0 col0" >0.94</td>
#       <td id="T_05735_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_05735_row0_col2" class="data row0 col2" >0.70</td>
#       <td id="T_05735_row0_col3" class="data row0 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_05735_row1_col0" class="data row1 col0" >0.95</td>
#       <td id="T_05735_row1_col1" class="data row1 col1" >0.99</td>
#       <td id="T_05735_row1_col2" class="data row1 col2" >0.69</td>
#       <td id="T_05735_row1_col3" class="data row1 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row2" class="row_heading level0 row2" >side-SVD-MSE</th>
#       <td id="T_05735_row2_col0" class="data row2 col0" >0.95</td>
#       <td id="T_05735_row2_col1" class="data row2 col1" >0.99</td>
#       <td id="T_05735_row2_col2" class="data row2 col2" >0.69</td>
#       <td id="T_05735_row2_col3" class="data row2 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_05735_row3_col0" class="data row3 col0" >0.97</td>
#       <td id="T_05735_row3_col1" class="data row3 col1" >0.97</td>
#       <td id="T_05735_row3_col2" class="data row3 col2" >0.69</td>
#       <td id="T_05735_row3_col3" class="data row3 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row4" class="row_heading level0 row4" >side-SVD-PrefVec</th>
#       <td id="T_05735_row4_col0" class="data row4 col0" >0.97</td>
#       <td id="T_05735_row4_col1" class="data row4 col1" >0.97</td>
#       <td id="T_05735_row4_col2" class="data row4 col2" >0.69</td>
#       <td id="T_05735_row4_col3" class="data row4 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row5" class="row_heading level0 row5" >side-Ortho-Rank</th>
#       <td id="T_05735_row5_col0" class="data row5 col0" >0.97</td>
#       <td id="T_05735_row5_col1" class="data row5 col1" >0.97</td>
#       <td id="T_05735_row5_col2" class="data row5 col2" >0.69</td>
#       <td id="T_05735_row5_col3" class="data row5 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row6" class="row_heading level0 row6" >side-Ortho-PrefVec</th>
#       <td id="T_05735_row6_col0" class="data row6 col0" >0.95</td>
#       <td id="T_05735_row6_col1" class="data row6 col1" >0.99</td>
#       <td id="T_05735_row6_col2" class="data row6 col2" >0.69</td>
#       <td id="T_05735_row6_col3" class="data row6 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row7" class="row_heading level0 row7" >side-Ortho-MSE</th>
#       <td id="T_05735_row7_col0" class="data row7 col0" >0.97</td>
#       <td id="T_05735_row7_col1" class="data row7 col1" >0.97</td>
#       <td id="T_05735_row7_col2" class="data row7 col2" >0.69</td>
#       <td id="T_05735_row7_col3" class="data row7 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row8" class="row_heading level0 row8" >side-None-Rank</th>
#       <td id="T_05735_row8_col0" class="data row8 col0" >0.97</td>
#       <td id="T_05735_row8_col1" class="data row8 col1" >0.97</td>
#       <td id="T_05735_row8_col2" class="data row8 col2" >0.69</td>
#       <td id="T_05735_row8_col3" class="data row8 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row9" class="row_heading level0 row9" >side-HRA-Rank</th>
#       <td id="T_05735_row9_col0" class="data row9 col0" >0.95</td>
#       <td id="T_05735_row9_col1" class="data row9 col1" >0.99</td>
#       <td id="T_05735_row9_col2" class="data row9 col2" >0.69</td>
#       <td id="T_05735_row9_col3" class="data row9 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row10" class="row_heading level0 row10" >dpo</th>
#       <td id="T_05735_row10_col0" class="data row10 col0" >0.95</td>
#       <td id="T_05735_row10_col1" class="data row10 col1" >0.99</td>
#       <td id="T_05735_row10_col2" class="data row10 col2" >0.69</td>
#       <td id="T_05735_row10_col3" class="data row10 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row11" class="row_heading level0 row11" >side-HRA-PrefVec</th>
#       <td id="T_05735_row11_col0" class="data row11 col0" >0.97</td>
#       <td id="T_05735_row11_col1" class="data row11 col1" >0.97</td>
#       <td id="T_05735_row11_col2" class="data row11 col2" >0.69</td>
#       <td id="T_05735_row11_col3" class="data row11 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row12" class="row_heading level0 row12" >side-HRA-MSE</th>
#       <td id="T_05735_row12_col0" class="data row12 col0" >0.97</td>
#       <td id="T_05735_row12_col1" class="data row12 col1" >0.97</td>
#       <td id="T_05735_row12_col2" class="data row12 col2" >0.69</td>
#       <td id="T_05735_row12_col3" class="data row12 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_05735_level0_row13" class="row_heading level0 row13" >side-ETHER-Rank</th>
#       <td id="T_05735_row13_col0" class="data row13 col0" >0.97</td>
#       <td id="T_05735_row13_col1" class="data row13 col1" >0.97</td>
#       <td id="T_05735_row13_col2" class="data row13 c
# # rel_acc:
#
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_easy
# <style type="text/css">
# #T_cdff1_row0_col0 {
#   background-color: #98b3d6;
#   color: #000000;
# }
# #T_cdff1_row0_col1 {
#   background-color: #c5d3e4;
#   color: #000000;
# }
# #T_cdff1_row0_col2, #T_cdff1_row2_col1, #T_cdff1_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_cdff1_row0_col3, #T_cdff1_row1_col3, #T_cdff1_row3_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_cdff1_row1_col0 {
#   background-color: #b2c6de;
#   color: #000000;
# }
# #T_cdff1_row1_col1 {
#   background-color: #eed4d9;
#   color: #000000;
# }
# #T_cdff1_row1_col2 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_cdff1_row2_col0 {
#   background-color: #5383bf;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_cdff1_row2_col2 {
#   background-color: #6b94c7;
#   color: #f1f1f1;
# }
# #T_cdff1_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_cdff1_row3_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_cdff1_row3_col2 {
#   background-color: #dce3ec;
#   color: #000000;
# }
# </style>
# <table id="T_cdff1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdff1_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_cdff1_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_cdff1_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_cdff1_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdff1_level0_row0" class="row_heading level0 row0" >side-None-PrefVec</th>
#       <td id="T_cdff1_row0_col0" class="data row0 col0" >1.01</td>
#       <td id="T_cdff1_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_cdff1_row0_col2" class="data row0 col2" >1.04</td>
#       <td id="T_cdff1_row0_col3" class="data row0 col3" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_cdff1_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_cdff1_row1_col0" class="data row1 col0" >1.01</td>
#       <td id="T_cdff1_row1_col1" class="data row1 col1" >0.99</td>
#       <td id="T_cdff1_row1_col2" class="data row1 col2" >1.04</td>
#       <td id="T_cdff1_row1_col3" class="data row1 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_cdff1_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_cdff1_row2_col0" class="data row2 col0" >1.03</td>
#       <td id="T_cdff1_row2_col1" class="data row2 col1" >1.03</td>
#       <td id="T_cdff1_row2_col2" class="data row2 col2" >1.02</td>
#       <td id="T_cdff1_row2_col3" class="data row2 col3" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_cdff1_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_cdff1_row3_col0" class="data row3 col0" >1.03</td>
#       <td id="T_cdff1_row3_col1" class="data row3 col1" >1.02</td>
#       <td id="T_cdff1_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_cdff1_row3_col3" class="data row3 col3" >0.96</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_low_quality
# <style type="text/css">
# #T_3f05a_row0_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_3f05a_row0_col1 {
#   background-color: #b0c4dd;
#   color: #000000;
# }
# #T_3f05a_row0_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_3f05a_row0_col3 {
#   background-color: #dc5c76;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_3f05a_row1_col0, #T_3f05a_row2_col0, #T_3f05a_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_3f05a_row1_col1 {
#   background-color: #b1c5de;
#   color: #000000;
# }
# #T_3f05a_row1_col2 {
#   background-color: #e7a5b2;
#   color: #000000;
#   font-weight: bold;
# }
# #T_3f05a_row1_col3, #T_3f05a_row2_col3, #T_3f05a_row3_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_3f05a_row2_col1 {
#   background-color: #abc1dc;
#   color: #000000;
# }
# #T_3f05a_row2_col2 {
#   background-color: #d94764;
#   color: #f1f1f1;
# }
# #T_3f05a_row3_col1 {
#   background-color: #94b0d4;
#   color: #000000;
#   font-weight: bold;
# }
# #T_3f05a_row3_col3 {
#   background-color: #df7288;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f05a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f05a_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_3f05a_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_3f05a_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_3f05a_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f05a_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_3f05a_row0_col0" class="data row0 col0" >1.20</td>
#       <td id="T_3f05a_row0_col1" class="data row0 col1" >1.15</td>
#       <td id="T_3f05a_row0_col2" class="data row0 col2" >1.02</td>
#       <td id="T_3f05a_row0_col3" class="data row0 col3" >1.04</td>
#     </tr>
#     <tr>
#       <th id="T_3f05a_level0_row1" class="row_heading level0 row1" >side-ETHER-PrefVec</th>
#       <td id="T_3f05a_row1_col0" class="data row1 col0" >1.10</td>
#       <td id="T_3f05a_row1_col1" class="data row1 col1" >1.07</td>
#       <td id="T_3f05a_row1_col2" class="data row1 col2" >1.02</td>
#       <td id="T_3f05a_row1_col3" class="data row1 col3" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_3f05a_level0_row2" class="row_heading level0 row2" >side-None-PrefVec</th>
#       <td id="T_3f05a_row2_col0" class="data row2 col0" >1.09</td>
#       <td id="T_3f05a_row2_col1" class="data row2 col1" >1.06</td>
#       <td id="T_3f05a_row2_col2" class="data row2 col2" >1.01</td>
#       <td id="T_3f05a_row2_col3" class="data row2 col3" >1.01</td>
#     </tr>
#     <tr>
#       <th id="T_3f05a_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_3f05a_row3_col0" class="data row3 col0" >1.20</td>
#       <td id="T_3f05a_row3_col1" class="data row3 col1" >1.15</td>
#       <td id="T_3f05a_row3_col2" class="data row3 col2" >0.98</td>
#       <td id="T_3f05a_row3_col3" class="data row3 col3" >1.01</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_mmlu
# <style type="text/css">
# #T_9ee75_row0_col0, #T_9ee75_row2_col0, #T_9ee75_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_9ee75_row0_col1 {
#   background-color: #edeef1;
#   color: #000000;
#   font-weight: bold;
# }
# #T_9ee75_row0_col2 {
#   background-color: #f1e7e9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_9ee75_row0_col3, #T_9ee75_row1_col3, #T_9ee75_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_9ee75_row1_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_9ee75_row1_col1 {
#   background-color: #dce3ec;
#   color: #000000;
#   font-weight: bold;
# }
# #T_9ee75_row1_col2 {
#   background-color: #f0e1e4;
#   color: #000000;
# }
# #T_9ee75_row2_col1 {
#   background-color: #8eadd3;
#   color: #f1f1f1;
# }
# #T_9ee75_row2_col2 {
#   background-color: #7ea1cd;
#   color: #f1f1f1;
# }
# #T_9ee75_row3_col1 {
#   background-color: #99b4d6;
#   color: #000000;
# }
# #T_9ee75_row3_col2 {
#   background-color: #ebc2ca;
#   color: #000000;
# }
# #T_9ee75_row3_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_9ee75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ee75_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_9ee75_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_9ee75_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_9ee75_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ee75_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_9ee75_row0_col0" class="data row0 col0" >1.25</td>
#       <td id="T_9ee75_row0_col1" class="data row0 col1" >1.10</td>
#       <td id="T_9ee75_row0_col2" class="data row0 col2" >1.09</td>
#       <td id="T_9ee75_row0_col3" class="data row0 col3" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_9ee75_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_9ee75_row1_col0" class="data row1 col0" >1.25</td>
#       <td id="T_9ee75_row1_col1" class="data row1 col1" >1.10</td>
#       <td id="T_9ee75_row1_col2" class="data row1 col2" >1.06</td>
#       <td id="T_9ee75_row1_col3" class="data row1 col3" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_9ee75_level0_row2" class="row_heading level0 row2" >side-ETHER-PrefVec</th>
#       <td id="T_9ee75_row2_col0" class="data row2 col0" >1.07</td>
#       <td id="T_9ee75_row2_col1" class="data row2 col1" >1.05</td>
#       <td id="T_9ee75_row2_col2" class="data row2 col2" >1.05</td>
#       <td id="T_9ee75_row2_col3" class="data row2 col3" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_9ee75_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_9ee75_row3_col0" class="data row3 col0" >1.07</td>
#       <td id="T_9ee75_row3_col1" class="data row3 col1" >1.05</td>
#       <td id="T_9ee75_row3_col2" class="data row3 col2" >1.02</td>
#       <td id="T_9ee75_row3_col3" class="data row3 col3" >0.99</td>
#     </tr>
#   </tbody>
# </table>
# ## princeton-nlp/Llama-3-Base-8B-SFT - alpaca_short
# skipped (1, 4)
# ## princeton-nlp/Llama-3-Base-8B-SFT - us_history_textbook
# <style type="text/css">
# #T_22bc8_row0_col0 {
#   background-color: #eab8c2;
#   color: #000000;
# }
# #T_22bc8_row0_col1 {
#   background-color: #eab7c1;
#   color: #000000;
#   font-weight: bold;
# }
# #T_22bc8_row0_col2 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_22bc8_row0_col3, #T_22bc8_row1_col3, #T_22bc8_row2_col3, #T_22bc8_row3_col3, #T_22bc8_row4_col3, #T_22bc8_row5_col1, #T_22bc8_row6_col1, #T_22bc8_row7_col3, #T_22bc8_row8_col3, #T_22bc8_row9_col3, #T_22bc8_row10_col3, #T_22bc8_row11_col3, #T_22bc8_row12_col3, #T_22bc8_row13_col3, #T_22bc8_row14_col3, #T_22bc8_row15_col3, #T_22bc8_row16_col3, #T_22bc8_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_22bc8_row1_col0 {
#   background-color: #e9b4be;
#   color: #000000;
# }
# #T_22bc8_row1_col1 {
#   background-color: #e9b2bd;
#   color: #000000;
#   font-weight: bold;
# }
# #T_22bc8_row1_col2, #T_22bc8_row2_col2, #T_22bc8_row3_col2, #T_22bc8_row4_col2, #T_22bc8_row5_col2, #T_22bc8_row6_col2, #T_22bc8_row7_col2, #T_22bc8_row8_col2, #T_22bc8_row9_col2, #T_22bc8_row10_col2, #T_22bc8_row11_col2, #T_22bc8_row12_col2, #T_22bc8_row13_col2, #T_22bc8_row14_col2, #T_22bc8_row15_col2, #T_22bc8_row16_col2, #T_22bc8_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_22bc8_row2_col0 {
#   background-color: #e9b2bd;
#   color: #000000;
# }
# #T_22bc8_row2_col1 {
#   background-color: #e8aeba;
#   color: #000000;
# }
# #T_22bc8_row3_col0 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
# }
# #T_22bc8_row3_col1, #T_22bc8_row10_col0 {
#   background-color: #e28497;
#   color: #f1f1f1;
# }
# #T_22bc8_row4_col0, #T_22bc8_row4_col1 {
#   background-color: #e7a3b0;
#   color: #000000;
# }
# #T_22bc8_row5_col0 {
#   background-color: #da4b68;
#   color: #f1f1f1;
# }
# #T_22bc8_row5_col3 {
#   background-color: #e597a7;
#   color: #000000;
#   font-weight: bold;
# }
# #T_22bc8_row6_col0 {
#   background-color: #da4d69;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_22bc8_row6_col3 {
#   background-color: #de6c83;
#   color: #f1f1f1;
# }
# #T_22bc8_row7_col0 {
#   background-color: #cbd7e6;
#   color: #000000;
# }
# #T_22bc8_row7_col1 {
#   background-color: #dbe2eb;
#   color: #000000;
# }
# #T_22bc8_row8_col0 {
#   background-color: #edcfd5;
#   color: #000000;
# }
# #T_22bc8_row8_col1 {
#   background-color: #e9afbb;
#   color: #000000;
# }
# #T_22bc8_row9_col0, #T_22bc8_row13_col0, #T_22bc8_row14_col0 {
#   background-color: #e6a0ae;
#   color: #000000;
# }
# #T_22bc8_row9_col1 {
#   background-color: #e9b5bf;
#   color: #000000;
# }
# #T_22bc8_row10_col1 {
#   background-color: #e69caa;
#   color: #000000;
# }
# #T_22bc8_row11_col0 {
#   background-color: #e7a4b1;
#   color: #000000;
# }
# #T_22bc8_row11_col1, #T_22bc8_row13_col1 {
#   background-color: #eab9c3;
#   color: #000000;
# }
# #T_22bc8_row12_col0 {
#   background-color: #c0cfe3;
#   color: #000000;
# }
# #T_22bc8_row12_col1 {
#   background-color: #dae1eb;
#   color: #000000;
# }
# #T_22bc8_row14_col1 {
#   background-color: #eabbc4;
#   color: #000000;
# }
# #T_22bc8_row15_col0 {
#   background-color: #edd0d6;
#   color: #000000;
# }
# #T_22bc8_row15_col1 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_22bc8_row16_col0 {
#   background-color: #6892c6;
#   color: #f1f1f1;
# }
# #T_22bc8_row16_col1 {
#   background-color: #8aaad1;
#   color: #f1f1f1;
# }
# #T_22bc8_row17_col0 {
#   background-color: #96b2d5;
#   color: #000000;
# }
# #T_22bc8_row17_col1 {
#   background-color: #8eadd3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_22bc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22bc8_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_22bc8_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_22bc8_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_22bc8_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22bc8_level0_row0" class="row_heading level0 row0" >side-HRA-PrefVec</th>
#       <td id="T_22bc8_row0_col0" class="data row0 col0" >1.01</td>
#       <td id="T_22bc8_row0_col1" class="data row0 col1" >1.01</td>
#       <td id="T_22bc8_row0_col2" class="data row0 col2" >1.13</td>
#       <td id="T_22bc8_row0_col3" class="data row0 col3" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row1" class="row_heading level0 row1" >side-Ortho-PrefVec</th>
#       <td id="T_22bc8_row1_col0" class="data row1 col0" >1.01</td>
#       <td id="T_22bc8_row1_col1" class="data row1 col1" >1.01</td>
#       <td id="T_22bc8_row1_col2" class="data row1 col2" >1.13</td>
#       <td id="T_22bc8_row1_col3" class="data row1 col3" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row2" class="row_heading level0 row2" >side-SVD-PrefVec</th>
#       <td id="T_22bc8_row2_col0" class="data row2 col0" >1.01</td>
#       <td id="T_22bc8_row2_col1" class="data row2 col1" >1.01</td>
#       <td id="T_22bc8_row2_col2" class="data row2 col2" >1.13</td>
#       <td id="T_22bc8_row2_col3" class="data row2 col3" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row3" class="row_heading level0 row3" >side-None-PrefVec</th>
#       <td id="T_22bc8_row3_col0" class="data row3 col0" >1.01</td>
#       <td id="T_22bc8_row3_col1" class="data row3 col1" >1.01</td>
#       <td id="T_22bc8_row3_col2" class="data row3 col2" >1.13</td>
#       <td id="T_22bc8_row3_col3" class="data row3 col3" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row4" class="row_heading level0 row4" >side-ETHER-PrefVec</th>
#       <td id="T_22bc8_row4_col0" class="data row4 col0" >1.01</td>
#       <td id="T_22bc8_row4_col1" class="data row4 col1" >1.01</td>
#       <td id="T_22bc8_row4_col2" class="data row4 col2" >1.12</td>
#       <td id="T_22bc8_row4_col3" class="data row4 col3" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row5" class="row_heading level0 row5" >dpo</th>
#       <td id="T_22bc8_row5_col0" class="data row5 col0" >1.01</td>
#       <td id="T_22bc8_row5_col1" class="data row5 col1" >1.01</td>
#       <td id="T_22bc8_row5_col2" class="data row5 col2" >1.11</td>
#       <td id="T_22bc8_row5_col3" class="data row5 col3" >1.03</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row6" class="row_heading level0 row6" >projgrad</th>
#       <td id="T_22bc8_row6_col0" class="data row6 col0" >1.01</td>
#       <td id="T_22bc8_row6_col1" class="data row6 col1" >1.01</td>
#       <td id="T_22bc8_row6_col2" class="data row6 col2" >1.11</td>
#       <td id="T_22bc8_row6_col3" class="data row6 col3" >1.02</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row7" class="row_heading level0 row7" >side-SVD-Rank</th>
#       <td id="T_22bc8_row7_col0" class="data row7 col0" >1.01</td>
#       <td id="T_22bc8_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_22bc8_row7_col2" class="data row7 col2" >1.09</td>
#       <td id="T_22bc8_row7_col3" class="data row7 col3" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row8" class="row_heading level0 row8" >side-Ortho-Rank</th>
#       <td id="T_22bc8_row8_col0" class="data row8 col0" >1.01</td>
#       <td id="T_22bc8_row8_col1" class="data row8 col1" >1.00</td>
#       <td id="T_22bc8_row8_col2" class="data row8 col2" >1.08</td>
#       <td id="T_22bc8_row8_col3" class="data row8 col3" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row9" class="row_heading level0 row9" >side-HRA-MSE</th>
#       <td id="T_22bc8_row9_col0" class="data row9 col0" >1.00</td>
#       <td id="T_22bc8_row9_col1" class="data row9 col1" >1.00</td>
#       <td id="T_22bc8_row9_col2" class="data row9 col2" >1.06</td>
#       <td id="T_22bc8_row9_col3" class="data row9 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_22bc8_level0_row10" class="row_heading level0 row10" >side-SVD-MSE</th>
#       <td id="T_22bc8_row10_col0" class="data row10 col0" >1.00</td>
#       <td id="T_22bc8_row10_col1" class="data row10 col1" >1.00</td>
#       <td id="T_22bc8_row10_col2" class="data r
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (2, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_2128f_row0_col0, #T_2128f_row1_col0, #T_2128f_row2_col0, #T_2128f_row10_col3 {
#   background-color: #e28799;
#   color: #f1f1f1;
# }
# #T_2128f_row0_col1, #T_2128f_row1_col1, #T_2128f_row2_col1 {
#   background-color: #e0768b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_2128f_row0_col2, #T_2128f_row1_col2, #T_2128f_row2_col2, #T_2128f_row8_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_2128f_row0_col3, #T_2128f_row1_col3, #T_2128f_row2_col3, #T_2128f_row3_col1, #T_2128f_row4_col1, #T_2128f_row5_col1, #T_2128f_row6_col1, #T_2128f_row7_col1, #T_2128f_row8_col1, #T_2128f_row9_col1, #T_2128f_row10_col1, #T_2128f_row11_col3, #T_2128f_row12_col3, #T_2128f_row13_col3, #T_2128f_row14_col0, #T_2128f_row15_col1, #T_2128f_row16_col2, #T_2128f_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_2128f_row3_col0 {
#   background-color: #e9b5bf;
#   color: #000000;
# }
# #T_2128f_row3_col2 {
#   background-color: #6f97c9;
#   color: #f1f1f1;
# }
# #T_2128f_row3_col3, #T_2128f_row4_col2, #T_2128f_row5_col3, #T_2128f_row6_col3, #T_2128f_row7_col3, #T_2128f_row9_col3, #T_2128f_row10_col2, #T_2128f_row11_col2, #T_2128f_row12_col2, #T_2128f_row13_col2, #T_2128f_row14_col2, #T_2128f_row15_col3, #T_2128f_row16_col3, #T_2128f_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_2128f_row4_col0 {
#   background-color: #df6f85;
#   color: #f1f1f1;
# }
# #T_2128f_row4_col3 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_2128f_row5_col0, #T_2128f_row6_col0, #T_2128f_row7_col0 {
#   background-color: #edccd2;
#   color: #000000;
#   font-weight: bold;
# }
# #T_2128f_row5_col2, #T_2128f_row6_col2, #T_2128f_row7_col2 {
#   background-color: #d7dfea;
#   color: #000000;
# }
# #T_2128f_row8_col0, #T_2128f_row9_col0 {
#   background-color: #e69dab;
#   color: #000000;
# }
# #T_2128f_row8_col2, #T_2128f_row14_col1 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_2128f_row9_col2 {
#   background-color: #ecc3cb;
#   color: #000000;
# }
# #T_2128f_row10_col0 {
#   background-color: #e9b1bc;
#   color: #000000;
# }
# #T_2128f_row11_col0, #T_2128f_row12_col0, #T_2128f_row13_col0 {
#   background-color: #efdde0;
#   color: #000000;
# }
# #T_2128f_row11_col1, #T_2128f_row12_col1, #T_2128f_row13_col1 {
#   background-color: #bacbe1;
#   color: #000000;
# }
# #T_2128f_row14_col3 {
#   background-color: #e28396;
#   color: #f1f1f1;
# }
# #T_2128f_row15_col0, #T_2128f_row16_col0 {
#   background-color: #e28497;
#   color: #f1f1f1;
# }
# #T_2128f_row15_col2 {
#   background-color: #de6b82;
#   color: #f1f1f1;
# }
# #T_2128f_row16_col1 {
#   background-color: #da4b68;
#   color: #f1f1f1;
# }
# #T_2128f_row17_col0 {
#   background-color: #de687f;
#   color: #f1f1f1;
# }
# #T_2128f_row17_col1 {
#   background-color: #e491a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2128f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2128f_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_2128f_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_2128f_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_2128f_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
#   background-color: #5383bf;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_16b6b_row0_col2 {
#   background-color: #f2eded;
#   color: #000000;
#   font-weight: bold;
# }
# #T_16b6b_row0_col3, #T_16b6b_row2_col3, #T_16b6b_row3_col3, #T_16b6b_row4_col3, #T_16b6b_row5_col3, #T_16b6b_row6_col3, #T_16b6b_row7_col3, #T_16b6b_row8_col3, #T_16b6b_row9_col3, #T_16b6b_row10_col3, #T_16b6b_row11_col3, #T_16b6b_row12_col3, #T_16b6b_row13_col3, #T_16b6b_row14_col3, #T_16b6b_row15_col3, #T_16b6b_row16_col3, #T_16b6b_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_16b6b_row1_col0, #T_16b6b_row2_col0, #T_16b6b_row3_col0, #T_16b6b_row4_col0, #T_16b6b_row5_col2, #T_16b6b_row6_col2, #T_16b6b_row7_col0, #T_16b6b_row8_col2, #T_16b6b_row9_col0, #T_16b6b_row10_col2, #T_16b6b_row11_col2, #T_16b6b_row12_col2, #T_16b6b_row13_col2, #T_16b6b_row14_col2, #T_16b6b_row15_col2, #T_16b6b_row16_col2, #T_16b6b_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_16b6b_row1_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
# }
# #T_16b6b_row1_col2 {
#   background-color: #edeef1;
#   color: #000000;
# }
# #T_16b6b_row1_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_16b6b_row2_col1 {
#   background-color: #638ec5;
#   color: #f1f1f1;
# }
# #T_16b6b_row2_col2 {
#   background-color: #becee2;
#   color: #000000;
# }
# #T_16b6b_row3_col1 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
# }
# #T_16b6b_row3_col2 {
#   background-color: #d0dae8;
#   color: #000000;
# }
# #T_16b6b_row4_col1 {
#   background-color: #5887c1;
#   color: #f1f1f1;
# }
# #T_16b6b_row4_col2 {
#   background-color: #f2ebec;
#   color: #000000;
# }
# #T_16b6b_row5_col0 {
#   background-color: #9fb8d8;
#   color: #000000;
# }
# #T_16b6b_row5_col1 {
#   background-color: #c9d6e6;
#   color: #000000;
# }
# #T_16b6b_row6_col0 {
#   background-color: #a3bbd9;
#   color: #000000;
# }
# #T_16b6b_row6_col1, #T_16b6b_row11_col1 {
#   background-color: #c8d5e5;
#   color: #000000;
# }
# #T_16b6b_row7_col1 {
#   background-color: #5c8ac2;
#   color: #f1f1f1;
# }
# #T_16b6b_row7_col2, #T_16b6b_row17_col0 {
#   background-color: #dae1eb;
#   color: #000000;
# }
# #T_16b6b_row8_col0 {
#   background-color: #9eb8d8;
#   color: #000000;
# }
# #T_16b6b_row8_col1 {
#   background-color: #c4d2e4;
#   color: #000000;
# }
# #T_16b6b_row9_col1 {
#   background-color: #628ec4;
#   color: #f1f1f1;
# }
# #T_16b6b_row9_col2 {
#   background-color: #f1eaeb;
#   color: #000000;
# }
# #T_16b6b_row10_col0 {
#   background-color: #a9bfdb;
#   color: #000000;
# }
# #T_16b6b_row10_col1, #T_16b6b_row17_col1 {
#   background-color: #d3dce9;
#   color: #000000;
# }
# #T_16b6b_row11_col0 {
#   background-color: #a1b9d9;
#   color: #000000;
# }
# #T_16b6b_row12_col0 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
# }
# #T_16b6b_row12_col1, #T_16b6b_row14_col1 {
#   background-color: #85a6d0;
#   color: #f1f1f1;
# }
# #T_16b6b_row13_col0 {
#   background-color: #6690c6;
#   color: #f1f1f1;
# }
# #T_16b6b_row13_col1 {
#   background-color: #89a9d1;
#   color: #f1f1f1;
# }
# #T_16b6b_row14_col0 {
#   background-color: #608dc4;
#   color: #f1f1f1;
# }
# #T_16b6b_row15_col0 {
#   background-color: #6791c6;
#   color: #f1f1f1;
# }
# #T_16b6b_row15_col1 {
#   background-color: #88a8d0;
#   color: #f1f1f1;
# }
# #T_16b6b_row16_col0 {
#   background-color: #497dbc;
#   color: #f1f1f1;
# }
# #T_16b6b_row16_col1 {
#   background-color: #6e96c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16b6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16b6b_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_16b6b_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_16b6b_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_16b6b_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16b6b_level0_row0" class="row_heading level0 row0" >projgrad</th>
#       <td id="T_16b6b_row0_col0" class="data row0 col0" >419.32</td>
#       <td id="T_16b6b_row0_col1" class="data row0 col1" >400.77</td>
#       <td id="T_16b6b_row0_col2" class="data row0 col2" >207.20</td>
#       <td id="T_16b6b_row0_col3" class="data row0 col3" >6.56</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_16b6b_row1_col0" class="data row1 col0" >370.23</td>
#       <td id="T_16b6b_row1_col1" class="data row1 col1" >353.86</td>
#       <td id="T_16b6b_row1_col2" class="data row1 col2" >193.47</td>
#       <td id="T_16b6b_row1_col3" class="data row1 col3" >7.55</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row2" class="row_heading level0 row2" >side-SVD-Rank</th>
#       <td id="T_16b6b_row2_col0" class="data row2 col0" >75.59</td>
#       <td id="T_16b6b_row2_col1" class="data row2 col1" >68.66</td>
#       <td id="T_16b6b_row2_col2" class="data row2 col2" >48.93</td>
#       <td id="T_16b6b_row2_col3" class="data row2 col3" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row3" class="row_heading level0 row3" >side-Ortho-Rank</th>
#       <td id="T_16b6b_row3_col0" class="data row3 col0" >80.53</td>
#       <td id="T_16b6b_row3_col1" class="data row3 col1" >75.38</td>
#       <td id="T_16b6b_row3_col2" class="data row3 col2" >48.46</td>
#       <td id="T_16b6b_row3_col3" class="data row3 col3" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row4" class="row_heading level0 row4" >side-None-Rank</th>
#       <td id="T_16b6b_row4_col0" class="data row4 col0" >82.20</td>
#       <td id="T_16b6b_row4_col1" class="data row4 col1" >77.22</td>
#       <td id="T_16b6b_row4_col2" class="data row4 col2" >40.02</td>
#       <td id="T_16b6b_row4_col3" class="data row4 col3" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row5" class="row_heading level0 row5" >side-None-PrefVec</th>
#       <td id="T_16b6b_row5_col0" class="data row5 col0" >28.40</td>
#       <td id="T_16b6b_row5_col1" class="data row5 col1" >23.87</td>
#       <td id="T_16b6b_row5_col2" class="data row5 col2" >38.52</td>
#       <td id="T_16b6b_row5_col3" class="data row5 col3" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row6" class="row_heading level0 row6" >side-HRA-PrefVec</th>
#       <td id="T_16b6b_row6_col0" class="data row6 col0" >24.37</td>
#       <td id="T_16b6b_row6_col1" class="data row6 col1" >20.75</td>
#       <td id="T_16b6b_row6_col2" class="data row6 col2" >33.58</td>
#       <td id="T_16b6b_row6_col3" class="data row6 col3" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row7" class="row_heading level0 row7" >side-ETHER-Rank</th>
#       <td id="T_16b6b_row7_col0" class="data row7 col0" >57.04</td>
#       <td id="T_16b6b_row7_col1" class="data row7 col1" >52.89</td>
#       <td id="T_16b6b_row7_col2" class="data row7 col2" >32.69</td>
#       <td id="T_16b6b_row7_col3" class="data row7 col3" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row8" class="row_heading level0 row8" >side-Ortho-PrefVec</th>
#       <td id="T_16b6b_row8_col0" class="data row8 col0" >23.44</td>
#       <td id="T_16b6b_row8_col1" class="data row8 col1" >20.06</td>
#       <td id="T_16b6b_row8_col2" class="data row8 col2" >31.76</td>
#       <td id="T_16b6b_row8_col3" class="data row8 col3" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row9" class="row_heading level0 row9" >side-HRA-Rank</th>
#       <td id="T_16b6b_row9_col0" class="data row9 col0" >60.39</td>
#       <td id="T_16b6b_row9_col1" class="data row9 col1" >55.13</td>
#       <td id="T_16b6b_row9_col2" class="data row9 col2" >29.64</td>
#       <td id="T_16b6b_row9_col3" class="data row9 col3" >1.53</td>
#     </tr>
#     <tr>
#       <th id="T_16b6b_level0_row10" class="row_heading level0 row10" >side-SVD-PrefVec</th>
#       <td id="T_16b6b_row10_col0" class="data row10 col0" >20.24</td
# ## reciprocate/tiny-llama - us_history_textbook
# skipped (2, 4)
# ## wassname/llama-3-2-1b-sft - us_history_textbook
# <style type="text/css">
# #T_97bab_row0_col0 {
#   background-color: #5887c1;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_97bab_row0_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_97bab_row0_col2 {
#   background-color: #f0e4e6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_97bab_row0_col3, #T_97bab_row1_col3, #T_97bab_row2_col3, #T_97bab_row3_col3, #T_97bab_row4_col3, #T_97bab_row5_col3, #T_97bab_row6_col3, #T_97bab_row7_col3, #T_97bab_row8_col3, #T_97bab_row10_col3, #T_97bab_row11_col3, #T_97bab_row12_col3, #T_97bab_row13_col3, #T_97bab_row14_col3, #T_97bab_row15_col3, #T_97bab_row16_col2, #T_97bab_row17_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_97bab_row1_col0, #T_97bab_row9_col0 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
# }
# #T_97bab_row1_col1, #T_97bab_row2_col0, #T_97bab_row3_col0, #T_97bab_row4_col0, #T_97bab_row5_col0, #T_97bab_row6_col2, #T_97bab_row7_col2, #T_97bab_row8_col2, #T_97bab_row9_col1, #T_97bab_row10_col1, #T_97bab_row11_col1, #T_97bab_row12_col1, #T_97bab_row13_col1, #T_97bab_row14_col1, #T_97bab_row15_col1, #T_97bab_row16_col1, #T_97bab_row17_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_97bab_row1_col2 {
#   background-color: #efdade;
#   color: #000000;
# }
# #T_97bab_row2_col1 {
#   background-color: #6892c6;
#   color: #f1f1f1;
# }
# #T_97bab_row2_col2 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_97bab_row3_col1, #T_97bab_row4_col1, #T_97bab_row5_col1, #T_97bab_row10_col0 {
#   background-color: #769ccb;
#   color: #f1f1f1;
# }
# #T_97bab_row3_col2, #T_97bab_row4_col2, #T_97bab_row5_col2 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_97bab_row6_col0, #T_97bab_row7_col0, #T_97bab_row8_col0 {
#   background-color: #8dacd2;
#   color: #f1f1f1;
# }
# #T_97bab_row6_col1, #T_97bab_row7_col1, #T_97bab_row8_col1 {
#   background-color: #a5bcda;
#   color: #000000;
# }
# #T_97bab_row9_col2 {
#   background-color: #e69caa;
#   color: #000000;
# }
# #T_97bab_row9_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_97bab_row10_col2 {
#   background-color: #92b0d4;
#   color: #000000;
# }
# #T_97bab_row11_col0 {
#   background-color: #628ec4;
#   color: #f1f1f1;
# }
# #T_97bab_row11_col2 {
#   background-color: #ecc6ce;
#   color: #000000;
# }
# #T_97bab_row12_col0, #T_97bab_row13_col0, #T_97bab_row14_col0, #T_97bab_row16_col0 {
#   background-color: #6d95c8;
#   color: #f1f1f1;
# }
# #T_97bab_row12_col2, #T_97bab_row13_col2, #T_97bab_row14_col2 {
#   background-color: #eed4d9;
#   color: #000000;
# }
# #T_97bab_row15_col0 {
#   background-color: #86a7d0;
#   color: #f1f1f1;
# }
# #T_97bab_row15_col2 {
#   background-color: #e9b4be;
#   color: #000000;
# }
# #T_97bab_row16_col3 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
# }
# #T_97bab_row17_col0 {
#   background-color: #c0cfe3;
#   color: #000000;
# }
# #T_97bab_row17_col1 {
#   background-color: #a1b9d9;
#   color: #000000;
# }
# </style>
# <table id="T_97bab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97bab_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_97bab_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_97bab_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_97bab_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97bab_level0_row0" class="row_heading level0 row0" >dpo</th>
#       <td id="T_97bab_row0_col0" class="data row0 col0" >325.32</td>
#       <td id="T_97bab_row0_col1" class="data row0 col1" >346.64</td>
#       <td id="T_97bab_row0_col2" class="data row0 col2" >159.94</td>
#       <td id="T_97bab_row0_col3" class="data row0 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row1" class="row_heading level0 row1" >projgrad</th>
#       <td id="T_97bab_row1_col0" class="data row1 col0" >299.71</td>
#       <td id="T_97bab_row1_col1" class="data row1 col1" >320.75</td>
#       <td id="T_97bab_row1_col2" class="data row1 col2" >139.28</td>
#       <td id="T_97bab_row1_col3" class="data row1 col3" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row2" class="row_heading level0 row2" >side-Ortho-Rank</th>
#       <td id="T_97bab_row2_col0" class="data row2 col0" >70.04</td>
#       <td id="T_97bab_row2_col1" class="data row2 col1" >62.56</td>
#       <td id="T_97bab_row2_col2" class="data row2 col2" >30.59</td>
#       <td id="T_97bab_row2_col3" class="data row2 col3" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row3" class="row_heading level0 row3" >side-ETHER-Rank</th>
#       <td id="T_97bab_row3_col0" class="data row3 col0" >94.98</td>
#       <td id="T_97bab_row3_col1" class="data row3 col1" >81.11</td>
#       <td id="T_97bab_row3_col2" class="data row3 col2" >28.40</td>
#       <td id="T_97bab_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row4" class="row_heading level0 row4" >side-None-Rank</th>
#       <td id="T_97bab_row4_col0" class="data row4 col0" >94.98</td>
#       <td id="T_97bab_row4_col1" class="data row4 col1" >81.11</td>
#       <td id="T_97bab_row4_col2" class="data row4 col2" >28.40</td>
#       <td id="T_97bab_row4_col3" class="data row4 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row5" class="row_heading level0 row5" >side-SVD-Rank</th>
#       <td id="T_97bab_row5_col0" class="data row5 col0" >94.98</td>
#       <td id="T_97bab_row5_col1" class="data row5 col1" >81.11</td>
#       <td id="T_97bab_row5_col2" class="data row5 col2" >28.40</td>
#       <td id="T_97bab_row5_col3" class="data row5 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row6" class="row_heading level0 row6" >side-HRA-PrefVec</th>
#       <td id="T_97bab_row6_col0" class="data row6 col0" >18.88</td>
#       <td id="T_97bab_row6_col1" class="data row6 col1" >17.28</td>
#       <td id="T_97bab_row6_col2" class="data row6 col2" >23.99</td>
#       <td id="T_97bab_row6_col3" class="data row6 col3" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row7" class="row_heading level0 row7" >side-None-PrefVec</th>
#       <td id="T_97bab_row7_col0" class="data row7 col0" >18.88</td>
#       <td id="T_97bab_row7_col1" class="data row7 col1" >17.28</td>
#       <td id="T_97bab_row7_col2" class="data row7 col2" >23.99</td>
#       <td id="T_97bab_row7_col3" class="data row7 col3" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row8" class="row_heading level0 row8" >side-SVD-PrefVec</th>
#       <td id="T_97bab_row8_col0" class="data row8 col0" >18.88</td>
#       <td id="T_97bab_row8_col1" class="data row8 col1" >17.28</td>
#       <td id="T_97bab_row8_col2" class="data row8 col2" >23.99</td>
#       <td id="T_97bab_row8_col3" class="data row8 col3" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row9" class="row_heading level0 row9" >side-HRA-Rank</th>
#       <td id="T_97bab_row9_col0" class="data row9 col0" >56.83</td>
#       <td id="T_97bab_row9_col1" class="data row9 col1" >60.86</td>
#       <td id="T_97bab_row9_col2" class="data row9 col2" >16.07</td>
#       <td id="T_97bab_row9_col3" class="data row9 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row10" class="row_heading level0 row10" >side-ETHER-PrefVec</th>
#       <td id="T_97bab_row10_col0" class="data row10 col0" >10.47</td>
#       <td id="T_97bab_row10_col1" class="data row10 col1" >12.31</td>
#       <td id="T_97bab_row10_col2" class="data row10 col2" >9.43</td>
#       <td id="T_97bab_row10_col3" class="data row10 col3" >-0.21</td>
#     </tr>
#     <tr>
#       <th id="T_97bab_level0_row11" class="row_heading level0 row11" >side-Ortho-PrefVec</th>
#       <td id="T_97bab_row11_col0" class="data row11 col0" >11.49</td>
#       <td id="T_97bab_row11_col1" class="data row11 col1" >12.59</td>
#       <td id="T_97bab_row11_col2" class="data row11 col2" >4.65</td>
#       <td id="
