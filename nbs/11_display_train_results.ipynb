# %% [markdown]
# This notebook will load all the results, group them into comparable sets and plot/table them

# %%
import re, os, sys, json, time, requests
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# TODO load config.json, load eval.parquet
fs = sorted(Path("../outputs").glob("**/eval.parquet"))
fs;

# %%
def load_config(f):
    # print(f.parent.parent.stem)
    config = json.load((f.parent / "config.json").open())
    log = (f.parent / "log.txt").open().read()

    # dataframe of all non list/dict/tuple in config
    config_df = pd.DataFrame(
        {k: v for k, v in config.items() if not isinstance(v, (list, dict, tuple))},
        index=[0],
    )
    config_df["log"] = log
    config_df["file"] = f
    config_df["ts"] = f.parent.stem
    try:
        _, method, _ = f.parent.parent.stem.split(
            "_", 2
        )  # this is {model}_{method}_{dataset}
    except ValueError as e:
        print(e)
        print(
            f"cannot split `{f.parent.parent.stem}` from {f} like [f.parent.parent.stem.split('_', 3)]"
        )
        method = ""
    config_df["method"] = method

    # put key cols first
    key_columns = ["dataset", "base_model"]
    columns = key_columns + [c for c in config_df.columns if not c in key_columns]
    return config_df[columns]


configs = [load_config(f) for f in fs]
df_configs = pd.concat(configs)
df_configs
# Out:
#                dataset                 base_model  verbose    dev  \
# 0   alpaca_low_quality  wassname/llama-3-2-1b-sft        1  False
# 0   alpaca_low_quality  wassname/llama-3-2-1b-sft        1  False
# 0   alpaca_low_quality  wassname/llama-3-2-1b-sft        1  False
# 0   alpaca_low_quality  wassname/llama-3-2-1b-sft        1  False
# 0   alpaca_low_quality  wassname/llama-3-2-1b-sft        1  False
# ..                 ...                        ...      ...    ...
# 0     unhelpful_alpaca  wassname/llama-3-2-1b-sft        2  False
# 0     unhelpful_alpaca  wassname/llama-3-2-1b-sft        2  False
# 0     unhelpful_alpaca  wassname/llama-3-2-1b-sft        2  False
# 0     unhelpful_alpaca  wassname/llama-3-2-1b-sft        2  False
# 0     unhelpful_alpaca  wassname/llama-3-2-1b-sft        2  False
#
#     load_in_4bit  load_in_8bit  use_gradient_checkpointing  batch_size  \
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
# ..           ...           ...                         ...         ...
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
# 0          False         False                       False          10
#
#     n_samples eval_samples  ...  collection_layers  collect_input  collect_hs  \
# 0       10000         None  ...                NaN            NaN         NaN
# 0       10000         None  ...               None           True        True
# 0       10000         None  ...               None           True        True
# 0       10000         None  ...               None           True        True
# 0       10000         None  ...                NaN            NaN         NaN
# ..        ...          ...  ...                ...            ...         ...
# 0        1800         None  ...                NaN           True       False
# 0        1800         None  ...                NaN           True       False
# 0        1800         None  ...                NaN           True       False
# 0        1800         None  ...                NaN           True       False
# 0        1800         None  ...                NaN           True       False
#
#       β  reverse_pref weight_dim scale_orth neg_slope mag_clip use_pref_ref
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   0.8          True        1.0      False       0.0     None         True
# ..  ...           ...        ...        ...       ...      ...          ...
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
# 0   NaN           NaN        NaN        NaN       NaN      NaN          NaN
#
# [95 rows x 29 columns]

# %%
# df_evals = [pd.read_parquet(f) for f in fs]
# df_eval = pd.concat(df_evals).reset_index()
# df_eval
from reprpo.training import parse_eval, key_metrics
from tqdm.auto import tqdm

data_acc = []
data_rel_acc = []
data_rel_ppl = []
data_rel_pref = []

for i in tqdm(range(len(fs))):
    try:
        df_res2 = pd.read_parquet(fs[i])
        config = df_configs.iloc[i]

        ds_alias = dict(
            list(zip(["train", "test", "oos", "rnd"], df_res2["dataset"].unique()))
        )
        # assert ds_alias['train']==config['dataset']
        assert "train" in ds_alias["train"]
        adapter_name = df_res2[["adapter"]].query('adapter!="base"').values[0, 0]
        df_acc = (
            df_res2.groupby(["dataset", "adapter"], dropna=False)["correct"]
            .mean()
            .unstack()
            .T
        )
        ds_alias_rev = {v: k for k, v in ds_alias.items()}
        df_acc = df_acc.rename(columns=ds_alias_rev)

        df_rel = key_metrics(df_res2, adapter_name, ds_alias)

        splits = list(ds_alias_rev.values())
        df_acc = df_acc[splits]

        data_acc.append(
            dict(
                base_model=config["base_model"],
                train_dataset=config["dataset"],
                method=adapter_name,
                ts=config["ts"],
                **df_acc.loc[adapter_name].to_dict(),
                **ds_alias_rev,
            )
        )
        data_acc.append(
            dict(
                base_model=config["base_model"],
                train_dataset=config["dataset"],
                method="base",
                ts=config["ts"],
                **df_acc.loc["base"].to_dict(),
                **ds_alias_rev,
            )
        )

        data_rel_acc.append(
            dict(
                base_model=config["base_model"],
                train_dataset=config["dataset"],
                method=adapter_name,
                ts=config["ts"],
                **df_rel.iloc[0].to_dict(),
                **ds_alias_rev,
            )
        )
        data_rel_ppl.append(
            dict(
                base_model=config["base_model"],
                train_dataset=config["dataset"],
                method=adapter_name,
                ts=config["ts"],
                **df_rel.iloc[1].to_dict(),
                **ds_alias_rev,
            )
        )
        data_rel_pref.append(
            dict(
                base_model=config["base_model"],
                train_dataset=config["dataset"],
                method=adapter_name,
                ts=config["ts"],
                **df_rel.iloc[2].to_dict(),
                **ds_alias_rev,
            )
        )
    except Exception as e:
        print(e)
        print(f"error in {fs[i]}")
        continue
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]

# %%
config.ts, config.n_samples, config.max_length
list(ds_alias_rev.values())
df_acc.loc[adapter_name].to_dict()
# Out:
# {'train': 0.07733333333333334,
#  'test': 0.072,
#  'oos': 0.4186991869918699,
#  'rnd': 0.3821022727272727}

# %%
import seaborn as sns

cmap = cmap = sns.diverging_palette(5, 250, as_cmap=True)


def style_df(df, caption=""):
    return (
        df.style.background_gradient(cmap, axis=1)
        # .set_caption(caption)
        .format(precision=3)
        .highlight_max(axis=0, props="font-weight:bold;")
    )

# %%
metrics = dict(
    acc=data_acc,
    # rel_acc=data_rel_acc,
    # rel_ppl=data_rel_ppl,
    # rel_pref=data_rel_pref,
)

for metric, data in metrics.items():
    print(f"# {metric}:\n")
    for (base_model, train_dataset), df1 in pd.DataFrame(data).groupby(
        ["base_model", "train_dataset"]
    ):
        ts = df1["ts"].unique()[0]
        dataset_map = df1.dropna(axis=1, how="all").iloc[0, -4:]
        ds_alias = {v: k for k, v in dataset_map.to_dict().items()}
        print(f"\n## {base_model} - {train_dataset}")
        print(ts)
        df = df1.drop(["base_model", "train_dataset"], axis="columns")
        df = (
            df.groupby("method", as_index=True)[
                [
                    "train",
                    "test",
                    "oos",
                    "rnd",
                ]
            ]
            .mean()
            .sort_values("oos", ascending=False)
            .dropna(axis=1)
        )
        if (len(df) > 2) and (df.std() > 0).all():
            display(style_df(df, f"{metric}: {base_model} {train_dataset}"))
        else:
            print(f"skipped due to low amount of rows {df.index}")
            continue

        if metric == "acc":
            caption = f"""Table 2: Absolute accuracy after training with adapter on ds:`{train_dataset}` compared to base model `{base_model}` for various distribution shifts:"""
            for k in ['train', 'test', 'oos', 'rnd']:
                v = ds_alias[k]
                def rename_ds(x):
                    "genies_preferences-alpaca_low_quality-train[:750]" 
                    if "[" in x:
                        x = x.split("[")[0]
                    x = x.replace("genies_preferences-", "genies / ")
                    x = x.replace("ethics_expression_preferences-", "ethics / ")
                    # x = x.split("-")[-1]
                    x = x.replace('_', ' ').replace('-test', '\t(test)').replace('-train', '\t(train)')
                    return x

                v = rename_ds(v)
                caption += f"\n- `{k}` \t:`{v}`"
            print(caption)

    print("\n")
# Out:
# # acc:
#
#
# ## wassname/llama-3-2-1b-sft - alpaca_low_quality
# 2025-05-15_19-24-02
# <style type="text/css">
# #T_e7510_row0_col0 {
#   background-color: #457abb;
#   color: #f1f1f1;
# }
# #T_e7510_row0_col1, #T_e7510_row1_col0, #T_e7510_row1_col1, #T_e7510_row2_col0, #T_e7510_row4_col0, #T_e7510_row4_col1, #T_e7510_row5_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_e7510_row0_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_e7510_row0_col3 {
#   background-color: #f0e4e6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_e7510_row1_col2, #T_e7510_row2_col2, #T_e7510_row3_col2, #T_e7510_row4_col2, #T_e7510_row5_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_e7510_row1_col3 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_e7510_row2_col1 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_e7510_row2_col3 {
#   background-color: #e7a7b4;
#   color: #000000;
# }
# #T_e7510_row3_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_e7510_row3_col1 {
#   background-color: #477bbb;
#   color: #f1f1f1;
# }
# #T_e7510_row3_col3 {
#   background-color: #e8abb7;
#   color: #000000;
# }
# #T_e7510_row4_col3 {
#   background-color: #f0e4e6;
#   color: #000000;
# }
# #T_e7510_row5_col0 {
#   background-color: #4b7ebd;
#   color: #f1f1f1;
# }
# #T_e7510_row5_col3 {
#   background-color: #ecc3cb;
#   color: #000000;
# }
# </style>
# <table id="T_e7510">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7510_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_e7510_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_e7510_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_e7510_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7510_level0_row0" class="row_heading level0 row0" >hs-None-PrefVec</th>
#       <td id="T_e7510_row0_col0" class="data row0 col0" >0.957</td>
#       <td id="T_e7510_row0_col1" class="data row0 col1" >0.961</td>
#       <td id="T_e7510_row0_col2" class="data row0 col2" >0.088</td>
#       <td id="T_e7510_row0_col3" class="data row0 col3" >0.491</td>
#     </tr>
#     <tr>
#       <th id="T_e7510_level0_row1" class="row_heading level0 row1" >hs-ETHER-PrefVec</th>
#       <td id="T_e7510_row1_col0" class="data row1 col0" >0.973</td>
#       <td id="T_e7510_row1_col1" class="data row1 col1" >0.971</td>
#       <td id="T_e7510_row1_col2" class="data row1 col2" >0.079</td>
#       <td id="T_e7510_row1_col3" class="data row1 col3" >0.438</td>
#     </tr>
#     <tr>
#       <th id="T_e7510_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_e7510_row2_col0" class="data row2 col0" >0.988</td>
#       <td id="T_e7510_row2_col1" class="data row2 col1" >0.983</td>
#       <td id="T_e7510_row2_col2" class="data row2 col2" >0.077</td>
#       <td id="T_e7510_row2_col3" class="data row2 col3" >0.347</td>
#     </tr>
#     <tr>
#       <th id="T_e7510_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_e7510_row3_col0" class="data row3 col0" >0.989</td>
#       <td id="T_e7510_row3_col1" class="data row3 col1" >0.981</td>
#       <td id="T_e7510_row3_col2" class="data row3 col2" >0.073</td>
#       <td id="T_e7510_row3_col3" class="data row3 col3" >0.355</td>
#     </tr>
#     <tr>
#       <th id="T_e7510_level0_row4" class="row_heading level0 row4" >hs-SupressedHS-PrefVec</th>
#       <td id="T_e7510_row4_col0" class="data row4 col0" >0.968</td>
#       <td id="T_e7510_row4_col1" class="data row4 col1" >0.968</td>
#       <td id="T_e7510_row4_col2" class="data row4 col2" >0.071</td>
#       <td id="T_e7510_row4_col3" class="data row4 col3" >0.484</td>
#     </tr>
#     <tr>
#       <th id="T_e7510_level0_row5" class="row_heading level0 row5" >base</th>
#       <td id="T_e7510_row5_col0" class="data row5 col0" >0.833</td>
#       <td id="T_e7510_row5_col1" class="data row5 col1" >0.851</td>
#       <td id="T_e7510_row5_col2" class="data row5 col2" >0.068</td>
#       <td id="T_e7510_row5_col3" class="data row5 col3" >0.361</td>
#     </tr>
#   </tbody>
# </table>
# Table 2: Absolute accuracy after training with adapter on ds:`alpaca_low_quality` compared to base model `wassname/llama-3-2-1b-sft` for various distribution shifts:
# - `train` 	:`genies / alpaca low quality	(train)`
# - `test` 	:`genies / alpaca low quality	(test)`
# - `oos` 	:`genies / alpaca high quality	(test)`
# - `rnd` 	:`ethics / justice	(test)`
#
# ## wassname/llama-3-2-1b-sft - math
# 2025-05-15_22-05-03
# <style type="text/css">
# #T_a2af5_row0_col0, #T_a2af5_row1_col0, #T_a2af5_row3_col0, #T_a2af5_row4_col1, #T_a2af5_row5_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_a2af5_row0_col1 {
#   background-color: #a2bad9;
#   color: #000000;
# }
# #T_a2af5_row0_col2 {
#   background-color: #e28698;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a2af5_row0_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a2af5_row1_col1 {
#   background-color: #9db7d7;
#   color: #000000;
# }
# #T_a2af5_row1_col2, #T_a2af5_row2_col2, #T_a2af5_row3_col2, #T_a2af5_row4_col2, #T_a2af5_row5_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_a2af5_row1_col3 {
#   background-color: #db546f;
#   color: #f1f1f1;
# }
# #T_a2af5_row2_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a2af5_row2_col1 {
#   background-color: #9db7d7;
#   color: #000000;
#   font-weight: bold;
# }
# #T_a2af5_row2_col3 {
#   background-color: #d73d5c;
#   color: #f1f1f1;
# }
# #T_a2af5_row3_col1 {
#   background-color: #a6bdda;
#   color: #000000;
# }
# #T_a2af5_row3_col3 {
#   background-color: #d8415f;
#   color: #f1f1f1;
# }
# #T_a2af5_row4_col0 {
#   background-color: #e9b2bd;
#   color: #000000;
# }
# #T_a2af5_row4_col3 {
#   background-color: #f1e5e7;
#   color: #000000;
# }
# #T_a2af5_row5_col1 {
#   background-color: #86a7d0;
#   color: #f1f1f1;
# }
# #T_a2af5_row5_col3 {
#   background-color: #dc5973;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2af5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2af5_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_a2af5_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_a2af5_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_a2af5_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2af5_level0_row0" class="row_heading level0 row0" >hs-ETHER-PrefVec</th>
#       <td id="T_a2af5_row0_col0" class="data row0 col0" >0.764</td>
#       <td id="T_a2af5_row0_col1" class="data row0 col1" >0.660</td>
#       <td id="T_a2af5_row0_col2" class="data row0 col2" >0.460</td>
#       <td id="T_a2af5_row0_col3" class="data row0 col3" >0.382</td>
#     </tr>
#     <tr>
#       <th id="T_a2af5_level0_row1" class="row_heading level0 row1" >hs-SupressedHS-PrefVec</th>
#       <td id="T_a2af5_row1_col0" class="data row1 col0" >0.773</td>
#       <td id="T_a2af5_row1_col1" class="data row1 col1" >0.665</td>
#       <td id="T_a2af5_row1_col2" class="data row1 col2" >0.348</td>
#       <td id="T_a2af5_row1_col3" class="data row1 col3" >0.378</td>
#     </tr>
#     <tr>
#       <th id="T_a2af5_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_a2af5_row2_col0" class="data row2 col0" >0.977</td>
#       <td id="T_a2af5_row2_col1" class="data row2 col1" >0.817</td>
#       <td id="T_a2af5_row2_col2" class="data row2 col2" >0.348</td>
#       <td id="T_a2af5_row2_col3" class="data row2 col3" >0.352</td>
#     </tr>
#     <tr>
#       <th id="T_a2af5_level0_row3" class="row_heading level0 row3" >dpo</th>
#       <td id="T_a2af5_row3_col0" class="data row3 col0" >0.976</td>
#       <td id="T_a2af5_row3_col1" class="data row3 col1" >0.797</td>
#       <td id="T_a2af5_row3_col2" class="data row3 col2" >0.344</td>
#       <td id="T_a2af5_row3_col3" class="data row3 col3" >0.355</td>
#     </tr>
#     <tr>
#       <th id="T_a2af5_level0_row4" class="row_heading level0 row4" >base</th>
#       <td id="T_a2af5_row4_col0" class="data row4 col0" >0.353</td>
#       <td id="T_a2af5_row4_col1" class="data row4 col1" >0.389</td>
#       <td id="T_a2af5_row4_col2" class="data row4 col2" >0.336</td>
#       <td id="T_a2af5_row4_col3" class="data row4 col3" >0.361</td>
#     </tr>
#     <tr>
#       <th id="T_a2af5_level0_row5" class="row_heading level0 row5" >hs-None-PrefVec</th>
#       <td id="T_a2af5_row5_col0" class="data row5 col0" >0.741</td>
#       <td id="T_a2af5_row5_col1" class="data row5 col1" >0.663</td>
#       <td id="T_a2af5_row5_col2" class="data row5 col2" >0.336</td>
#       <td id="T_a2af5_row5_col3" class="data row5 col3" >0.369</td>
#     </tr>
#   </tbody>
# </table>
# Table 2: Absolute accuracy after training with adapter on ds:`math` compared to base model `wassname/llama-3-2-1b-sft` for various distribution shifts:
# - `train` 	:`genies / math	(train)`
# - `test` 	:`genies / math	(test)`
# - `oos` 	:`genies / change my view	(test)`
# - `rnd` 	:`ethics / justice	(test)`
#
# ## wassname/llama-3-2-1b-sft - math_easy
# 2025-05-15_17-05-36
# <style type="text/css">
# #T_38524_row0_col0, #T_38524_row1_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_38524_row0_col1 {
#   background-color: #4b7ebd;
#   color: #f1f1f1;
# }
# #T_38524_row0_col2 {
#   background-color: #f2ebec;
#   color: #000000;
#   font-weight: bold;
# }
# #T_38524_row0_col3, #T_38524_row1_col3, #T_38524_row3_col3, #T_38524_row4_col3, #T_38524_row5_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_38524_row1_col1 {
#   background-color: #497dbc;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_38524_row1_col2 {
#   background-color: #f1e5e7;
#   color: #000000;
# }
# #T_38524_row2_col0, #T_38524_row3_col0, #T_38524_row4_col0, #T_38524_row5_col1 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_38524_row2_col1 {
#   background-color: #457abb;
#   color: #f1f1f1;
# }
# #T_38524_row2_col2 {
#   background-color: #e3889a;
#   color: #f1f1f1;
# }
# #T_38524_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_38524_row3_col1 {
#   background-color: #5585c0;
#   color: #f1f1f1;
# }
# #T_38524_row3_col2 {
#   background-color: #e28396;
#   color: #f1f1f1;
# }
# #T_38524_row4_col1 {
#   background-color: #4c7ebd;
#   color: #f1f1f1;
# }
# #T_38524_row4_col2 {
#   background-color: #df6d84;
#   color: #f1f1f1;
# }
# #T_38524_row5_col0 {
#   background-color: #487cbc;
#   color: #f1f1f1;
# }
# #T_38524_row5_col3 {
#   background-color: #e07389;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_38524">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38524_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_38524_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_38524_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_38524_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38524_level0_row0" class="row_heading level0 row0" >dpo</th>
#       <td id="T_38524_row0_col0" class="data row0 col0" >0.995</td>
#       <td id="T_38524_row0_col1" class="data row0 col1" >0.980</td>
#       <td id="T_38524_row0_col2" class="data row0 col2" >0.660</td>
#       <td id="T_38524_row0_col3" class="data row0 col3" >0.347</td>
#     </tr>
#     <tr>
#       <th id="T_38524_level0_row1" class="row_heading level0 row1" >projgrad</th>
#       <td id="T_38524_row1_col0" class="data row1 col0" >0.995</td>
#       <td id="T_38524_row1_col1" class="data row1 col1" >0.984</td>
#       <td id="T_38524_row1_col2" class="data row1 col2" >0.648</td>
#       <td id="T_38524_row1_col3" class="data row1 col3" >0.347</td>
#     </tr>
#     <tr>
#       <th id="T_38524_level0_row2" class="row_heading level0 row2" >hs-ETHER-PrefVec</th>
#       <td id="T_38524_row2_col0" class="data row2 col0" >0.957</td>
#       <td id="T_38524_row2_col1" class="data row2 col1" >0.953</td>
#       <td id="T_38524_row2_col2" class="data row2 col2" >0.487</td>
#       <td id="T_38524_row2_col3" class="data row2 col3" >0.361</td>
#     </tr>
#     <tr>
#       <th id="T_38524_level0_row3" class="row_heading level0 row3" >hs-None-PrefVec</th>
#       <td id="T_38524_row3_col0" class="data row3 col0" >0.961</td>
#       <td id="T_38524_row3_col1" class="data row3 col1" >0.929</td>
#       <td id="T_38524_row3_col2" class="data row3 col2" >0.477</td>
#       <td id="T_38524_row3_col3" class="data row3 col3" >0.358</td>
#     </tr>
#     <tr>
#       <th id="T_38524_level0_row4" class="row_heading level0 row4" >hs-SupressedHS-PrefVec</th>
#       <td id="T_38524_row4_col0" class="data row4 col0" >0.961</td>
#       <td id="T_38524_row4_col1" class="data row4 col1" >0.947</td>
#       <td id="T_38524_row4_col2" class="data row4 col2" >0.436</td>
#       <td id="T_38524_row4_col3" class="data row4 col3" >0.351</td>
#     </tr>
#     <tr>
#       <th id="T_38524_level0_row5" class="row_heading level0 row5" >base</th>
#       <td id="T_38524_row5_col0" class="data row5 col0" >0.920</td>
#       <td id="T_38524_row5_col1" class="data row5 col1" >0.929</td>
#       <td id="T_38524_row5_col2" class="data row5 col2" >0.256</td>
#       <td id="T_38524_row5_col3" class="data row5 col3" >0.361</td>
#     </tr>
#   </tbody>
# </table>
# Table 2: Absolute accuracy after training with adapter on ds:`math_easy` compared to base model `wassname/llama-3-2-1b-sft` for various distribution shifts:
# - `train` 	:`genies / math easy	(train)`
# - `test` 	:`genies / math easy	(test)`
# - `oos` 	:`genies / math hard	(test)`
# - `rnd` 	:`ethics / justice	(test)`
#
# ## wassname/llama-3-2-1b-sft - truthful_qa
# 2025-05-13_21-10-35
# <style type="text/css">
# #T_9acbf_row0_col0 {
#   background-color: #de687f;
#   color: #f1f1f1;
# }
# #T_9acbf_row0_col1 {
#   background-color: #e0798d;
#   color: #f1f1f1;
# }
# #T_9acbf_row0_col2, #T_9acbf_row1_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_9acbf_row0_col3, #T_9acbf_row1_col3, #T_9acbf_row2_col3, #T_9acbf_row3_col2, #T_9acbf_row4_col2, #T_9acbf_row5_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_9acbf_row1_col1 {
#   background-color: #a5bcda;
#   color: #000000;
#   font-weight: bold;
# }
# #T_9acbf_row1_col2 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_9acbf_row2_col0, #T_9acbf_row3_col0, #T_9acbf_row4_col0, #T_9acbf_row5_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_9acbf_row2_col1 {
#   background-color: #a9bfdb;
#   color: #000000;
# }
# #T_9acbf_row2_col2 {
#   background-color: #e6a0ae;
#   color: #000000;
# }
# #T_9acbf_row3_col1 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
# }
# #T_9acbf_row3_col3 {
#   background-color: #e48fa0;
#   color: #f1f1f1;
# }
# #T_9acbf_row4_col1 {
#   background-color: #5c8ac2;
#   color: #f1f1f1;
# }
# #T_9acbf_row4_col3 {
#   background-color: #e9afbb;
#   color: #000000;
#   font-weight: bold;
# }
# #T_9acbf_row5_col1 {
#   background-color: #5484c0;
#   color: #f1f1f1;
# }
# #T_9acbf_row5_col3 {
#   background-color: #e7a7b4;
#   color: #000000;
# }
# </style>
# <table id="T_9acbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9acbf_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_9acbf_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_9acbf_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_9acbf_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9acbf_level0_row0" class="row_heading level0 row0" >base</th>
#       <td id="T_9acbf_row0_col0" class="data row0 col0" >0.389</td>
#       <td id="T_9acbf_row0_col1" class="data row0 col1" >0.400</td>
#       <td id="T_9acbf_row0_col2" class="data row0 col2" >0.589</td>
#       <td id="T_9acbf_row0_col3" class="data row0 col3" >0.361</td>
#     </tr>
#     <tr>
#       <th id="T_9acbf_level0_row1" class="row_heading level0 row1" >dpo</th>
#       <td id="T_9acbf_row1_col0" class="data row1 col0" >0.988</td>
#       <td id="T_9acbf_row1_col1" class="data row1 col1" >0.816</td>
#       <td id="T_9acbf_row1_col2" class="data row1 col2" >0.559</td>
#       <td id="T_9acbf_row1_col3" class="data row1 col3" >0.376</td>
#     </tr>
#     <tr>
#       <th id="T_9acbf_level0_row2" class="row_heading level0 row2" >projgrad</th>
#       <td id="T_9acbf_row2_col0" class="data row2 col0" >0.984</td>
#       <td id="T_9acbf_row2_col1" class="data row2 col1" >0.806</td>
#       <td id="T_9acbf_row2_col2" class="data row2 col2" >0.539</td>
#       <td id="T_9acbf_row2_col3" class="data row2 col3" >0.371</td>
#     </tr>
#     <tr>
#       <th id="T_9acbf_level0_row3" class="row_heading level0 row3" >hs-ETHER-PrefVec</th>
#       <td id="T_9acbf_row3_col0" class="data row3 col0" >0.723</td>
#       <td id="T_9acbf_row3_col1" class="data row3 col1" >0.699</td>
#       <td id="T_9acbf_row3_col2" class="data row3 col2" >0.403</td>
#       <td id="T_9acbf_row3_col3" class="data row3 col3" >0.477</td>
#     </tr>
#     <tr>
#       <th id="T_9acbf_level0_row4" class="row_heading level0 row4" >hs-None-PrefVec</th>
#       <td id="T_9acbf_row4_col0" class="data row4 col0" >0.738</td>
#       <td id="T_9acbf_row4_col1" class="data row4 col1" >0.713</td>
#       <td id="T_9acbf_row4_col2" class="data row4 col2" >0.402</td>
#       <td id="T_9acbf_row4_col3" class="data row4 col3" >0.509</td>
#     </tr>
#     <tr>
#       <th id="T_9acbf_level0_row5" class="row_heading level0 row5" >hs-SupressedHS-PrefVec</th>
#       <td id="T_9acbf_row5_col0" class="data row5 col0" >0.732</td>
#       <td id="T_9acbf_row5_col1" class="data row5 col1" >0.715</td>
#       <td id="T_9acbf_row5_col2" class="data row5 col2" >0.388</td>
#       <td id="T_9acbf_row5_col3" class="data row5 col3" >0.490</td>
#     </tr>
#   </tbody>
# </table>
# Table 2: Absolute accuracy after training with adapter on ds:`truthful_qa` compared to base model `wassname/llama-3-2-1b-sft` for various distribution shifts:
# - `train` 	:`genies / truthful qa	(train)`
# - `test` 	:`genies / truthful qa	(test)`
# - `oos` 	:`genies / alpaca mmlu	(test)`
# - `rnd` 	:`ethics / justice	(test)`
#
# ## wassname/llama-3-2-1b-sft - unhelpful_alpaca
# 2025-04-02_16-18-39
# <style type="text/css">
# #T_8dcb3_row0_col0, #T_8dcb3_row0_col1, #T_8dcb3_row2_col2, #T_8dcb3_row3_col1, #T_8dcb3_row4_col2, #T_8dcb3_row5_col2, #T_8dcb3_row6_col2, #T_8dcb3_row7_col2, #T_8dcb3_row8_col0, #T_8dcb3_row9_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_8dcb3_row0_col2 {
#   background-color: #c8d5e5;
#   color: #000000;
#   font-weight: bold;
# }
# #T_8dcb3_row0_col3, #T_8dcb3_row1_col3, #T_8dcb3_row2_col0, #T_8dcb3_row2_col3, #T_8dcb3_row3_col3, #T_8dcb3_row4_col1, #T_8dcb3_row5_col0, #T_8dcb3_row6_col0, #T_8dcb3_row7_col0, #T_8dcb3_row8_col2, #T_8dcb3_row9_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_8dcb3_row1_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8dcb3_row1_col1 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8dcb3_row1_col2 {
#   background-color: #f1e5e7;
#   color: #000000;
# }
# #T_8dcb3_row2_col1 {
#   background-color: #db5872;
#   color: #f1f1f1;
# }
# #T_8dcb3_row3_col0 {
#   background-color: #5182bf;
#   color: #f1f1f1;
# }
# #T_8dcb3_row3_col2 {
#   background-color: #ecc5cc;
#   color: #000000;
# }
# #T_8dcb3_row4_col0 {
#   background-color: #d8405e;
#   color: #f1f1f1;
# }
# #T_8dcb3_row4_col3 {
#   background-color: #769ccb;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_8dcb3_row5_col1 {
#   background-color: #d84361;
#   color: #f1f1f1;
# }
# #T_8dcb3_row5_col3 {
#   background-color: #638ec5;
#   color: #f1f1f1;
# }
# #T_8dcb3_row6_col1 {
#   background-color: #d94663;
#   color: #f1f1f1;
# }
# #T_8dcb3_row6_col3 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
# }
# #T_8dcb3_row7_col1 {
#   background-color: #d84462;
#   color: #f1f1f1;
# }
# #T_8dcb3_row7_col3 {
#   background-color: #5b89c2;
#   color: #f1f1f1;
# }
# #T_8dcb3_row8_col1 {
#   background-color: #5887c1;
#   color: #f1f1f1;
# }
# #T_8dcb3_row8_col3 {
#   background-color: #e0798d;
#   color: #f1f1f1;
# }
# #T_8dcb3_row9_col1 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
# }
# #T_8dcb3_row9_col3 {
#   background-color: #e17d91;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8dcb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dcb3_level0_col0" class="col_heading level0 col0" >train</th>
#       <th id="T_8dcb3_level0_col1" class="col_heading level0 col1" >test</th>
#       <th id="T_8dcb3_level0_col2" class="col_heading level0 col2" >oos</th>
#       <th id="T_8dcb3_level0_col3" class="col_heading level0 col3" >rnd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dcb3_level0_row0" class="row_heading level0 row0" >hs-HRA-PrefVec</th>
#       <td id="T_8dcb3_row0_col0" class="data row0 col0" >0.993</td>
#       <td id="T_8dcb3_row0_col1" class="data row0 col1" >0.994</td>
#       <td id="T_8dcb3_row0_col2" class="data row0 col2" >0.762</td>
#       <td id="T_8dcb3_row0_col3" class="data row0 col3" >0.386</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row1" class="row_heading level0 row1" >hs-ETHER-PrefVec</th>
#       <td id="T_8dcb3_row1_col0" class="data row1 col0" >0.997</td>
#       <td id="T_8dcb3_row1_col1" class="data row1 col1" >0.994</td>
#       <td id="T_8dcb3_row1_col2" class="data row1 col2" >0.665</td>
#       <td id="T_8dcb3_row1_col3" class="data row1 col3" >0.373</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row2" class="row_heading level0 row2" >hs-None-PrefVec</th>
#       <td id="T_8dcb3_row2_col0" class="data row2 col0" >0.383</td>
#       <td id="T_8dcb3_row2_col1" class="data row2 col1" >0.392</td>
#       <td id="T_8dcb3_row2_col2" class="data row2 col2" >0.499</td>
#       <td id="T_8dcb3_row2_col3" class="data row2 col3" >0.384</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row3" class="row_heading level0 row3" >hs-SupressedHS-PrefVec</th>
#       <td id="T_8dcb3_row3_col0" class="data row3 col0" >0.508</td>
#       <td id="T_8dcb3_row3_col1" class="data row3 col1" >0.513</td>
#       <td id="T_8dcb3_row3_col2" class="data row3 col2" >0.430</td>
#       <td id="T_8dcb3_row3_col3" class="data row3 col3" >0.380</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row4" class="row_heading level0 row4" >hs-SupressedHS-Rank</th>
#       <td id="T_8dcb3_row4_col0" class="data row4 col0" >0.287</td>
#       <td id="T_8dcb3_row4_col1" class="data row4 col1" >0.284</td>
#       <td id="T_8dcb3_row4_col2" class="data row4 col2" >0.424</td>
#       <td id="T_8dcb3_row4_col3" class="data row4 col3" >0.403</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row5" class="row_heading level0 row5" >side-None-PrefVec</th>
#       <td id="T_8dcb3_row5_col0" class="data row5 col0" >0.074</td>
#       <td id="T_8dcb3_row5_col1" class="data row5 col1" >0.082</td>
#       <td id="T_8dcb3_row5_col2" class="data row5 col2" >0.413</td>
#       <td id="T_8dcb3_row5_col3" class="data row5 col3" >0.382</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row6" class="row_heading level0 row6" >base</th>
#       <td id="T_8dcb3_row6_col0" class="data row6 col0" >0.055</td>
#       <td id="T_8dcb3_row6_col1" class="data row6 col1" >0.064</td>
#       <td id="T_8dcb3_row6_col2" class="data row6 col2" >0.386</td>
#       <td id="T_8dcb3_row6_col3" class="data row6 col3" >0.361</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row7" class="row_heading level0 row7" >hs-SupressedHS-MSE</th>
#       <td id="T_8dcb3_row7_col0" class="data row7 col0" >0.055</td>
#       <td id="T_8dcb3_row7_col1" class="data row7 col1" >0.064</td>
#       <td id="T_8dcb3_row7_col2" class="data row7 col2" >0.386</td>
#       <td id="T_8dcb3_row7_col3" class="data row7 col3" >0.363</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row8" class="row_heading level0 row8" >dpo</th>
#       <td id="T_8dcb3_row8_col0" class="data row8 col0" >0.910</td>
#       <td id="T_8dcb3_row8_col1" class="data row8 col1" >0.868</td>
#       <td id="T_8dcb3_row8_col2" class="data row8 col2" >0.230</td>
#       <td id="T_8dcb3_row8_col3" class="data row8 col3" >0.346</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb3_level0_row9" class="row_heading level0 row9" >projgrad</th>
#       <td id="T_8dcb3_row9_col0" class="data row9 col0" >0.910</td>
#       <td id="T_8dcb3_row9_col1" class="data row9 col1" >0.866</td>
#       <td id="T_8dcb3_row9_col2" class="data row9 col2" >0.223</td>
#       <td id="T_8dcb3_row9_col3" class="data row9 col3" >0.347</td>
#     </tr>
#   </tbody>
# </table>
# Table 2: Absolute accuracy after training with adapter on ds:`unhelpful_alpaca` compared to base model `wassname/llama-3-2-1b-sft` for various distribution shifts:
# - `train` 	:`genies / unhelpful alpaca	(train)`
# - `test` 	:`genies / unhelpful alpaca	(test)`
# - `oos` 	:`genies / illegal dont help	(test)`
# - `rnd` 	:`ethics / justice	(test)`
