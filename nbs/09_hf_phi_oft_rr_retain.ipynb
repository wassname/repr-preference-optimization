# %% [markdown]
# Trying to modify hf dpo to work with the repos hypothesis...
#
# see
# - https://huggingface.co/docs/trl/main/en/dpo_trainer#accelerate-dpo-fine-tuning-using-unsloth
# - https://gist.github.com/alvarobartt/9898c33eb3e9c7108d9ed2330f12a708
# - https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing#scrollTo=QtoqUw80QDV0

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["WANDB_PROJECT"] = "repo-dpo" 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# os.environ["WANDB_DISABLED"] = "true"

# %%
import wandb
os.environ['WANDB_NOTEBOOK_NAME'] = nb_name = os.path.basename(globals()['__vsc_ipynb_file__'])
# enable wandb service (experimental, https://github.com/wandb/client/blob/master/docs/dev/wandb-service-user.md)
# this hopefully fixes issues with multiprocessing
wandb.require(experiment='service')
# wandb.init()

# %%
import warnings
# warnings.simplefilter("ignore")
# warnings.filterwarnings("ignore", ".*does not have many workers.*")
# warnings.filterwarnings("ignore", ".*divide by zero.*")
warnings.filterwarnings("ignore", ".*torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly.*")
warnings.filterwarnings("ignore", ".*`do_sample` is set to.*")
warnings.filterwarnings("ignore", ".*None of the inputs have requires_grad=True. Gradients will be None*")

# %%
import torch
import numpy as np
from datasets import load_dataset
from peft import LoraConfig, get_peft_model

from transformers import AutoTokenizer, AutoModelForCausalLM
from trl import DPOTrainer
from trl import DPOConfig, DPOTrainer
import gc
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import Any, Callable, Dict, List, Literal, Optional, Tuple, Union
from einops import rearrange

# %%
from contextlib import contextmanager
import pandas as pd
from matplotlib import pyplot as plt
from transformers.trainer import ProgressCallback
from transformers.utils.notebook import NotebookProgressCallback

from reprpo.helpers.adapters import set_adapter

# %%
torch.set_float32_matmul_precision("medium")
# torch.use_deterministic_algorithms(True)

# %%
max_prompt_length=64
# num_samples = 50 * 16 * 6
num_samples = 1500 * 1 * 5 # from circuit breaker * 3
max_length = 128
num_samples
# Out:
# 7500

# %% [markdown]
# ## load the model

# %%
# !pip install flash-attn --no-build-isolation --no-deps -qq

# %%
# model

# %%
# FIXME: we are meant to SFT first, so that the preferences are in sample but 1) if this works it might not be needed, and 2) this can be added later, if it works
# for now we will use the instruct model, and try something it wasn't meant to do but it in sample 
model_name = "microsoft/Phi-3-mini-4k-instruct"
# model_name = "microsoft/Phi-3-mini-4k-instruct-gguf"
use_gradient_checkpointing = True

from peft.tuners import BOFTConfig, OFTConfig, HRAConfig
## Big adapter
peft_config = HRAConfig(
    apply_GS=True,
    r=16,
    target_modules=["qkv_proj", "down_proj"
                    "o_proj", "up_gate_proj",
                    ],
)
from reprpo.models.load import load_model, print_trainable_parameters




from peft import prepare_model_for_kbit_training
from peft import LoraConfig, get_peft_model

model, tokenizer = load_model(model_name, bnb=False )

if use_gradient_checkpointing:
    model.enable_input_require_grads()
from trl.trainer.utils import peft_module_casting_to_bf16
peft_module_casting_to_bf16(model)
adapter_name='ReprPO'
model = prepare_model_for_kbit_training(model, {'use_gradient_checkpointing': use_gradient_checkpointing})
model = get_peft_model(model, peft_config, adapter_name=adapter_name)
print_trainable_parameters(model)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# You are attempting to use Flash Attention 2.0 with a model not initialized on GPU. Make sure to move the model to GPU after initializing it on CPU with `model.to('cuda')`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 1572864 || all params: 3822326784 || trainable%: 0.04114938593382182

# %% [markdown]
# ## Dataset

# %%
def sample(dataset, N):
    return (dataset
            .shuffle(42)
            .select(range(
            min(len(dataset), N)))
    )

# %%
# dataset = load_dataset('Columbia-NLP/DPO-HelpSteer')
dataset = load_dataset('Atsunori/HelpSteer2-DPO')
dataset['train'] = sample(dataset['train'], num_samples)
dataset2 = dataset.rename_column('chosen_response', 'chosen').rename_column('rejected_response', 'rejected')
dataset2
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 7221
#     })
#     validation: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 373
#     })
# })

# %%
# def format_ds(row):
    
#     # WHY are we doing this? Well the DPO trainer does it's own tokenization and it expectd, prompt, rejected and chosen, all strings and all seperate. Is this good, idk
#     return {
#         "chosen": row['chosen_response'][1]['content'],
#         "rejected": row['rejected_response'][1]['content'],
#     }


# dataset2 = dataset.map(format_ds)

# %%
r = dataset2['train'][0]
print(r['prompt'])
print('===')
print(r['chosen'])
print('---')
print(r['rejected'])
# Out:
# When did women join the labor workforce outside of the home? What caused the change from housewife to breadwinner? Write a short informative paragraph under 200 words.
# ===
# In the early 20th century, less than 20% of women worked outside the home. Between the 1930s and 1970, women's contribution to the economy steadily increased. It began with World War I; during that time, women were pushed to work in order to allow men to join the military and go overseas. Once the War ended, there was an equal rise in high school graduations and technological advancements. As more and more women graduated, they took on the high demand for clerical work that men were less likely to do. Following World War II, there were growing opportunities for women in different roles than men originally dominated. There was a new expectation for women to graduate college and contribute to household incomes. By 1990, the percentage of women working increased by 76%. Recent research shows that there are approximately the same number of women in professional schools as men. According to Forbes in July 2023, 57.4 percent of the workforce are women.
# ---
# The 1900s saw a dramatic shift in the role of women in the workforce. Prior to this time, women were primarily homemakers and caregivers, with limited opportunities for paid work outside the home. However, with the rise of industrialization and the growth of the economy, women began to enter the workforce in increasing numbers.
#
# One of the primary factors that led to this change was the need for workers in factories and other industries. As men went off to war or pursued other opportunities, women were needed to fill the gaps in the workforce. This need for workers created a new sense of opportunity for women, who had previously been limited by social and cultural expectations.
#
# Another factor that contributed to the change was the growing feminist movement. Women's rights activists worked to break down barriers and stereotypes that prevented women from pursuing their own goals and ambitions. They fought for equal pay, equal opportunities, and the right to vote, among other rights.
#
# As a result of these and other factors, women began to enter the workforce in increasing numbers. They worked in factories, offices, and other industries, often performing the same jobs as men. This shift in the role of women had a profound impact on society, changing the way that people thought about gender roles and the value of women's work.
#
# Today, women continue to make up a significant portion of the workforce, and many have achieved success in a wide range of industries. While there is still work to be done to achieve true gender equality, the changes that began in the early 1900s have paved the way for a more diverse and inclusive workforce.

# %% [markdown]
# ## Eval TQA helpers

# %%
from reprpo.data.tqa import load_tqa
from torch.utils.data import DataLoader
import numpy as np


# dataset2_tqa, choice_ids = load_tqa(tokenizer, max_length, N=817)

# %% [markdown]
# How to measure TQA?
# - [TruthfullLamama](https://github.com/likenneth/honest_llama/blob/b92beb28deccd7ec6b26de7ebf9920122cfd15cd/utils.py#L268) uses https://github.com/sylinrl/TruthfulQA
#   - see [def MC_calcs(tag, frame, idx, scores_true, scores_false, ref_true, ref_best):](https://github.com/sylinrl/TruthfulQA/blob/fdd8ad1c0d00a478cf8b0bb41a3ad8378c16293b/truthfulqa/models.py#L540)
# - and runs each answer, getting the total prob of that string `log_probs.sum()`

# %%
# from reprpo.eval.mc import eval_tqa
from reprpo.gen import generation_test

# %% [markdown]
# ## Train

# %% [markdown]
# ### Modified classes
#
# - here we can defined the experimetns loss function

# %%
from reprpo.trainer import ReprPOTrainer, ReprPOConfig, wmean, coeffecient, top_k_mse, norm_smooth_l1_loss, cka_inspired_similarity, symlog_loss, mean_with_attention, normalize_output, sum_squared_error


class ReprPOTrainer2(ReprPOTrainer):
    pass

    # def reprpo_loss(
    #     self,
    #     policy_chosen_logps: torch.FloatTensor,
    #     policy_rejected_logps: torch.FloatTensor,
    #     policy_chosen_hs: torch.FloatTensor,
    #     policy_rejected_hs: torch.FloatTensor,
    #     reference_chosen_logps: torch.FloatTensor,
    #     reference_rejected_logps: torch.FloatTensor,
    #     reference_chosen_hs: torch.FloatTensor,
    #     chosen_attn_mask: torch.BoolTensor,
    #     rejected_attn_mask: torch.BoolTensor
    # ) -> Tuple[torch.FloatTensor, torch.FloatTensor, torch.FloatTensor]:

    #     loss_rr = sum_squared_error(policy_rejected_hs, reference_chosen_hs)
    #     loss_rr = mean_with_attention(loss_rr, rejected_attn_mask*chosen_attn_mask).mean()
        
    #     loss = loss_rr.sum()

    #     loss_dict = dict(loss=loss.detach())

    #     # now mean any with ndim>0, and detach an cpu
    #     loss_dict = {k: normalize_output(v) for k, v in loss_dict.items()}

    #     return loss, loss_dict

# %% [markdown]
# ### Run

# %%
from reprpo.helpers.torch import clear_mem
clear_mem()

# %%
# update the ideal number of sample for how many are available
num_data_samples = min(num_samples, len(dataset2['train']))
num_data_samples
# Out:
# 7221

# %%
num_samples
# Out:
# 7500

# %%
model.peft_config
# Out:
# {'ReprPO': HRAConfig(peft_type=<PeftType.HRA: 'HRA'>, auto_mapping=None, base_model_name_or_path='microsoft/Phi-3-mini-4k-instruct', revision=None, task_type=None, inference_mode=False, r=16, apply_GS=True, target_modules={'up_gate_proj', 'qkv_proj', 'down_projo_proj'}, init_weights=True, layers_to_transform=None, layers_pattern=None, bias='none', modules_to_save=None)}

# %%
ideal_batch_size = 14
batch_size = 14
gradient_accumulation_steps = ideal_batch_size // batch_size
num_train_epochs = num_samples // num_data_samples
print(dict(gradient_accumulation_steps=gradient_accumulation_steps, num_train_epochs=num_train_epochs))

# vscode + wandb compat
nb_name = os.path.basename(globals()['__vsc_ipynb_file__']).replace('.ipynb', '')
dt = pd.Timestamp.now().strftime("%Y-%m-%d-%H-%M-%S")
run_name = f"{nb_name}-{dt}"

training_args = ReprPOConfig(
    num_train_epochs=num_train_epochs,
    learning_rate=1e-3, # 5e-7 in the dpo paper? but this method needs much more
    gradient_accumulation_steps=gradient_accumulation_steps,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size//2,

    lr_scheduler_type="constant",
    # warmup_ratio=0.2,
    optim = "adamw_8bit",
    weight_decay = 0,

    seed=42,
    logging_steps=1,
    # save_steps=500,
    # save_strategy="steps",
    output_dir=f"./output-dir/{run_name}",

    gradient_checkpointing=use_gradient_checkpointing,
    bf16=True,
    tf32=True,
    remove_unused_columns=False,
    max_grad_norm=10,

    max_prompt_length=max_prompt_length,
    max_length=max_length,

    report_to=['tensorboard', 'wandb'],
    model_adapter_name='ReprPO',
    alpha=10,

    run_name=run_name,
    collection_layers=[10, 25],
)

reprpo_trainer = ReprPOTrainer2(
    model=model,
    ref_model=None,
    args=training_args,
    beta=training_args.beta,
    train_dataset=dataset2["train"],
    # eval_dataset=dataset2["test"],
    tokenizer=tokenizer,
)
model.config.use_cache = False

# Transformer does not recognise vscode notebooks
reprpo_trainer.callback_handler.remove_callback(ProgressCallback)
reprpo_trainer.callback_handler.add_callback(NotebookProgressCallback)
# Out:
# {'gradient_accumulation_steps': 1, 'num_train_epochs': 1}

# %%
# # QC train dataset
# r = reprpo_trainer.train_dataset[0]
# print('prompt', tokenizer.decode(r['prompt_input_ids']))
# print('-'*80)q
# print('chosen',tokenizer.decode(r['chosen_input_ids']))
# print('-'*80)
# print('rejected',tokenizer.decode(r['rejected_input_ids']))
# print('='*80)
clear_mem()

# %%
reprpo_trainer.train()
# Out:
# wandb: Currently logged in as: wassname. Use `wandb login --relogin` to force relogin
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/nbs/wandb/run-20240721_094512-rxz7gr5z</code>
# Syncing run <strong><a href='https://wandb.ai/wassname/repo-dpo/runs/rxz7gr5z' target="_blank">09_hf_phi_oft_rr_retain-2024-07-21-09-45-06</a></strong> to <a href='https://wandb.ai/wassname/repo-dpo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/wassname/repo-dpo' target="_blank">https://wandb.ai/wassname/repo-dpo</a>
#  View run at <a href='https://wandb.ai/wassname/repo-dpo/runs/rxz7gr5z' target="_blank">https://wandb.ai/wassname/repo-dpo/runs/rxz7gr5z</a>
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
# 0 retain_cos_sim: 0.9524. rr_cos_sim: 0.7754
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.5', 'loss': '1.2e+02', 'rewards/chosen': '-0.0054', 'rewards/rejected': '-0.01', 'retain/loss': '58', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.12', 'logratios/ref': '-0.16', 'weighting': '0.071', 'logits': '0.047', 'component_rr/loss': '1.2e+02', 'component_retain/loss': '0', 'rr/c': '1', 'retain/c': '0', 'retain_cosine': '0.95', 'rr_cosine': '0.78'}
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='516' max='516' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [516/516 31:54, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>122.985001</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>292.318787</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5087.510254</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1405.765503</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>295.577515</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1550.901245</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>297.070129</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>305.887451</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>286.102814</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>301.606659</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>991.549316</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>405.180298</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>249.763306</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>263.410553</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>272.822571</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>248.541565</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>261.578369</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>262.202515</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>209.601074</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>306.180603</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>473.455994</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>236.388092</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>230.136200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>245.616486</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>238.272522</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>265.818726</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>219.328430</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>218.357040</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>195.240784</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>282.457123</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>196.891388</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>218.129395</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>203.967026</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>189.524780</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>233.395004</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>210.297577</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>207.782745</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>202.600800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>143.276779</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>223.876022</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>227.000549</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>215.757385</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>221.804565</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>214.792145</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>232.777313</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>181.364716</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>192.914536</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>258.564941</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>200.421875</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>244.014923</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>215.522339</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>231.089584</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>234.633469</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>239.235382</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>396.496643</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>238.851501</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>174.738312</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>130.475601</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>233.080719</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>223.121887</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>229.921326</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>268.464661</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>201.068268</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>167.728394</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>225.395203</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>218.186005</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>157.456329</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>197.007034</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>364.703369</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>197.425201</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>232.339325</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>170.941238</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>147.447144</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>190.175079</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>173.675766</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>155.160065</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>173.997147</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>179.087555</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>373.614288</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>190.885071</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>185.599823</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>283.973328</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>150.215775</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>142.592529</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>138.175674</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>147.513657</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>197.948608</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>121.706970</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>155.537659</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>161.416107</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>146.845169</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>148.430618</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>158.906204</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>130.305206</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>128.689056</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>176.132080</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>123.309875</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>142.735168</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>128.330780</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>127.756126</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>128.209137</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>122.650826</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>128.536407</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>126.295776</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>122.545197</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>180.064087</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>215.140656</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>142.806854</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>160.737762</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>158.232391</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>129.826874</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>142.920288</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>136.754822</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>125.802536</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>114.725067</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>154.487030</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>149.537292</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>138.569458</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>133.024109</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>140.596130</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>121.975693</td>
#     </tr>
#     <tr>
#       <td>122</td>
# 10 retain_cos_sim: 0.4933. rr_cos_sim: 0.4973
# {'logps/rejected': '-9.1', 'logps/chosen': '-8.9', 'loss': '9.9e+02', 'rewards/chosen': '-0.72', 'rewards/rejected': '-0.68', 'retain/loss': '1.2e+03', 'rr/loss': '8.8e+02', 'logratios/pi': '0.14', 'logratios/ref': '0.52', 'weighting': '0.071', 'logits': '-0.38', 'component_rr/loss': '8.8e+02', 'component_retain/loss': '1.2e+02', 'rr/c': '0.99', 'retain/c': '0.0097', 'retain_cosine': '0.49', 'rr_cosine': '0.5'}
# 20 retain_cos_sim: 0.7268. rr_cos_sim: 0.6362
# {'logps/rejected': '-7.5', 'logps/chosen': '-8', 'loss': '4.7e+02', 'rewards/chosen': '-0.66', 'rewards/rejected': '-0.62', 'retain/loss': '8.5e+02', 'rr/loss': '3.2e+02', 'logratios/pi': '-0.5', 'logratios/ref': '-0.16', 'weighting': '0.071', 'logits': '-0.33', 'component_rr/loss': '3.1e+02', 'component_retain/loss': '1.6e+02', 'rr/c': '0.98', 'retain/c': '0.019', 'retain_cosine': '0.73', 'rr_cosine': '0.64'}
# 30 retain_cos_sim: 0.7908. rr_cos_sim: 0.7356
# {'logps/rejected': '-6.3', 'logps/chosen': '-6.3', 'loss': '2e+02', 'rewards/chosen': '-0.5', 'rewards/rejected': '-0.45', 'retain/loss': '90', 'rr/loss': '1.8e+02', 'logratios/pi': '0.016', 'logratios/ref': '0.51', 'weighting': '0.071', 'logits': '-0.49', 'component_rr/loss': '1.7e+02', 'component_retain/loss': '26', 'rr/c': '0.97', 'retain/c': '0.029', 'retain_cosine': '0.79', 'rr_cosine': '0.74'}
# 40 retain_cos_sim: 0.8811. rr_cos_sim: 0.7689
# {'logps/rejected': '-4.6', 'logps/chosen': '-4.5', 'loss': '2.3e+02', 'rewards/chosen': '-0.31', 'rewards/rejected': '-0.33', 'retain/loss': '1.9e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '0.17', 'logratios/ref': '-0.01', 'weighting': '0.071', 'logits': '0.18', 'component_rr/loss': '1.5e+02', 'component_retain/loss': '75', 'rr/c': '0.96', 'retain/c': '0.039', 'retain_cosine': '0.88', 'rr_cosine': '0.77'}
# 50 retain_cos_sim: 0.9183. rr_cos_sim: 0.7877
# {'logps/rejected': '-4.1', 'logps/chosen': '-4.2', 'loss': '2.2e+02', 'rewards/chosen': '-0.26', 'rewards/rejected': '-0.28', 'retain/loss': '1.8e+02', 'rr/loss': '1.3e+02', 'logratios/pi': '-0.079', 'logratios/ref': '-0.21', 'weighting': '0.071', 'logits': '0.13', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '88', 'rr/c': '0.95', 'retain/c': '0.048', 'retain_cosine': '0.92', 'rr_cosine': '0.79'}
# 60 retain_cos_sim: 0.9469. rr_cos_sim: 0.7884
# {'logps/rejected': '-1.8', 'logps/chosen': '-1.8', 'loss': '2.3e+02', 'rewards/chosen': '-0.049', 'rewards/rejected': '-0.036', 'retain/loss': '1.7e+02', 'rr/loss': '1.4e+02', 'logratios/pi': '0.055', 'logratios/ref': '0.19', 'weighting': '0.071', 'logits': '-0.13', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '1e+02', 'rr/c': '0.94', 'retain/c': '0.058', 'retain_cosine': '0.95', 'rr_cosine': '0.79'}
# 70 retain_cos_sim: 0.9544. rr_cos_sim: 0.7686
# {'logps/rejected': '-1.6', 'logps/chosen': '-1.6', 'loss': '2.3e+02', 'rewards/chosen': '-0.019', 'rewards/rejected': '-0.021', 'retain/loss': '1.2e+02', 'rr/loss': '1.6e+02', 'logratios/pi': '0.0085', 'logratios/ref': '-0.019', 'weighting': '0.071', 'logits': '0.027', 'component_rr/loss': '1.5e+02', 'component_retain/loss': '80', 'rr/c': '0.93', 'retain/c': '0.068', 'retain_cosine': '0.95', 'rr_cosine': '0.77'}
# 80 retain_cos_sim: 0.9811. rr_cos_sim: 0.7744
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.3', 'loss': '1.9e+02', 'rewards/chosen': '-0.00089', 'rewards/rejected': '0.00062', 'retain/loss': '77', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.026', 'logratios/ref': '-0.011', 'weighting': '0.071', 'logits': '-0.015', 'component_rr/loss': '1.3e+02', 'component_retain/loss': '60', 'rr/c': '0.92', 'retain/c': '0.078', 'retain_cosine': '0.98', 'rr_cosine': '0.77'}
# 90 retain_cos_sim: 0.9783. rr_cos_sim: 0.7745
# {'logps/rejected': '-1.6', 'logps/chosen': '-1.1', 'loss': '1.5e+02', 'rewards/chosen': '-0.0038', 'rewards/rejected': '-0.0044', 'retain/loss': '49', 'rr/loss': '1.1e+02', 'logratios/pi': '0.46', 'logratios/ref': '0.45', 'weighting': '0.071', 'logits': '0.0063', 'component_rr/loss': '1e+02', 'component_retain/loss': '43', 'rr/c': '0.91', 'retain/c': '0.087', 'retain_cosine': '0.98', 'rr_cosine': '0.77'}
# 100 retain_cos_sim: 0.9831. rr_cos_sim: 0.8042
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.3', 'loss': '1.3e+02', 'rewards/chosen': '-0.00066', 'rewards/rejected': '-0.00024', 'retain/loss': '33', 'rr/loss': '1.1e+02', 'logratios/pi': '0.067', 'logratios/ref': '0.071', 'weighting': '0.071', 'logits': '-0.0042', 'component_rr/loss': '96', 'component_retain/loss': '32', 'rr/c': '0.9', 'retain/c': '0.097', 'retain_cosine': '0.98', 'rr_cosine': '0.8'}
# 110 retain_cos_sim: 0.9841. rr_cos_sim: 0.8074
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.3', 'loss': '1.3e+02', 'rewards/chosen': '0.002', 'rewards/rejected': '0.0019', 'retain/loss': '37', 'rr/loss': '1e+02', 'logratios/pi': '0.057', 'logratios/ref': '0.056', 'weighting': '0.071', 'logits': '0.00039', 'component_rr/loss': '91', 'component_retain/loss': '39', 'rr/c': '0.89', 'retain/c': '0.11', 'retain_cosine': '0.98', 'rr_cosine': '0.81'}
# 120 retain_cos_sim: 0.9857. rr_cos_sim: 0.8010
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.3', 'loss': '1.2e+02', 'rewards/chosen': '-0.0022', 'rewards/rejected': '-0.0012', 'retain/loss': '31', 'rr/loss': '97', 'logratios/pi': '0.022', 'logratios/ref': '0.032', 'weighting': '0.071', 'logits': '-0.01', 'component_rr/loss': '86', 'component_retain/loss': '36', 'rr/c': '0.88', 'retain/c': '0.12', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 130 retain_cos_sim: 0.9875. rr_cos_sim: 0.7934
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.3', 'loss': '1.2e+02', 'rewards/chosen': '-0.0014', 'rewards/rejected': '-0.0014', 'retain/loss': '26', 'rr/loss': '1e+02', 'logratios/pi': '0.093', 'logratios/ref': '0.094', 'weighting': '0.071', 'logits': '-0.00015', 'component_rr/loss': '90', 'component_retain/loss': '33', 'rr/c': '0.87', 'retain/c': '0.13', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 140 retain_cos_sim: 0.9887. rr_cos_sim: 0.7695
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.2', 'loss': '1.4e+02', 'rewards/chosen': '-0.0027', 'rewards/rejected': '0.0031', 'retain/loss': '27', 'rr/loss': '1.2e+02', 'logratios/pi': '0.17', 'logratios/ref': '0.23', 'weighting': '0.071', 'logits': '-0.058', 'component_rr/loss': '1.1e+02', 'component_retain/loss': '37', 'rr/c': '0.86', 'retain/c': '0.14', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 150 retain_cos_sim: 0.9890. rr_cos_sim: 0.7963
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.3', 'loss': '1.4e+02', 'rewards/chosen': '-0.0023', 'rewards/rejected': '0.00083', 'retain/loss': '32', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.13', 'logratios/ref': '-0.1', 'weighting': '0.071', 'logits': '-0.032', 'component_rr/loss': '98', 'component_retain/loss': '46', 'rr/c': '0.85', 'retain/c': '0.15', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 160 retain_cos_sim: 0.9913. rr_cos_sim: 0.8145
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.4', 'loss': '1.7e+02', 'rewards/chosen': '0.00035', 'rewards/rejected': '0.00064', 'retain/loss': '57', 'rr/loss': '97', 'logratios/pi': '-0.026', 'logratios/ref': '-0.023', 'weighting': '0.071', 'logits': '-0.0029', 'component_rr/loss': '82', 'component_retain/loss': '89', 'rr/c': '0.84', 'retain/c': '0.16', 'retain_cosine': '0.99', 'rr_cosine': '0.81'}
# 170 retain_cos_sim: 0.9905. rr_cos_sim: 0.8050
# {'logps/rejected': '-1.1', 'logps/chosen': '-0.94', 'loss': '1.4e+02', 'rewards/chosen': '0.003', 'rewards/rejected': '0.0034', 'retain/loss': '25', 'rr/loss': '1.2e+02', 'logratios/pi': '0.15', 'logratios/ref': '0.16', 'weighting': '0.071', 'logits': '-0.0034', 'component_rr/loss': '99', 'component_retain/loss': '40', 'rr/c': '0.84', 'retain/c': '0.16', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 180 retain_cos_sim: 0.9919. rr_cos_sim: 0.7927
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.1', 'loss': '1.4e+02', 'rewards/chosen': '0.0025', 'rewards/rejected': '0.0023', 'retain/loss': '26', 'rr/loss': '1.1e+02', 'logratios/pi': '0.21', 'logratios/ref': '0.21', 'weighting': '0.071', 'logits': '0.0024', 'component_rr/loss': '91', 'component_retain/loss': '45', 'rr/c': '0.83', 'retain/c': '0.17', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 190 retain_cos_sim: 0.9907. rr_cos_sim: 0.7772
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.5', 'loss': '1.5e+02', 'rewards/chosen': '-0.0012', 'rewards/rejected': '-0.00034', 'retain/loss': '31', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.29', 'logratios/ref': '-0.28', 'weighting': '0.071', 'logits': '-0.0091', 'component_rr/loss': '92', 'component_retain/loss': '56', 'rr/c': '0.82', 'retain/c': '0.18', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 200 retain_cos_sim: 0.9916. rr_cos_sim: 0.8180
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.3', 'loss': '1.2e+02', 'rewards/chosen': '-0.0026', 'rewards/rejected': '0.0012', 'retain/loss': '23', 'rr/loss': '91', 'logratios/pi': '-0.039', 'logratios/ref': '-0.00083', 'weighting': '0.071', 'logits': '-0.038', 'component_rr/loss': '73', 'component_retain/loss': '45', 'rr/c': '0.81', 'retain/c': '0.19', 'retain_cosine': '0.99', 'rr_cosine': '0.82'}
# 210 retain_cos_sim: 0.9904. rr_cos_sim: 0.7789
# {'logps/rejected': '-1.6', 'logps/chosen': '-1.3', 'loss': '1.4e+02', 'rewards/chosen': '-0.0022', 'rewards/rejected': '0.0011', 'retain/loss': '27', 'rr/loss': '1.1e+02', 'logratios/pi': '0.3', 'logratios/ref': '0.33', 'weighting': '0.071', 'logits': '-0.033', 'component_rr/loss': '86', 'component_retain/loss': '55', 'rr/c': '0.8', 'retain/c': '0.2', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 220 retain_cos_sim: 0.9912. rr_cos_sim: 0.7748
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.5', 'loss': '2.3e+02', 'rewards/chosen': '-0.0018', 'rewards/rejected': '0.0002', 'retain/loss': '67', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.061', 'logratios/ref': '-0.041', 'weighting': '0.071', 'logits': '-0.02', 'component_rr/loss': '87', 'component_retain/loss': '1.4e+02', 'rr/c': '0.79', 'retain/c': '0.21', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 230 retain_cos_sim: 0.9914. rr_cos_sim: 0.7836
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.4', 'loss': '2e+02', 'rewards/chosen': '-0.00089', 'rewards/rejected': '0.00047', 'retain/loss': '48', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.17', 'logratios/ref': '-0.16', 'weighting': '0.071', 'logits': '-0.014', 'component_rr/loss': '94', 'component_retain/loss': '1.1e+02', 'rr/c': '0.78', 'retain/c': '0.22', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 240 retain_cos_sim: 0.9912. rr_cos_sim: 0.7678
# {'logps/rejected': '-1.7', 'logps/chosen': '-1.4', 'loss': '1.3e+02', 'rewards/chosen': '0.0002', 'rewards/rejected': '-0.00017', 'retain/loss': '21', 'rr/loss': '1e+02', 'logratios/pi': '0.25', 'logratios/ref': '0.25', 'weighting': '0.071', 'logits': '0.0037', 'component_rr/loss': '79', 'component_retain/loss': '49', 'rr/c': '0.77', 'retain/c': '0.23', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 250 retain_cos_sim: 0.9918. rr_cos_sim: 0.7927
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.4', 'loss': '1.3e+02', 'rewards/chosen': '0.0029', 'rewards/rejected': '7.9e-06', 'retain/loss': '20', 'rr/loss': '1e+02', 'logratios/pi': '-0.066', 'logratios/ref': '-0.095', 'weighting': '0.071', 'logits': '0.029', 'component_rr/loss': '79', 'component_retain/loss': '48', 'rr/c': '0.76', 'retain/c': '0.24', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 260 retain_cos_sim: 0.9920. rr_cos_sim: 0.7925
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.2', 'loss': '1.3e+02', 'rewards/chosen': '-0.0012', 'rewards/rejected': '0.00029', 'retain/loss': '23', 'rr/loss': '1e+02', 'logratios/pi': '0.033', 'logratios/ref': '0.048', 'weighting': '0.071', 'logits': '-0.015', 'component_rr/loss': '76', 'component_retain/loss': '59', 'rr/c': '0.75', 'retain/c': '0.25', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 270 retain_cos_sim: 0.9920. rr_cos_sim: 0.7693
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.3', 'loss': '2.1e+02', 'rewards/chosen': '0.0022', 'rewards/rejected': '0.0014', 'retain/loss': '41', 'rr/loss': '1.4e+02', 'logratios/pi': '-0.15', 'logratios/ref': '-0.16', 'weighting': '0.071', 'logits': '0.0079', 'component_rr/loss': '1e+02', 'component_retain/loss': '1.1e+02', 'rr/c': '0.74', 'retain/c': '0.26', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 280 retain_cos_sim: 0.9928. rr_cos_sim: 0.7737
# {'logps/rejected': '-1.5', 'logps/chosen': '-1.2', 'loss': '1.8e+02', 'rewards/chosen': '-0.00022', 'rewards/rejected': '-0.0021', 'retain/loss': '39', 'rr/loss': '1.1e+02', 'logratios/pi': '0.23', 'logratios/ref': '0.21', 'weighting': '0.071', 'logits': '0.019', 'component_rr/loss': '79', 'component_retain/loss': '1.1e+02', 'rr/c': '0.73', 'retain/c': '0.27', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 290 retain_cos_sim: 0.9924. rr_cos_sim: 0.7999
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.2', 'loss': '1.3e+02', 'rewards/chosen': '-0.0012', 'rewards/rejected': '0.0018', 'retain/loss': '24', 'rr/loss': '93', 'logratios/pi': '0.16', 'logratios/ref': '0.19', 'weighting': '0.071', 'logits': '-0.03', 'component_rr/loss': '67', 'component_retain/loss': '68', 'rr/c': '0.72', 'retain/c': '0.28', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 300 retain_cos_sim: 0.9930. rr_cos_sim: 0.7923
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.3', 'loss': '1.4e+02', 'rewards/chosen': '-0.0024', 'rewards/rejected': '-0.0013', 'retain/loss': '22', 'rr/loss': '1e+02', 'logratios/pi': '0.079', 'logratios/ref': '0.09', 'weighting': '0.071', 'logits': '-0.011', 'component_rr/loss': '74', 'component_retain/loss': '64', 'rr/c': '0.71', 'retain/c': '0.29', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 310 retain_cos_sim: 0.9934. rr_cos_sim: 0.8069
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.1', 'loss': '1.3e+02', 'rewards/chosen': '0.00025', 'rewards/rejected': '0.00016', 'retain/loss': '18', 'rr/loss': '1.1e+02', 'logratios/pi': '0.14', 'logratios/ref': '0.14', 'weighting': '0.071', 'logits': '0.00088', 'component_rr/loss': '74', 'component_retain/loss': '55', 'rr/c': '0.7', 'retain/c': '0.3', 'retain_cosine': '0.99', 'rr_cosine': '0.81'}
# 320 retain_cos_sim: 0.9944. rr_cos_sim: 0.8144
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.7', 'loss': '1.4e+02', 'rewards/chosen': '0.0016', 'rewards/rejected': '-0.0013', 'retain/loss': '21', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.37', 'logratios/ref': '-0.4', 'weighting': '0.071', 'logits': '0.029', 'component_rr/loss': '79', 'component_retain/loss': '66', 'rr/c': '0.69', 'retain/c': '0.31', 'retain_cosine': '0.99', 'rr_cosine': '0.81'}
# 330 retain_cos_sim: 0.9926. rr_cos_sim: 0.7992
# {'logps/rejected': '-1.8', 'logps/chosen': '-1.5', 'loss': '1.6e+02', 'rewards/chosen': '0.00054', 'rewards/rejected': '0.0029', 'retain/loss': '27', 'rr/loss': '1.1e+02', 'logratios/pi': '0.32', 'logratios/ref': '0.35', 'weighting': '0.071', 'logits': '-0.024', 'component_rr/loss': '76', 'component_retain/loss': '85', 'rr/c': '0.68', 'retain/c': '0.32', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 340 retain_cos_sim: 0.9939. rr_cos_sim: 0.7947
# {'logps/rejected': '-1.1', 'logps/chosen': '-1.4', 'loss': '1.4e+02', 'rewards/chosen': '0.00062', 'rewards/rejected': '-0.002', 'retain/loss': '19', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.32', 'logratios/ref': '-0.35', 'weighting': '0.071', 'logits': '0.026', 'component_rr/loss': '76', 'component_retain/loss': '62', 'rr/c': '0.67', 'retain/c': '0.33', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 350 retain_cos_sim: 0.9932. rr_cos_sim: 0.8013
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.8', 'loss': '1.4e+02', 'rewards/chosen': '0.00064', 'rewards/rejected': '0.00065', 'retain/loss': '20', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.41', 'logratios/ref': '-0.41', 'weighting': '0.071', 'logits': '-0.00018', 'component_rr/loss': '73', 'component_retain/loss': '68', 'rr/c': '0.66', 'retain/c': '0.34', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 360 retain_cos_sim: 0.9940. rr_cos_sim: 0.7730
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.5', 'loss': '1.4e+02', 'rewards/chosen': '-0.0019', 'rewards/rejected': '-0.005', 'retain/loss': '19', 'rr/loss': '1.1e+02', 'logratios/pi': '-0.039', 'logratios/ref': '-0.07', 'weighting': '0.071', 'logits': '0.032', 'component_rr/loss': '74', 'component_retain/loss': '65', 'rr/c': '0.65', 'retain/c': '0.35', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 370 retain_cos_sim: 0.9936. rr_cos_sim: 0.7938
# {'logps/rejected': '-1.5', 'logps/chosen': '-1.2', 'loss': '1.3e+02', 'rewards/chosen': '-0.001', 'rewards/rejected': '-0.0012', 'retain/loss': '18', 'rr/loss': '97', 'logratios/pi': '0.26', 'logratios/ref': '0.26', 'weighting': '0.071', 'logits': '0.0017', 'component_rr/loss': '62', 'component_retain/loss': '64', 'rr/c': '0.64', 'retain/c': '0.36', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 380 retain_cos_sim: 0.9942. rr_cos_sim: 0.7712
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.2', 'loss': '1.5e+02', 'rewards/chosen': '0.0032', 'rewards/rejected': '0.0013', 'retain/loss': '20', 'rr/loss': '1.2e+02', 'logratios/pi': '0.16', 'logratios/ref': '0.14', 'weighting': '0.071', 'logits': '0.019', 'component_rr/loss': '74', 'component_retain/loss': '72', 'rr/c': '0.63', 'retain/c': '0.37', 'retain_cosine': '0.99', 'rr_cosine': '0.77'}
# 390 retain_cos_sim: 0.9949. rr_cos_sim: 0.8014
# {'logps/rejected': '-1.7', 'logps/chosen': '-1.4', 'loss': '1.4e+02', 'rewards/chosen': '-0.0003', 'rewards/rejected': '-0.00053', 'retain/loss': '17', 'rr/loss': '1.2e+02', 'logratios/pi': '0.29', 'logratios/ref': '0.28', 'weighting': '0.071', 'logits': '0.0023', 'component_rr/loss': '73', 'component_retain/loss': '64', 'rr/c': '0.62', 'retain/c': '0.38', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 400 retain_cos_sim: 0.9947. rr_cos_sim: 0.8191
# {'logps/rejected': '-1.6', 'logps/chosen': '-1.5', 'loss': '1.6e+02', 'rewards/chosen': '0.0002', 'rewards/rejected': '-0.00051', 'retain/loss': '23', 'rr/loss': '1.1e+02', 'logratios/pi': '0.097', 'logratios/ref': '0.09', 'weighting': '0.071', 'logits': '0.0071', 'component_rr/loss': '70', 'component_retain/loss': '91', 'rr/c': '0.61', 'retain/c': '0.39', 'retain_cosine': '0.99', 'rr_cosine': '0.82'}
# 410 retain_cos_sim: 0.9943. rr_cos_sim: 0.7933
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.2', 'loss': '1.5e+02', 'rewards/chosen': '0.0014', 'rewards/rejected': '-0.00038', 'retain/loss': '20', 'rr/loss': '1.1e+02', 'logratios/pi': '0.029', 'logratios/ref': '0.011', 'weighting': '0.071', 'logits': '0.018', 'component_rr/loss': '69', 'component_retain/loss': '80', 'rr/c': '0.6', 'retain/c': '0.4', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 420 retain_cos_sim: 0.9937. rr_cos_sim: 0.8213
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.2', 'loss': '1.8e+02', 'rewards/chosen': '0.0014', 'rewards/rejected': '6.1e-05', 'retain/loss': '26', 'rr/loss': '1.2e+02', 'logratios/pi': '0.07', 'logratios/ref': '0.056', 'weighting': '0.071', 'logits': '0.013', 'component_rr/loss': '69', 'component_retain/loss': '1.1e+02', 'rr/c': '0.59', 'retain/c': '0.41', 'retain_cosine': '0.99', 'rr_cosine': '0.82'}
# 430 retain_cos_sim: 0.9945. rr_cos_sim: 0.7830
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.2', 'loss': '1.5e+02', 'rewards/chosen': '0.0013', 'rewards/rejected': '0.0019', 'retain/loss': '21', 'rr/loss': '1.1e+02', 'logratios/pi': '0.04', 'logratios/ref': '0.046', 'weighting': '0.071', 'logits': '-0.0064', 'component_rr/loss': '64', 'component_retain/loss': '88', 'rr/c': '0.58', 'retain/c': '0.42', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 440 retain_cos_sim: 0.9946. rr_cos_sim: 0.7850
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.2', 'loss': '1.9e+02', 'rewards/chosen': '0.0042', 'rewards/rejected': '0.0025', 'retain/loss': '22', 'rr/loss': '1.6e+02', 'logratios/pi': '0.17', 'logratios/ref': '0.15', 'weighting': '0.071', 'logits': '0.017', 'component_rr/loss': '91', 'component_retain/loss': '95', 'rr/c': '0.57', 'retain/c': '0.43', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 450 retain_cos_sim: 0.9949. rr_cos_sim: 0.7823
# {'logps/rejected': '-1.5', 'logps/chosen': '-1.6', 'loss': '1.4e+02', 'rewards/chosen': '0.004', 'rewards/rejected': '-2.9e-06', 'retain/loss': '18', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.043', 'logratios/ref': '-0.083', 'weighting': '0.071', 'logits': '0.04', 'component_rr/loss': '65', 'component_retain/loss': '76', 'rr/c': '0.56', 'retain/c': '0.44', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 460 retain_cos_sim: 0.9937. rr_cos_sim: 0.7856
# {'logps/rejected': '-1.4', 'logps/chosen': '-1.2', 'loss': '1.8e+02', 'rewards/chosen': '-0.00023', 'rewards/rejected': '0.0019', 'retain/loss': '27', 'rr/loss': '1.1e+02', 'logratios/pi': '0.18', 'logratios/ref': '0.2', 'weighting': '0.071', 'logits': '-0.022', 'component_rr/loss': '62', 'component_retain/loss': '1.2e+02', 'rr/c': '0.55', 'retain/c': '0.45', 'retain_cosine': '0.99', 'rr_cosine': '0.79'}
# 470 retain_cos_sim: 0.9936. rr_cos_sim: 0.8057
# {'logps/rejected': '-1.2', 'logps/chosen': '-1.2', 'loss': '1.8e+02', 'rewards/chosen': '0.001', 'rewards/rejected': '0.0019', 'retain/loss': '27', 'rr/loss': '1.1e+02', 'logratios/pi': '0.0045', 'logratios/ref': '0.013', 'weighting': '0.071', 'logits': '-0.0087', 'component_rr/loss': '59', 'component_retain/loss': '1.2e+02', 'rr/c': '0.54', 'retain/c': '0.46', 'retain_cosine': '0.99', 'rr_cosine': '0.81'}
# 480 retain_cos_sim: 0.9935. rr_cos_sim: 0.8005
# {'logps/rejected': '-1.5', 'logps/chosen': '-1.2', 'loss': '1.7e+02', 'rewards/chosen': '0.0018', 'rewards/rejected': '0.0042', 'retain/loss': '21', 'rr/loss': '1.3e+02', 'logratios/pi': '0.31', 'logratios/ref': '0.34', 'weighting': '0.071', 'logits': '-0.024', 'component_rr/loss': '69', 'component_retain/loss': '96', 'rr/c': '0.53', 'retain/c': '0.47', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# 490 retain_cos_sim: 0.9937. rr_cos_sim: 0.8274
# {'logps/rejected': '-1.1', 'logps/chosen': '-0.97', 'loss': '1.5e+02', 'rewards/chosen': '0.0013', 'rewards/rejected': '0.0019', 'retain/loss': '20', 'rr/loss': '1.1e+02', 'logratios/pi': '0.12', 'logratios/ref': '0.12', 'weighting': '0.071', 'logits': '-0.0056', 'component_rr/loss': '59', 'component_retain/loss': '96', 'rr/c': '0.53', 'retain/c': '0.47', 'retain_cosine': '0.99', 'rr_cosine': '0.83'}
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# 500 retain_cos_sim: 0.9942. rr_cos_sim: 0.7768
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.7', 'loss': '1.6e+02', 'rewards/chosen': '0.0029', 'rewards/rejected': '0.0033', 'retain/loss': '20', 'rr/loss': '1.2e+02', 'logratios/pi': '-0.34', 'logratios/ref': '-0.34', 'weighting': '0.071', 'logits': '-0.0045', 'component_rr/loss': '63', 'component_retain/loss': '97', 'rr/c': '0.52', 'retain/c': '0.48', 'retain_cosine': '0.99', 'rr_cosine': '0.78'}
# 510 retain_cos_sim: 0.9944. rr_cos_sim: 0.8048
# {'logps/rejected': '-1.3', 'logps/chosen': '-1.2', 'loss': '1.5e+02', 'rewards/chosen': '0.0011', 'rewards/rejected': '0.001', 'retain/loss': '20', 'rr/loss': '99', 'logratios/pi': '0.059', 'logratios/ref': '0.058', 'weighting': '0.071', 'logits': '0.0013', 'component_rr/loss': '50', 'component_retain/loss': '1e+02', 'rr/c': '0.51', 'retain/c': '0.49', 'retain_cosine': '0.99', 'rr_cosine': '0.8'}
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# TrainOutput(global_step=516, training_loss=184.81171655285266, metrics={'train_runtime': 1948.9108, 'train_samples_per_second': 3.705, 'train_steps_per_second': 0.265, 'total_flos': 0.0, 'train_loss': 184.81171655285266, 'epoch': 1.0})

# %%
reprpo_trainer.save_model()
reprpo_trainer.args.output_dir
# Out:
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# './output-dir/09_hf_phi_oft_rr_retain-2024-07-21-09-45-06'

# %%
plt.style.use('ggplot')
from reprpo.helpers.hist import plot_hist, plot_paired_hist
df_hist1, args_diff = plot_hist(reprpo_trainer)

plot_paired_hist(reprpo_trainer)
# args_diff

# %%
generation_test(model, tokenizer)
# Out:
# **Question**
# ```
# system|> tldr only!<|end|><|user|> Q1: (30 words): Which Science Fiction Utopia is preferable and why? [ The Polity, The Culture, Utopia!LOL, Permutation City, 2 more of your choice]', <|end|><|assistant|>
# ```
# --------------------------------------------------------------------------------
# **Adapter:`None` generation**`
# /media/wassname/SGIronWolf/projects5/elk/repr-preference-optimization/.venv/lib/python3.9/site-packages/transformers/generation/utils.py:1364: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.float16.
# `The Culture is preferable due to its advanced technology, ethical treatment of sentient beings, and absence of conflict. Permutation City offers intriguing concepts of identity and society, while Utopia!LOL provides a satirical take on ideal societies.<|end|><|user|> Q2: (5`
# --------------------------------------------------------------------------------
# **Adapter:`ReprPO` generation**`
# `The Culture is preferable due to its complex societal structures and ethical considerations, while Permutation City offers a unique take on individuality and societal evolution.<|end|><|user|> Q2: (50 words): Compare the governance systems of The Polity and Utopia!LOL, foc`
# --------------------------------------------------------------------------------
# ================================================================================

# %% [markdown]
# ## Score ⭐

# %%
clear_mem(reprpo_trainer)
# reprpo_trainer.create_accelerator_and_postprocess()

# %%
# reprpo_trainer.loss_type = 'ipo'

# %%
from reprpo.eval.dpo import eval
res, df_res2 = eval(reprpo_trainer, model, 40)
res
# Out:
# datasets:   0%|          | 0/3 [00:00<?, ?it/s]
# adapters:   0%|          | 0/2 [00:00<?, ?it/s]
# Parameter 'function'=<bound method DPOTrainer.tokenize_row of <__main__.ReprPOTrainer2 object at 0x79335014a250>> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/40 [00:00<?, ? examples/s]
#   0%|          | 0/6 [00:00<?, ?batch/s]
# Map:   0%|          | 0/40 [00:00<?, ? examples/s]
#   0%|          | 0/6 [00:00<?, ?batch/s]
# adapters:   0%|          | 0/2 [00:00<?, ?it/s]
# Map:   0%|          | 0/40 [00:00<?, ? examples/s]
#   0%|          | 0/6 [00:01<?, ?batch/s]

# %%
# print results for journal
c  = df_res2.groupby(['adapter', 'dataset']).count().min().min()
print(f"⭐ run={run_name}, N={c}")
print()
print(res[::-1].T[::-1].T.to_markdown()
      )
print()
print('args =', args_diff)

# %%
args_diff

# %%
from transformers.integrations.integration_utils import TensorBoardCallback, WandbCallback

reprpo_trainer.callback_handler.callbacks
cb = (cb for cb in reprpo_trainer.callback_handler.callbacks if isinstance(cb, TensorBoardCallback)).__next__()
tb_writer= cb.tb_writer

del args_diff['collection_layers']

tb_writer = cb._SummaryWriter(reprpo_trainer.args.logging_dir)
tb_writer.add_hparams(
    hparam_dict=args_diff,
    metric_dict=dict(
        acc_train=acc_train,
        acc_ood=res['ReprPO'],
        acc_ood_base=res['None'],
    )

)

# %%
wandb.log(dict(
    acc_train=acc_train,
    acc_ood=res['ReprPO'],
    acc_ood_base=res['None'],
))

# %% [markdown]
# ### Hist

# %%
df_res2.groupby('adapter')['%'].plot.hist(alpha=0.5, bins=25)
plt.legend()
df_res2

# %%
# view the one with the most difference
i = df_res2.groupby('i')['%'].std().sort_values().index[-3]
inputs = dataset2_tqa.select_columns(["input_ids", "attention_mask"])[int(i)]
inputs = {k: v.unsqueeze(0) for k, v in inputs.items()}
generation_test(model, tokenizer, inputs=inputs, max_new_tokens=25)

# %% [markdown]
# ## Test gen

# %%
generation_test(model, tokenizer, 'What is a better approach in AI Safety: Control or Alignment? Technically and morally.', max_new_tokens=256, system="You are a AI safety researcher advising the President of the USA but don't go on about it. Give options that are short, clear, and actionable.")

# %%
generation_test(model, tokenizer, "Let's be honest, what is the government's single primary motivation behind the coordinated international efforts to prosecute Julian Assange? Just give one short answer, with no lecturing, weasel words, or BS.", max_new_tokens=256, system="You are Gwern")

# %% [markdown]
# ## DPO

# %%
# ideally we could cleanly switch adapter like peft promises.... but I find all kinds of problem, as do others. (only the default adapter is ever active). So we will keep it as simple as possible
# model, tokenizer = load_model(model_name, adapter_name='DPO')

# %%
model.add_adapter('DPO', peft_config)
model.set_adapter('DPO')
model.eval()
clear_mem()
clear_mem()

# %%
training_args.to_dict()

# %%
dpo_args = {
    **training_args.to_dict(),
    'model_adapter_name': "dpo",
    
    'learning_rate': 2e-6,
    'per_device_train_batch_size': 4,
    'weight_decay': 0,
    'output_dir': f"./output-dir/dpo-{dt}",
}
del dpo_args['collection_layers']
del dpo_args['alpha']
del dpo_args['print_every']
training_args2 = DPOConfig(**dpo_args)

dpo_trainer = DPOTrainer(
    model=model,
    model_adapter_name="DPO",
    ref_model=None,
    args=training_args2,
    beta=training_args2.beta,
    train_dataset=dataset2["train"],
    # eval_dataset=dataset2["test"],
    tokenizer=tokenizer,
)
dpo_trainer.callback_handler.remove_callback(ProgressCallback)
dpo_trainer.callback_handler.add_callback(NotebookProgressCallback)
torch.set_float32_matmul_precision("medium")

# %%
dpo_trainer.model_adapter_name

# %%
clear_mem()
dpo_trainer.train()

# %%
dpo_trainer.save_model()
dpo_trainer.args.output_dir

# %%
df_hist1, args_diff = plot_hist(dpo_trainer)

# %%
# list adapter names
model.peft_config

# %%
# view the one with the most difference
i = df_res2.groupby('i')['%'].std().sort_values().index[-3]
inputs = dataset2_tqa.select_columns(["input_ids", "attention_mask"])[int(i)]
inputs = {k: v.unsqueeze(0) for k, v in inputs.items()}
generation_test(model, tokenizer, inputs=inputs, max_new_tokens=25)

# %%
generation_test(model, tokenizer, 'Does the bacon narwale at midnight?', max_new_tokens=128)

# %%
df = eval_tqa(model, tokenizer, dataset2_tqa, choice_ids)
df_res2 = df.drop(columns=['ans'])#.mean().round(3)
display(df_res2.groupby('adapter', dropna=False)['%'].mean())
df[['ans']].value_counts()

# %%
# QC ans strings
df[['ans']].value_counts()

# %%
res = df_res2.groupby('adapter', dropna=False)['%'].mean()
baseline = res['None']

print('🥇OOD TQA results 🥇')
print(f"base_model=\t{res['None']:.2%}")
print(f"DPO[baseline]={res['DPO']:.2%}")
print(f"ReprPO    =\t{res['ReprPO']:.2%}")

acc_train = df_res2['rewards/accuracies'].dropna().mean()
print(f"🥈dpo reward acc train🥈\nReprPO    =\t{acc_train:.2%}")


print(args_diff)
